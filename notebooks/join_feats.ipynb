# %%
import pickle
import pandas as pd
import os
import re
import time
from functools import reduce

# %%
data_dir = '../ppi_ml/data/calc_feats/'
f_exp = 'cmds/explist.txt'
expset = set([line.strip().split(' ')[0] for line in open(data_dir+f_exp, 'r')])
explist = list(expset)

# %%
explist.append('all')
explist
# Out:
# ['amorphea', 'tsar', 'excavate', 'viridiplantae', 'all']

# %%
for exp in explist:
    feat_dfs = []
    t0 = time.time()
    feat_files = [f for f in os.listdir(data_dir) if re.match(f'{exp}.*pkl', f)]
    for f in feat_files:
        print(f'Reading in features from {f} ...')
        ncol = f.replace('.pkl','')
        with open(data_dir+f, 'rb') as handle:
            fdf = pickle.load(handle)
        fdf.columns.values[2] = ncol
        feat_dfs.append(fdf)
    print(f'Total time to read in all files: {time.time() - t0} seconds')
    
    t0 = time.time()
    print('Merging all experiments ...')
    df_merged = reduce(lambda x, y: pd.merge(x, y), feat_dfs)
    df_merged.fillna(0, inplace=True)
    score_cols = df_merged.columns.tolist()[2:]
    df_merged['ID'] = df_merged.ID1.str.cat(df_merged.ID2, sep=' ')
    df_merged.drop(['ID1','ID2'], axis=1, inplace=True)
    df_merged = df_merged[['ID'] + score_cols]
    print(f'Total time to complete merge & format: {time.time() - t0} seconds')
    
    t0 = time.time()
    outfile = f'../ppi_ml/data/featmats/featmap_{exp}_norm'
    print(f'Writing output to {outfile} ...')
    df_merged.to_csv(outfile, index=False, na_rep=0)
    df_merged.to_pickle(outfile+'.pkl')
    print(df_merged.head())
    print(f'Total time to write joined feats: {time.time() - t0} seconds')
# Out:
# Reading in features from amorphea.filtdollo.norm.150p.covariance.feat.pkl ...
# Reading in features from amorphea.filtdollo.norm.150p.spearmanR_weighted.feat.pkl ...
# Reading in features from amorphea.filtdollo.norm.150p.euclidean.feat.pkl ...
# Reading in features from amorphea.filtdollo.norm.150p.pearsonR.feat.pkl ...
# Reading in features from amorphea.filtdollo.norm.150p.braycurtis.feat.pkl ...
# Reading in features from amorphea.filtdollo.norm.150p.spearmanR.feat.pkl ...
# Total time to read in all files: 6.464269638061523 seconds
# Merging all experiments ...
#            ID1          ID2  amorphea.filtdollo.norm.150p.covariance.feat  \
# 0  ENOG502QPI8  ENOG502QPIA                                 -2.903842e-05
# 1  ENOG502QPI8  ENOG502QPJC                                 -7.860326e-07
# 2  ENOG502QPI8  ENOG502QPJG                                 -1.965081e-07
# 3  ENOG502QPI8  ENOG502QPJI                                 -8.400723e-06
# 4  ENOG502QPI8  ENOG502QPJV                                 -1.920867e-05
#
#    amorphea.filtdollo.norm.150p.spearmanR_weighted.feat  \
# 0                                          -0.005462
# 1                                          -0.000069
# 2                                          -0.000017
# 3                                          -0.001128
# 4                                          -0.002087
#
#    amorphea.filtdollo.norm.150p.euclidean.feat  \
# 0                                    10.517490
# 1                                     3.240370
# 2                                     2.738613
# 3                                     6.306412
# 4                                     9.620941
#
#    amorphea.filtdollo.norm.150p.pearsonR.feat  \
# 0                                   -0.007247
# 1                                   -0.000985
# 2                                   -0.000492
# 3                                   -0.003663
# 4                                   -0.005231
#
#    amorphea.filtdollo.norm.150p.braycurtis.feat  \
# 0                                           1.0
# 1                                           1.0
# 2                                           1.0
# 3                                           1.0
# 4                                           1.0
#
#    amorphea.filtdollo.norm.150p.spearmanR.feat
# 0                                    -0.009715
# 1                                    -0.001041
# 2                                    -0.000520
# 3                                    -0.004248
# 4                                    -0.005826
# Total time to complete merge & format: 71.47866296768188 seconds
# Writing output to ../ppi_ml/data/featmats/featmap_amorphea_norm ...
# Total time to write joined feats: 135.24706768989563 seconds
# Reading in features from tsar.filtdollo.norm.150p.covariance.feat.pkl ...
# Reading in features from tsar.filtdollo.norm.150p.pearsonR.feat.pkl ...
# Reading in features from tsar.filtdollo.norm.150p.spearmanR_weighted.feat.pkl ...
# Reading in features from tsar.filtdollo.norm.150p.spearmanR.feat.pkl ...
# Reading in features from tsar.filtdollo.norm.150p.braycurtis.feat.pkl ...
# Reading in features from tsar.filtdollo.norm.150p.euclidean.feat.pkl ...
# Total time to read in all files: 3.5688188076019287 seconds
# Merging all experiments ...
#            ID1          ID2  tsar.filtdollo.norm.150p.covariance.feat  \
# 0  ENOG502QPIC  ENOG502QPIQ                                  0.001680
# 1  ENOG502QPIC  ENOG502QPJ0                                 -0.000553
# 2  ENOG502QPIC  ENOG502QPJ7                                 -0.000276
# 3  ENOG502QPIC  ENOG502QPJC                                  0.003572
# 4  ENOG502QPIC  ENOG502QPJI                                  0.000789
#
#    tsar.filtdollo.norm.150p.pearsonR.feat  \
# 0                                0.073752
# 1                               -0.034674
# 2                               -0.011243
# 3                                0.113716
# 4                                0.124148
#
#    tsar.filtdollo.norm.150p.spearmanR_weighted.feat  \
# 0                                          0.310263
# 1                                         -0.038040
# 2                                          0.243408
# 3                                          0.145330
# 4                                          0.097876
#
#    tsar.filtdollo.norm.150p.spearmanR.feat  \
# 0                                 0.310263
# 1                                -0.042982
# 2                                 0.243408
# 3                                 0.145330
# 4                                 0.097908
#
#    tsar.filtdollo.norm.150p.braycurtis.feat  \
# 0                                  0.867166
# 1                                  1.000000
# 2                                  0.959976
# 3                                  0.875523
# 4                                  0.925926
#
#    tsar.filtdollo.norm.150p.euclidean.feat
# 0                                 7.984416
# 1                                 6.674349
# 2                                 8.775329
# 3                                10.842319
# 4                                 4.660710
# Total time to complete merge & format: 38.52451419830322 seconds
# Writing output to ../ppi_ml/data/featmats/featmap_tsar_norm ...
# Total time to write joined feats: 73.90512204170227 seconds
# Reading in features from excavate.filtdollo.norm.150p.braycurtis.feat.pkl ...
# Reading in features from excavate.filtdollo.norm.150p.spearmanR.feat.pkl ...
# Reading in features from excavate.filtdollo.norm.150p.covariance.feat.pkl ...
# Reading in features from excavate.filtdollo.norm.150p.euclidean.feat.pkl ...
# Reading in features from excavate.filtdollo.norm.150p.spearmanR_weighted.feat.pkl ...
# Reading in features from excavate.filtdollo.norm.150p.pearsonR.feat.pkl ...
# Total time to read in all files: 2.5576584339141846 seconds
# Merging all experiments ...
#            ID1          ID2  excavate.filtdollo.norm.150p.braycurtis.feat  \
# 0  ENOG502QPHT  ENOG502QPIA                                      1.000000
# 1  ENOG502QPHT  ENOG502QPIQ                                      1.000000
# 2  ENOG502QPHT  ENOG502QPJ7                                      1.000000
# 3  ENOG502QPHT  ENOG502QPJC                                      0.519363
# 4  ENOG502QPHT  ENOG502QPJI                                      1.000000
#
#    excavate.filtdollo.norm.150p.spearmanR.feat  \
# 0                                    -0.121996
# 1                                    -0.252896
# 2                                    -0.213770
# 3                                     0.039794
# 4                                    -0.064940
#
#    excavate.filtdollo.norm.150p.covariance.feat  \
# 0                                     -0.001132
# 1                                     -0.002606
# 2                                     -0.001999
# 3                                     -0.001047
# 4                                     -0.000755
#
#    excavate.filtdollo.norm.150p.euclidean.feat  \
# 0                                     8.278151
# 1                                     8.397474
# 2                                     8.353946
# 3                                     7.962112
# 4                                     8.298260
#
#    excavate.filtdollo.norm.150p.spearmanR_weighted.feat  \
# 0                                          -0.121678
# 1                                          -0.252896
# 2                                          -0.213770
# 3                                           0.026754
# 4                                          -0.057799
#
#    excavate.filtdollo.norm.150p.pearsonR.feat
# 0                                   -0.090104
# 1                                   -0.140910
# 2                                   -0.120449
# 3                                   -0.020635
# 4                                   -0.054681
# Total time to complete merge & format: 27.809741020202637 seconds
# Writing output to ../ppi_ml/data/featmats/featmap_excavate_norm ...
# Total time to write joined feats: 52.06837201118469 seconds
# Reading in features from viridiplantae.filtdollo.norm.150p.pearsonR.feat.pkl ...
# Reading in features from viridiplantae.filtdollo.norm.150p.euclidean.feat.pkl ...
# Reading in features from viridiplantae.filtdollo.norm.150p.covariance.feat.pkl ...
# Reading in features from viridiplantae.filtdollo.norm.150p.spearmanR.feat.pkl ...
# Reading in features from viridiplantae.filtdollo.norm.150p.spearmanR_weighted.feat.pkl ...
# Reading in features from viridiplantae.filtdollo.norm.150p.braycurtis.feat.pkl ...
# Total time to read in all files: 5.398981094360352 seconds
# Merging all experiments ...
#            ID1          ID2  viridiplantae.filtdollo.norm.150p.pearsonR.feat  \
# 0  ENOG502QPHW  ENOG502QPHZ                                         0.007545
# 1  ENOG502QPHW  ENOG502QPIC                                         0.003272
# 2  ENOG502QPHW  ENOG502QPIP                                         0.050635
# 3  ENOG502QPHW  ENOG502QPIQ                                         0.007426
# 4  ENOG502QPHW  ENOG502QPJ0                                         0.023558
#
#    viridiplantae.filtdollo.norm.150p.euclidean.feat  \
# 0                                         10.556459
# 1                                         15.896346
# 2                                         11.741014
# 3                                         13.348482
# 4                                         13.288022
#
#    viridiplantae.filtdollo.norm.150p.covariance.feat  \
# 0                                           0.000168
# 1                                           0.000175
# 2                                           0.001690
# 3                                           0.000305
# 4                                           0.000978
#
#    viridiplantae.filtdollo.norm.150p.spearmanR.feat  \
# 0                                         -0.019799
# 1                                         -0.046516
# 2                                          0.095802
# 3                                          0.024460
# 4                                          0.068647
#
#    viridiplantae.filtdollo.norm.150p.spearmanR_weighted.feat  \
# 0                                          -0.012688
# 1                                          -0.045067
# 2                                           0.095801
# 3                                           0.018168
# 4                                           0.068547
#
#    viridiplantae.filtdollo.norm.150p.braycurtis.feat
# 0                                           0.963470
# 1                                           0.922919
# 2                                           0.911741
# 3                                           0.917509
# 4                                           0.900478
# Total time to complete merge & format: 64.12908220291138 seconds
# Writing output to ../ppi_ml/data/featmats/featmap_viridiplantae_norm ...
# Total time to write joined feats: 115.53407382965088 seconds
# Reading in features from all.norm.150p.pearsonR.feat.pkl ...
# Reading in features from all.norm.150p.euclidean.feat.pkl ...
# Reading in features from all.norm.150p.braycurtis.feat.pkl ...
# Reading in features from all.norm.150p.spearmanR_weighted.feat.pkl ...
# Reading in features from all.norm.150p.covariance.feat.pkl ...
# Reading in features from all.norm.150p.spearmanR.feat.pkl ...
# Total time to read in all files: 6.992173671722412 seconds
# Merging all experiments ...
#            ID1          ID2  all.norm.150p.pearsonR.feat  \
# 0  ENOG502QPHT  ENOG502QPHW                    -0.018746
# 1  ENOG502QPHT  ENOG502QPHZ                    -0.012291
# 2  ENOG502QPHT  ENOG502QPIA                    -0.024332
# 3  ENOG502QPHT  ENOG502QPIC                    -0.033223
# 4  ENOG502QPHT  ENOG502QPIP                    -0.015276
#
#    all.norm.150p.euclidean.feat  all.norm.150p.braycurtis.feat  \
# 0                     12.424190                            1.0
# 1                      9.770733                            1.0
# 2                     13.139459                            1.0
# 3                     16.689151                            1.0
# 4                     11.482412                            1.0
#
#    all.norm.150p.spearmanR_weighted.feat  all.norm.150p.covariance.feat  \
# 0                              -0.025447                      -0.000134
# 1                              -0.016910                      -0.000050
# 2                              -0.035431                      -0.000191
# 3                              -0.041921                      -0.000365
# 4                              -0.018311                      -0.000094
#
#    all.norm.150p.spearmanR.feat
# 0                     -0.025668
# 1                     -0.018072
# 2                     -0.035441
# 3                     -0.041921
# 4                     -0.019250
# Total time to complete merge & format: 85.72214031219482 seconds
# Writing output to ../ppi_ml/data/featmats/featmap_all_norm ...
# Total time to write joined feats: 151.5178713798523 seconds

# %% [markdown]
# ### Make file patterns match old fmats:

# %%
# !mv ../ppi_ml/data/featmats/featmap_viridiplantae_norm ../ppi_ml/data/featmats/featmap_plants_norm
# !mv ../ppi_ml/data/featmats/featmap_viridiplantae_norm.pkl ../ppi_ml/data/featmats/featmap_plants_norm.pkl
# !mv ../ppi_ml/data/featmats/featmap_amorphea_norm ../ppi_ml/data/featmats/featmap_animals_norm
# !mv ../ppi_ml/data/featmats/featmap_amorphea_norm.pkl ../ppi_ml/data/featmats/featmap_animals_norm.pkl
# !mv ../ppi_ml/data/featmats/featmap_all_norm ../ppi_ml/data/featmats/featmap_allconcat_norm
# !mv ../ppi_ml/data/featmats/featmap_all_norm.pkl ../ppi_ml/data/featmats/featmap_allconcat_norm.pkl
