# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# set the color palette
# colors = ["#096264", "#5CC3AF", "#E7E1BD", "#ECA24D", "#DD3D00"]
# sns.set_palette(colors)

# %%
# !pwd
# Out:
# /stor/work/Marcotte/project/rmcox/leca/notebooks

# %%
# viridis-like
custom = sns.cubehelix_palette(start=0.05, rot=-.55, light=0.9, dark=0)
sns.cubehelix_palette(start=0.05, rot=-.55, light=0.9, dark=0, as_cmap=True)

# %%
rocket = sns.color_palette("rocket_r")
sns.color_palette("rocket_r", as_cmap=True)

# %%
# actually viridis
vir = sns.color_palette("viridis_r")
sns.color_palette("viridis_r", as_cmap=True)

# %%
cmr = sns.color_palette("CMRmap_r", 8)
sns.color_palette(n_colors=8, palette="CMRmap_r")
# Out:
# [(0.9121568627450981, 0.9121568627450981, 0.5607843137254902),
#  (0.9, 0.7864705882352941, 0.19725490196078432),
#  (0.9, 0.5833333333333334, 0.03333333333333334),
#  (0.9545098039215686, 0.36372549019607847, 0.08176470588235293),
#  (0.8180392156862745, 0.22725490196078432, 0.3092156862745098),
#  (0.5, 0.18333333333333335, 0.5833333333333334),
#  (0.2635294117647059, 0.15, 0.6892156862745098),
#  (0.13176470588235295, 0.13176470588235295, 0.4392156862745098)]

# %%
npg = ["#E64B35", "#4DBBD5", "#00A087", "#3C5488", "#F39B7F", "#8491B4", "#91D1C2", "#DC0000", "#7E6148", "#B09C85"]
sns.blend_palette
# Out:
# '0.12.1'

# %%
# cividis
civ = sns.color_palette("cividis_r")
sns.color_palette("cividis_r", as_cmap=True)

# %%
sns.color_palette("ch:s=-.2,r=.6", as_cmap=True)

# %%
# generate some random data
data = np.random.rand(25,25)

# create the heat map
plt.figure(figsize=(6, 8))
sns.heatmap(
    data, vmin = 0, vmax = 1, 
    xticklabels=False, yticklabels=False,
    cmap="cividis_r"
)

# show the plot
plt.show()

# %%
ifile = 'leca.unique.filtdollo.150p.norm.ordered.clst.correlation.average.elut.pkl'
path = '../ppi_ml/results/elutions/clustered/'
df = pd.read_pickle(path+ifile)
df.set_index('orthogroup', inplace=True)
df.head()
# Out:
#              Rotifer_SEC_09a_04162018  Rotifer_SEC_10a_04162018  \
# orthogroup
# ENOG502QU2G                  0.038462                  0.076923
# ENOG502SCCH                  0.000000                  0.000000
# ENOG502QU2S                  0.000000                  0.000000
# ENOG502QRRC                  0.000000                  0.000000
# ENOG502RH9U                  0.000000                  0.000000
#
#              Rotifer_SEC_11a_04162018  Rotifer_SEC_12a_04162018  \
# orthogroup
# ENOG502QU2G                  0.038462                  0.153846
# ENOG502SCCH                  0.000000                  0.000000
# ENOG502QU2S                  0.000000                  0.000000
# ENOG502QRRC                  0.000000                  0.000000
# ENOG502RH9U                  0.000000                  0.000000
#
#              Rotifer_SEC_13a_04142018  Rotifer_SEC_14a_04142018  \
# orthogroup
# ENOG502QU2G                  0.230769                  0.307692
# ...

# %%
x = df.to_numpy()

# %%
plt.figure(figsize=(8, 4.5))
p = sns.heatmap(x, xticklabels=False, yticklabels=False, cmap = "cividis_r")
p.tick_params(left=False, bottom=False)
# plt.savefig('../ppi_ml/figures/elut_heatmap_150p_norm_18kr.pdf', 
#            dpi=300)
# plt.savefig('../ppi_ml/figures/elut_heatmap_150p_norm_18kr.png', 
#            dpi=300)
plt.show()

# %%
plt.figure(figsize=(8, 4.5))
p = sns.heatmap(x, xticklabels=False, yticklabels=False, cmap = "rocket_r")
p.tick_params(left=False, bottom=False)
# plt.savefig('../ppi_ml/figures/elut_heatmap_150p_filtdollo_norm_6krows.pdf', 
#            dpi=300)
# plt.savefig('../ppi_ml/figures/elut_heatmap_150p_filtdollo_norm_6krows.png', 
#            dpi=300)
plt.show()
