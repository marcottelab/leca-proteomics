# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# set the color palette
# colors = ["#096264", "#5CC3AF", "#E7E1BD", "#ECA24D", "#DD3D00"]
# sns.set_palette(colors)
cscale = sns.cm.rocket_r

# %%
# !pwd
# Out:
# /stor/work/Marcotte/project/rmcox/leca/notebooks

# %%
# generate some random data
data = np.random.rand(10,10)

# create the heat map
sns.heatmap(data, cmap = cscale)

# show the plot
plt.show()

# %%
ifile = '../ppi_ml/results/elutions/leca.unique.150p.norm.elut.ordered.hclust.pkl'
df = pd.read_pickle(ifile)
df.set_index('orthogroup', inplace=True)
df.head()
# Out:
#             Rotifer_SEC_09a_04162018  Rotifer_SEC_10a_04162018  \
# orthogroup
# KOG1745                     0.250000                  0.500000
# KOG3467                     1.000000                  0.666667
# KOG1756                     0.666667                  0.333333
# KOG1744                     0.636364                  0.454545
# KOG1757                     0.000000                  0.000000
#
#             Rotifer_SEC_11a_04162018  Rotifer_SEC_12a_04162018  \
# orthogroup
# KOG1745                     0.500000                  0.250000
# KOG3467                     0.555556                  0.666667
# KOG1756                     0.333333                  0.333333
# KOG1744                     0.454545                  0.727273
# KOG1757                     0.000000                  0.000000
#
#             Rotifer_SEC_13a_04142018  Rotifer_SEC_14a_04142018  \
# orthogroup
# KOG1745                     0.000000                  0.250000
# KOG3467                     0.777778                  0.777778
# KOG1756                     0.333333                  0.333333
# KOG1744                     0.636364                  1.000000
# KOG1757                     1.000000                  0.000000
#
#             Rotifer_SEC_15a_04142018  Rotifer_SEC_16a_04142018  \
# orthogroup
# KOG1745                     0.000000                  0.250000
# KOG3467                     0.666667                  0.777778
# KOG1756                     1.000000                  0.666667
# KOG1744                     0.545455                  0.727273
# KOG1757                     0.500000                  0.500000
#
#             Rotifer_SEC_17a_04152018  Rotifer_SEC_18a_04152018  ...  \
# orthogroup                                                      ...
# KOG1745                     0.250000                  0.250000  ...
# KOG3467                     0.888889                  0.888889  ...
# KOG1756                     0.666667                  0.000000  ...
# KOG1744                     0.727273                  0.636364  ...
# KOG1757                     0.500000                  0.000000  ...
#
#             Wheatgrass_SEC_40a_02022017  Wheatgrass_SEC_41a_02022017  \
# orthogroup
# KOG1745                        0.888889                     1.000000
# KOG3467                        0.666667                     1.000000
# KOG1756                        0.000000                     0.125000
# KOG1744                        0.181818                     0.181818
# KOG1757                        0.000000                     0.000000
#
#             Wheatgrass_SEC_42a_02022017  Wheatgrass_SEC_43a_02022017  \
# orthogroup
# KOG1745                        0.666667                     0.888889
# KOG3467                        0.500000                     0.833333
# KOG1756                        0.125000                     0.000000
# KOG1744                        0.000000                     0.090909
# KOG1757                        0.000000                     0.000000
#
#             Wheatgrass_SEC_44a_02032017  Wheatgrass_SEC_45a_02032017  \
# orthogroup
# KOG1745                        0.444444                     0.555556
# KOG3467                        0.333333                     0.333333
# KOG1756                        0.000000                     0.125000
# KOG1744                        0.272727                     0.181818
# KOG1757                        0.333333                     0.000000
#
#             Wheatgrass_SEC_47b_02032017_170207030854  \
# orthogroup
# KOG1745                                     0.222222
# KOG3467                                     0.000000
# KOG1756                                     0.000000
# KOG1744                                     0.090909
# KOG1757                                     0.000000
#
#             Wheatgrass_SEC_48a_02032017  Wheatgrass_SEC_49a_02032017  \
# orthogroup
# KOG1745                        0.333333                     0.444444
# KOG3467                        0.000000                     0.000000
# KOG1756                        0.000000                     0.000000
# KOG1744                        0.000000                     0.272727
# KOG1757                        0.000000                     0.000000
#
#             Wheatgrass_SEC_50a_02032017
# orthogroup
# KOG1745                        0.333333
# KOG3467                        0.333333
# KOG1756                        0.000000
# KOG1744                        0.090909
# KOG1757                        0.000000
#
# [5 rows x 10481 columns]

# %%
#test = df.iloc[:3000,:3000]

# %%
x = df.to_numpy()

# %%
p = sns.heatmap(x, xticklabels=False, yticklabels=False)
p.tick_params(left=False, bottom=False)
# plt.savefig('../ppi_ml/figures/elut_heatmap_150p_norm_18kr.pdf', 
#            dpi=300)
# plt.savefig('../ppi_ml/figures/elut_heatmap_150p_norm_18kr.png', 
#            dpi=300)
plt.show()

# %%
ifile = '../ppi_ml/results/elutions/pkl/leca.unique.filtdollo.150p.norm.elut.ordered.pkl'
df = pd.read_pickle(ifile)
df.set_index('orthogroup', inplace=True)
df.head()
# Out:
#              Rotifer_SEC_09a_04162018  Rotifer_SEC_10a_04162018  \
# orthogroup
# ENOG502QPM4                   0.00000                  0.500000
# ENOG502QPNA                   0.00000                  0.000000
# ENOG502QPP0                   0.56338                  0.922535
# ENOG502QPPX                   0.00000                  0.000000
# ENOG502QPRY                   0.00000                  0.000000
#
#              Rotifer_SEC_11a_04162018  Rotifer_SEC_12a_04162018  \
# orthogroup
# ENOG502QPM4                       0.0                  0.000000
# ENOG502QPNA                       0.0                  0.000000
# ENOG502QPP0                       1.0                  0.542254
# ENOG502QPPX                       0.0                  0.000000
# ENOG502QPRY                       0.0                  0.000000
#
#              Rotifer_SEC_13a_04142018  Rotifer_SEC_14a_04142018  \
# orthogroup
# ENOG502QPM4                  0.000000                  0.000000
# ENOG502QPNA                  0.000000                  0.000000
# ENOG502QPP0                  0.338028                  0.232394
# ENOG502QPPX                  0.000000                  0.000000
# ENOG502QPRY                  0.000000                  0.000000
#
#              Rotifer_SEC_15a_04142018  Rotifer_SEC_16a_04142018  \
# orthogroup
# ENOG502QPM4                  0.000000                  0.000000
# ENOG502QPNA                  0.500000                  0.000000
# ENOG502QPP0                  0.225352                  0.232394
# ENOG502QPPX                  0.000000                  0.000000
# ENOG502QPRY                  0.000000                  0.000000
#
#              Rotifer_SEC_17a_04152018  Rotifer_SEC_18a_04152018  ...  \
# orthogroup                                                       ...
# ENOG502QPM4                  0.500000                  0.000000  ...
# ENOG502QPNA                  0.000000                  0.000000  ...
# ENOG502QPP0                  0.225352                  0.211268  ...
# ENOG502QPPX                  0.000000                  0.000000  ...
# ENOG502QPRY                  0.000000                  0.000000  ...
#
#              Wheatgrass_SEC_40a_02022017  Wheatgrass_SEC_41a_02022017  \
# orthogroup
# ENOG502QPM4                          0.0                          0.0
# ENOG502QPNA                          0.0                          0.0
# ENOG502QPP0                          0.0                          0.0
# ENOG502QPPX                          0.0                          0.0
# ENOG502QPRY                          0.0                          0.0
#
#              Wheatgrass_SEC_42a_02022017  Wheatgrass_SEC_43a_02022017  \
# orthogroup
# ENOG502QPM4                          0.0                          0.0
# ENOG502QPNA                          0.0                          0.0
# ENOG502QPP0                          0.0                          0.0
# ENOG502QPPX                          0.0                          0.0
# ENOG502QPRY                          0.0                          0.0
#
#              Wheatgrass_SEC_44a_02032017  Wheatgrass_SEC_45a_02032017  \
# orthogroup
# ENOG502QPM4                          0.0                          0.0
# ENOG502QPNA                          0.0                          0.0
# ENOG502QPP0                          0.0                          0.0
# ENOG502QPPX                          0.0                          0.0
# ENOG502QPRY                          0.0                          0.0
#
#              Wheatgrass_SEC_47b_02032017_170207030854  \
# orthogroup
# ENOG502QPM4                                       0.0
# ENOG502QPNA                                       0.0
# ENOG502QPP0                                       0.0
# ENOG502QPPX                                       0.0
# ENOG502QPRY                                       0.0
#
#              Wheatgrass_SEC_48a_02032017  Wheatgrass_SEC_49a_02032017  \
# orthogroup
# ENOG502QPM4                          0.0                          0.0
# ENOG502QPNA                          0.0                          0.0
# ENOG502QPP0                          0.0                          0.0
# ENOG502QPPX                          0.0                          0.0
# ENOG502QPRY                          0.0                          0.0
#
#              Wheatgrass_SEC_50a_02032017
# orthogroup
# ENOG502QPM4                          0.0
# ENOG502QPNA                          0.0
# ENOG502QPP0                          0.0
# ENOG502QPPX                          0.0
# ENOG502QPRY                          0.0
#
# [5 rows x 10481 columns]

# %%
#test = df.iloc[:3000,:3000]

# %%
x = df.to_numpy()

# %%
p = sns.heatmap(x, xticklabels=False, yticklabels=False, cmap = cscale)
p.tick_params(left=False, bottom=False)
# plt.savefig('../ppi_ml/figures/elut_heatmap_150p_filtdollo_norm_6krows.pdf', 
#            dpi=300)
# plt.savefig('../ppi_ml/figures/elut_heatmap_150p_filtdollo_norm_6krows.png', 
#            dpi=300)
plt.show()
