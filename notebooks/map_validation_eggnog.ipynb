# %%
import pandas as pd
import re
import time
import numpy as np

# %% [markdown]
# # Set up mapping (Entrez <-> Ensembl <-> UniProt <-> eggNOG)

# %%
e2u_file = '../ppi_ml/annotations/uniprot/EntrezToUniprot_clean.csv'
u2og_file = '../ppi_ml/data/og_proteomes/nog_mapping/human.euNOG.diamond.mapping.2759'

# %%
u2og = pd.read_csv(u2og_file, sep='\t')
u2og['uniprot_id'] = u2og['ProteinID'].str.extract(r'(?<=\|)(.*)(?=\|)')    
u2og.head()
# Out:
#                         ProteinID           ID  uniprot_id
# 0  tr|A0A024R1R8|A0A024R1R8_HUMAN      KOG4766  A0A024R1R8
# 1       sp|A0A024RBG1|NUD4B_HUMAN      KOG2839  A0A024RBG1
# 2  tr|A0A024RCN7|A0A024RCN7_HUMAN  ENOG502R0UR  A0A024RCN7
# 3  tr|A0A075B6H5|A0A075B6H5_HUMAN  ENOG502SA48  A0A075B6H5
# 4        sp|A0A075B6H7|KV37_HUMAN  ENOG502S3KF  A0A075B6H7

# %%
og_dict = dict()
og_issues = []
og_dupes = []
for i in range(len(u2og)):
    up = u2og['uniprot_id'][i]
    og = u2og['ID'][i]
    if up not in og_dict.keys():
        og_dict.update({up: og})
    else:
        if u2og['ID'][i] != og_dict[up]:
            og_issues.append(up)
            og_dict.pop(up)
        if up not in og_dupes:
            og_dupes.append(up)
print("# of total duplicated UniProt IDs = ", len(og_dupes))
print("# of UniProt IDs that map to multiple eggNOG IDs = ", len(set(og_issues)))
# Out:
# # of total duplicated UniProt IDs =  347
# # of UniProt IDs that map to multiple eggNOG IDs =  347

# %%
e2u = pd.read_csv(e2u_file)
e2u['entrez_id'] = e2u['entrez_id'].astype(str).replace('\.0', '', regex=True)
e2u.dropna(inplace=True)
e2u.reset_index(drop=True, inplace=True)
e2u.head()
# Out:
#     gene_stable_id gene_stable_id_version entrez_id  uniprot_id uniprot_sp_id
# 0  ENSG00000198888      ENSG00000198888.2      4535      P03886        P03886
# 1  ENSG00000198888      ENSG00000198888.2      4535      U5Z754        P03886
# 2  ENSG00000198763      ENSG00000198763.3      4536      P03891        P03891
# 3  ENSG00000198763      ENSG00000198763.3      4536      Q7GXY9        P03891
# 4  ENSG00000198763      ENSG00000198763.3      4536  A0A1X7RBG6        P03891

# %%
ensembl_dict = dict()
ensembl_issues = []
ensembl_dupes = []
for i in range(len(e2u)):
    up = e2u['uniprot_sp_id'][i]
    ens = e2u['gene_stable_id'][i]
    if ens in ensembl_issues:
        continue
    elif ens not in ensembl_dict.keys():
        ensembl_dict.update({ens: up})
    else:
        if e2u['uniprot_sp_id'][i] != ensembl_dict[ens]:
            ensembl_issues.append(ens)
            ensembl_dict.pop(ens)
        if ens not in ensembl_dupes:
            ensembl_dupes.append(ens)
print("# of total Ensembl IDs uniquely mapped to UniProt IDs = ", len(ensembl_dict))
print("# of total duplicated Ensembl IDs = ", len(ensembl_dupes))
print("# of Ensembl IDs that map to multiple UniProt IDs = ", len(set(ensembl_issues)))
# Out:
# # of total Ensembl IDs uniquely mapped to UniProt IDs =  21236
# # of total duplicated Ensembl IDs =  15456
# # of Ensembl IDs that map to multiple UniProt IDs =  41

# %%
entrez_dict = dict()
entrez_issues = []
entrez_dupes = []
for i in range(len(e2u)):
    up = e2u['uniprot_sp_id'][i]
    enz = e2u['entrez_id'][i]
    if enz in entrez_issues:
        continue
    elif enz not in entrez_dict.keys():
        entrez_dict.update({enz: up})
    else:
        if e2u['uniprot_sp_id'][i] != entrez_dict[enz]:
            entrez_issues.append(enz)
            entrez_dict.pop(enz)
        if enz not in entrez_dupes:
            entrez_dupes.append(enz)
print("# of total Entrez IDs uniquely mapped to UniProt IDs = ", len(entrez_dict))
print("# of total duplicated Entrez IDs = ", len(entrez_dupes))
print("# of Entrez IDs that map to multiple UniProt IDs = ", len(set(entrez_issues)))
# Out:
# # of total Entrez IDs uniquely mapped to UniProt IDs =  19105
# # of total duplicated Entrez IDs =  14189
# # of Entrez IDs that map to multiple UniProt IDs =  110

# %%
entrez_dict
# Out:
# {'4535': 'P03886',
#  '4536': 'P03891',
#  '4512': 'P00395',
#  '4513': 'P00403',
#  '4509': 'P03928',
#  '4508': 'P00846',
#  '4514': 'P00414',
#  '4537': 'P03897',
#  '4539': 'P03901',
#  '4538': 'P03905',
#  '4540': 'P03915',
#  '4541': 'P03923',
#  '4519': 'P00156',
#  '55251': 'Q9NV79',
#  '3804': 'P43628',
#  '2832': 'P48146',
#  '3809': 'P43632',
#  '100132285': 'P43631',
#  '124900573': 'P43631',
#  '124900575': 'P43631',
#  '3805': 'Q99706',
#  '124900568': 'Q99706',
#  '3803': 'P43627',
#  '3808': 'Q14952',
#  '4661': 'Q01538',
#  '3811': 'P43629',
#  '65123': 'Q68E01',
#  '124900569': 'Q8N109',
#  '2204': 'P24071',
#  '3812': 'P43630',
#  '553128': 'Q8NHK3',
#  '57459': 'Q8WXI9',
#  '80212': 'Q53HC0',
#  '3806': 'Q14954',
#  '3802': 'P43626',
#  '11000': 'Q5K4L6',
#  '7639': 'Q03923',
#  '115653': 'Q8N743',
#  '54474': 'P35900',
#  '283189': 'Q8NGQ1',
#  '83896': 'Q9BYR8',
#  '83897': 'Q9BYR7',
#  '85294': 'Q9BYR9',
#  '25984': 'Q9C075',
#  '83899': 'Q9BYQ4',
#  '85280': 'Q9BYQ2',
#  '83900': 'Q9BYQ3',
#  '163227': 'Q8IYN0',
#  '100533177': 'A8MX34',
#  '100507608': 'A8MVA2',
#  '100505724': 'A8MTY7',
#  '81870': 'Q9BYP9',
#  '125115': 'Q6A162',
#  '81851': 'Q07627',
#  '653240': 'Q9BYQ6',
#  '81850': 'Q8IUG1',
#  '85354': 'G5E9R7',
#  '3859': 'Q99456',
#  '83895': 'Q9BYS1',
#  '390792': 'Q6A163',
#  '81872': 'Q9BYU5',
#  '85293': 'Q9BYR6',
#  '730755': 'P0C7H8',
#  '83755': 'Q9BQ66',
#  '728255': 'P0C5Y4',
#  '64711': 'Q96QI5',
#  '58516': 'Q9NP50',
#  '26084': 'Q96DR7',
#  '92126': 'Q8IZU8',
#  '200315': 'P31941',
#  '100913187': 'P31941',
#  '6218': 'P08708',
#  '9231': 'Q8TDM6',
#  '9271': 'Q96J94',
#  '283767': 'Q8N7Z2',
#  '124900581': 'Q8N7Z2',
#  '124905482': 'Q8N7Z2',
#  '124907501': 'Q8N7Z2',
#  '440023': 'Q6L8G9',
#  '387264': 'Q6L8H4',
#  '387267': 'Q6L8H1',
#  '57818': 'Q9NQR9',
#  '51289': 'Q9NSD7',
#  '57405': 'Q9HBM1',
#  '26047': 'Q9UHC6',
#  '1850': 'Q13202',
#  '387266': 'Q6L8H2',
#  '440021': 'Q701N4',
#  '22904': 'Q9Y2G9',
#  '26063': 'Q9NUI1',
#  '26065': 'Q8ND56',
#  '220134': 'Q96BD8',
#  '284207': 'Q641Q3',
#  '64506': 'Q9BZB8',
#  '2618': 'P22102',
#  '54943': 'Q9NX36',
#  '254879': 'Q8NHC8',
#  '401992': 'Q6IF00',
#  '127074': 'Q8NH00',
#  '81458': 'P0C7T2',
#  '26696': 'O43869',
#  '439915': 'Q701N2',
#  '343173': 'Q8NH03',
#  '401993': 'Q6IEZ7',
#  '440295': 'A6NEM1',
#  '9727': 'O75154',
#  '3460': 'P38484',
#  '344752': 'Q6P093',
#  '26692': 'Q9Y3N9',
#  '757': 'P56557',
#  '94104': 'Q9Y5B6',
#  '56245': 'Q9NYP8',
#  '442191': 'Q9UGF5',
#  '4700': 'P56556',
#  '91689': 'Q9H4I9',
#  '85409': 'Q969F2',
#  '146712': 'Q67FW5',
#  '124907948': 'Q67FW5',
#  '84221': 'Q9H0A9',
#  '504190': 'P0C7N5',
#  '390154': 'Q8NGG3',
#  '219464': 'Q8NGG2',
#  '219473': 'Q8NH51',
#  '219469': 'Q8NGG4',
#  '390155': 'Q8NG75',
#  '390157': 'Q8NGG5',
#  '219477': 'Q8NGP2',
#  '5987': 'P14373',
#  '84498': 'Q96EK7',
#  '282890': 'Q5JNZ3',
#  '28514': 'O00548',
#  '1565': 'P10635',
#  '442184': 'O76000',
#  '84916': 'Q969X6',
#  '10288': 'Q8N423',
#  '6942': 'Q9UGU0',
#  '23547': 'P59901',
#  '57661': 'Q9P1Y6',
#  '441864': 'B6A8C7',
#  '7940': 'O00453',
#  '79143': 'Q96N66',
#  '622': 'Q02338',
#  '256329': 'Q8IXW0',
#  '6606': 'Q16637',
#  '6607': 'Q16637',
#  '3903': 'Q6GTX8',
#  '374308': 'Q3KNS1',
#  '79799': 'Q6UWM9',
#  '442186': 'O76001',
#  '4849': 'O75175',
#  '1196': 'P49760',
#  '112724': 'Q8NBN7',
#  '200958': 'Q8N307',
#  '7365': 'P36537',
#  '79042': 'Q9BSV6',
#  '4277': 'Q29980',
#  '5313': 'P30613',
#  '10107': 'Q9UDY6',
#  '79165': 'Q96BZ8',
#  '80352': 'Q9H2S5',
#  '10067': 'O14828',
#  '6050': 'P13489',
#  '503618': 'Q8WTQ1',
#  '124906746': 'Q8WTQ1',
#  '26531': 'Q9GZK7',
#  '147798': 'Q7Z404',
#  '245908': 'Q8NG35',
#  '504180': 'Q8NG35',
#  '124906747': 'Q8NG35',
#  '100131608': 'E9PI22',
#  '199713': 'Q8WX94',
#  '1673': 'O15263',
#  '100289462': 'O15263',
#  '124906748': 'O15263',
#  '55894': 'P81534',
#  '124906744': 'P81534',
#  '245910': 'Q8IZN7',
#  '503614': 'Q8IZN7',
#  '124906743': 'Q8IZN7',
#  '91746': 'Q96MU7',
#  '2966': 'Q13888',
#  '284415': 'Q6UX27',
#  '10407': 'Q08648',
#  '124906741': 'Q08648',
#  '503841': 'Q8N104',
#  '124906749': 'Q8N104',
#  '29': 'Q12979',
#  '6203': 'P46781',
#  '1815': 'P21917',
#  '353514': 'A6NI73',
#  '126014': 'Q8IYS5',
#  '4696': 'O95167',
#  '57657': 'Q9P1Z3',
#  '29928': 'Q9Y584',
#  '29844': 'P0C1Z6',
#  '8293': 'O75920',
#  '728492': 'O75920',
#  '55655': 'Q9NX02',
#  '9172': 'P54296',
#  '4340': 'Q16653',
#  '3665': 'Q92985',
#  '10712': 'P81408',
#  '9437': 'O76036',
#  '11026': 'Q8N6C8',
#  '9920': 'O94819',
#  '26707': 'O76002',
#  '3265': 'P01112',
#  '3135': 'P17693',
#  '388021': 'Q6ZVK1',
#  '8045': 'Q02833',
#  '3813': 'Q14943',
#  '11027': 'Q8N149',
#  '343068': 'Q5TYX0',
#  '3304': 'P0DMV9',
#  '400258': 'Q8N912',
#  '391002': 'Q5VWM4',
#  '441873': 'A6NGN4',
#  '645359': 'A6NGN4',
#  '1519': 'P43234',
#  '9639': 'O15013',
#  '6999': 'P48775',
#  '10990': 'O75023',
#  '8764': 'Q92956',
#  '57189': 'A4D1U4',
#  '6343': 'P09683',
#  '3904': 'Q6ISS4',
#  '100287898': 'A8MYJ7',
#  '1089': 'O75871',
#  '90273': 'Q3KPI0',
#  '163223': 'Q8N7Q3',
#  '6742': 'Q04837',
#  '10859': 'Q8NHL6',
#  '79258': 'Q495T6',
#  '55750': 'Q53H12',
#  '494551': 'P0C1S8',
#  '4671': 'Q13075',
#  '440073': 'Q9UPP2',
#  '55229': 'Q9NVE7',
#  '2550': 'Q9UBS5',
#  '22932': 'Q6PJE2',
#  '50945': 'Q9Y458',
#  '79168': 'Q6PI73',
#  '6880': 'Q16594',
#  '81696': 'Q9UGF6',
#  '105375355': 'Q9BT76',
#  '9651': 'O75038',
#  '259215': 'Q5SQ64',
#  '170679': 'Q9UIG5',
#  '388585': 'Q5TA89',
#  '3112': 'P13765',
#  '91419': 'Q9Y6H3',
#  '7932': 'O95918',
#  '6992': 'O60927',
#  '55937': 'O95445',
#  '4050': 'Q06643',
#  '346171': 'Q9NU63',
#  '259293': 'P59541',
#  '259294': 'P59542',
#  '50836': 'Q9NYW2',
#  '50837': 'Q9NYW3',
#  '259296': 'P59544',
#  '259289': 'P59537',
#  '259291': 'P59537',
#  '50840': 'Q9NYV8',
#  '106707243': 'Q9NYV8',
#  '50835': 'Q9NYW1',
#  '259290': 'P59538',
#  '5698': 'P28065',
#  '50838': 'Q9NYV9',
#  '259292': 'P59540',
#  '259295': 'P59543',
#  '7262': 'Q53GA4',
#  '5554': 'Q16378',
#  '11272': 'Q16378',
#  '2794': 'P36915',
#  '259197': 'O14931',
#  '57348': 'Q9H313',
#  '100293534': 'P0C0L5',
#  '50839': 'Q9NYW0',
#  '28973': 'Q9Y676',
#  '6598': 'Q12824',
#  '11156': 'O75365',
#  '400916': 'Q8WYQ3',
#  '2843': 'Q99678',
#  '321': 'Q99767',
#  '8859': 'P49842',
#  '4320': 'P24347',
#  '11270': 'Q8IXM6',
#  '3122': 'P01903',
#  '91319': 'Q96Q80',
#  '79897': 'Q9H633',
#  '202658': 'Q9H633',
#  '10554': 'Q99943',
#  '283768': 'Q08AF8',
#  '5884': 'O75943',
#  '114823': 'Q96PV6',
#  '653486': 'P0DMR2',
#  '56160': 'Q96MG7',
#  '89870': 'Q9C019',
#  '833': 'P49589',
#  '7920': 'O95870',
#  '27164': 'Q9BXA9',
#  '5514': 'Q96QC0',
#  '9501': 'Q9UNE2',
#  '4758': 'Q99519',
#  '222236': 'Q6IQ20',
#  '9824': 'Q6P4F7',
#  '1022': 'P50613',
#  '80863': 'Q99946',
#  '100507547': 'Q99946',
#  '66035': 'Q9BYW1',
#  '401250': 'P59942',
#  '23532': 'P78395',
#  '442194': 'Q96KK4',
#  '3120': 'P05538',
#  '80741': 'Q5SRR4',
#  '3303': 'P0DMV8',
#  '170954': 'Q6NYC8',
#  '107987457': 'Q6NYC8',
#  '3305': 'P34931',
#  '9560': 'Q8NHW4',
#  '63940': 'Q9Y4H4',
#  '116511': 'P35410',
#  '401251': 'Q5SSQ6',
#  '57819': 'Q9Y333',
#  '26529': 'P58182',
#  '148170': 'Q6NZY7',
#  '7473': 'P56703',
#  '101929777': 'P56703',
#  '717': 'P06681',
#  '56658': 'Q9HCM9',
#  '4282': 'P14174',
#  '6890': 'Q03518',
#  '102724862': 'A0A087WXS9',
#  '8705': 'O96024',
#  '5816': 'P20472',
#  '653689': 'P0CG30',
#  '6349': 'P16619',
#  '414062': 'P16619',
#  '127124': 'Q96LB4',
#  '11024': 'O75019',
#  '79969': 'Q5SQI0',
#  '56244': 'Q9UIR0',
#  '1652': 'P30046',
#  '6362': 'P55774',
#  '6257': 'P28702',
#  '4676': 'Q99733',
#  '388372': 'Q8NHW4',
#  '94059': 'Q96B70',
#  '2953': 'P0CG29',
#  '170680': 'Q9UIG4',
#  '201176': 'Q6ZUM4',
#  '2952': 'P30711',
#  '220972': 'Q5T0T0',
#  '7407': 'P26640',
#  '79290': 'Q8NGR1',
#  '8578': 'Q14162',
#  '7082': 'Q07157',
#  '3126': 'P13762',
#  '7484': 'O14905',
#  '653073': 'A6NMD2',
#  '26585': 'O60565',
#  '5788': 'P08575',
#  '6048': 'Q99942',
#  '6348': 'P10147',
#  '4049': 'P01374',
#  '727910': 'A6NGC4',
#  '129807': 'Q8WWR8',
#  '1192': 'O00299',
#  '6351': 'P13236',
#  '26716': 'Q9GZK4',
#  '240': 'P09917',
#  '22909': 'Q9Y2M0',
#  '4905': 'P46459',
#  '6447': 'P05408',
#  '54893': 'Q9NXD2',
#  '51621': 'Q9Y2Y9',
#  '10665': 'Q5SRN2',
#  '9842': 'Q9Y4G2',
#  '30834': 'Q9P1U0',
#  '81797': 'Q9UGF7',
#  '285093': 'Q14D33',
#  '124997': 'Q562E7',
#  '5133': 'Q15116',
#  '90987': 'Q9BRH9',
#  '79792': 'P57764',
#  '80864': 'Q99944',
#  '160728': 'Q8N695',
#  '23564': 'O95865',
#  '121601': 'Q32M45',
#  '4439': 'O43196',
#  '730394': 'Q6P1K8',
#  '203068': 'P07437',
#  '26121': 'Q8WWY3',
#  '7531': 'P62258',
#  '65263': 'Q53H96',
#  '6015': 'Q06587',
#  '153562': 'Q8N4S9',
#  '124935': 'Q8N370',
#  '3109': 'P28068',
#  '26496': 'P58181',
#  '120065': 'Q8WZ92',
#  '120066': 'Q8WZ94',
#  '390093': 'Q8NH74',
#  '23543': 'O43251',
#  '135644': 'Q6P9F5',
#  '338322': 'Q86W26',
#  '51206': 'Q9HCN6',
#  '80740': 'O95867',
#  '83547': 'Q96NA2',
#  '6046': 'P25440',
#  '5696': 'P28062',
#  '55814': 'A6H8Y1',
#  '123036': 'Q8N9U0',
#  '51596': 'O60888',
#  '1394': 'P34998',
#  '104909134': 'P34998',
#  '102723407': 'P0DP08',
#  '80737': 'Q9Y334',
#  '7726': 'Q12899',
#  '79820': 'Q9H7T0',
#  '11074': 'Q9BZY9',
#  '9656': 'Q14676',
#  '202243': 'Q86Z20',
#  '51326': 'Q8IVW1',
#  '100506084': 'Q8IVW1',
#  '100996709': 'Q8IVW1',
#  '10594': 'Q6P2Q9',
#  '102157402': 'Q9Y3D8',
#  '570': 'Q14032',
#  '54886': 'Q8TBJ4',
#  '140691': 'Q86WT6',
#  '8449': 'O60231',
#  '2968': 'Q92759',
#  '5345': 'P08697',
#  '567': 'P61769',
#  '3115': 'P04440',
#  '2055': 'Q9UBY8',
#  '92259': 'P82909',
#  '55780': 'Q5T6L9',
#  '9374': 'Q9UMR5',
#  '101928108': 'H3BQJ8',
#  '6991': 'Q8IZS6',
#  '10471': 'O15212',
#  '3108': 'P28067',
#  '11025': 'O75022',
#  '102725035': 'O75022',
#  '107987425': 'O75022',
#  '107987462': 'O75022',
#  '4062': 'O94772',
#  '1936': 'P29692',
#  '29113': 'Q6UXA7',
#  '6222': 'P62269',
#  '4137': 'P10636',
#  '566': 'P20160',
#  '5657': 'P24158',
#  '135927': 'Q96L11',
#  '4061': 'Q16553',
#  '8870': 'P46695',
#  '1991': 'P08246',
#  '5645': 'P07478',
#  '84662': 'Q9BZE0',
#  '1675': 'P00746',
#  '114990': 'Q6EMK4',
#  '5644': 'P07477',
#  '23420': 'Q15155',
#  '346517': 'Q8N148',
#  '199': 'P55008',
#  '93432': 'Q2M2H8',
#  '3111': 'P06340',
#  '135924': 'Q8NGT5',
#  '225689': 'Q8TD08',
#  '57407': 'Q9HBL8',
#  '9859': 'Q5SW79',
#  '645455': 'Q5SW79',
#  '286077': 'Q6ZRV2',
#  '1066': 'P23141',
#  '122258': 'Q96KW9',
#  '54700': 'Q9NYV6',
#  '145270': 'Q86XR5',
#  '6368': 'P55773',
#  '7264': 'Q13630',
#  '7148': 'P22105',
#  '3429': 'P40305',
#  '10919': 'Q96KQ7',
#  '10000': 'Q9Y243',
#  '3133': 'P13747',
#  '6360': 'O15467',
#  '57718': 'Q6NUP7',
#  '136541': 'Q8IYP2',
#  '629': 'P00751',
#  '64112': 'Q96BY2',
#  '26175': 'Q8N6I4',
#  '58496': 'Q8NDX9',
#  '5073': 'O95453',
#  '10806': 'Q86SQ7',
#  '866': 'P08185',
#  '80736': 'Q53GD3',
#  '1460': 'P67870',
#  '11056': 'Q9Y2R4',
#  '3113': 'P20036',
#  '3881': 'Q15323',
#  '4795': 'Q9UBC1',
#  '7917': 'P46379',
#  '3883': 'O76009',
#  '8399': 'O15496',
#  '8688': 'O76014',
#  '100505753': 'A8MUX0',
#  '55727': 'Q9P203',
#  '83902': 'Q9BYP8',
#  '3163': 'P30519',
#  '3884': 'Q14525',
#  '7922': 'Q92504',
#  '122509': 'Q96BM0',
#  '3792': 'P23276',
#  '7124': 'P01375',
#  '63943': 'Q9UIM3',
#  '57151': 'O75951',
#  '80742': 'P79522',
#  '51025': 'Q9Y3D7',
#  '84311': 'Q9BRJ2',
#  '9081': 'O14603',
#  '124908884': 'O14603',
#  '10537': 'O15205',
#  '22827': 'Q9UHX1',
#  '123811': 'Q96NB1',
#  '23': 'Q8NE71',
#  '9093': 'Q96EY1',
#  '93100': 'Q6XQN6',
#  '8287': 'O00507',
#  '64595': 'O00507',
#  '57578': 'Q9P2D8',
#  '100130274': 'P0CW27',
#  '448831': 'Q64ET8',
#  '442862': 'O14603',
#  '80739': 'O95866',
#  '51156': 'Q9UK55',
#  '2483': 'Q14331',
#  '9086': 'O14602',
#  '5796': 'Q15262',
#  '177': 'Q15109',
#  '9083': 'O14599',
#  '29965': 'Q9H305',
#  '55148': 'Q8N806',
#  '387357': 'Q8N1K5',
#  '286075': 'Q96C28',
#  '101928160': 'Q96C28',
#  '51676': 'Q96Q27',
#  '100289087': 'P0CW01',
#  '124905630': 'P0CW01',
#  '124909093': 'P0CW01',
#  '4855': 'Q99466',
#  '84948': 'Q53EQ6',
#  '9831': 'O75123',
#  '7258': 'Q01534',
#  '124909015': 'Q01534',
#  '124909084': 'Q01534',
#  '642475': 'A6NGR9',
#  '54535': 'Q8TD31',
#  '81037': 'Q96KA5',
#  '6891': 'Q03519',
#  '378949': 'P0C7P1',
#  '3705': 'Q13572',
#  '2515': 'Q99965',
#  '159119': 'Q96LI6',
#  '23042': 'Q6P996',
#  '124900586': 'Q6P996',
#  '78990': 'Q96DC9',
#  '90050': 'Q8N9Y4',
#  '341947': 'Q7Z4L0',
#  '83982': 'Q9H2X8',
#  '11006': 'Q8NHJ6',
#  '79585': 'P57737',
#  '3833': 'Q9BW19',
#  '6531': 'Q01959',
#  '1113': 'P10645',
#  '5089': 'P40425',
#  '57062': 'Q9GZR7',
#  '84520': 'Q9BXV9',
#  '368': 'O95255',
#  '255027': 'Q2QL34',
#  '203102': 'Q8TC27',
#  '3134': 'P30511',
#  '123803': 'Q96AB6',
#  '8284': 'Q9BY66',
#  '86614': 'Q96LI6',
#  '90655': 'Q8IUE0',
#  '1302': 'P13942',
#  '8749': 'Q9Y3Q7',
#  '31': 'Q13085',
#  '89927': 'Q96MC5',
#  '221545': 'Q5SQH8',
#  '159163': 'Q15415',
#  '9426': 'Q9Y6F7',
#  '3118': 'P01906',
#  '51283': 'Q9NZS9',
#  '6499': 'Q15477',
#  '442868': 'O14599',
#  '54820': 'Q9NXR1',
#  '353274': 'P59923',
#  '285346': 'Q6ZMS4',
#  '9665': 'Q9Y4F3',
#  '80179': 'Q96H55',
#  '6293': 'Q8N1B4',
#  '5863': 'O15211',
#  '55888': 'Q9P0L1',
#  '57135': 'Q86SG3',
#  '285349': 'Q6AZW8',
#  '7703': 'P35227',
#  '203611': 'Q9Y6F7',
#  '6736': 'Q05066',
#  '6192': 'P22090',
#  '389376': 'Q6UW10',
#  '10211': 'O75955',
#  '4363': 'P33527',
#  '10168': 'O14709',
#  '110354863': 'O14709',
#  '7544': 'P08048',
#  '4302': 'P55198',
#  '7918': 'O95872',
#  '7584': 'P13682',
#  '1388': 'Q99941',
#  '7936': 'P18615',
#  '6892': 'O15533',
#  '91392': 'Q8TBZ5',
#  '9326': 'Q15649',
#  '221527': 'Q9Y330',
#  '8653': 'O15523',
#  '115560': 'Q96CX3',
#  '57456': 'Q96AT1',
#  '6871': 'O75478',
#  '79922': 'Q6IN84',
#  '408050': 'P69849',
#  '79893': 'Q9H3C7',
#  '6359': 'Q16663',
#  '56992': 'Q9NS87',
#  '8396': 'P78356',
#  '131616': 'Q69YG0',
#  '26574': 'Q9NY61',
#  '7047': 'P49221',
#  '729877': 'P0C7X1',
#  '388381': 'A8MV24',
#  '7404': 'O14607',
#  '30837': 'O14512',
#  '100170841': 'A6NHQ4',
#  '9087': 'O14604',
#  '9084': 'O14598',
#  '57054': 'Q9NR90',
#  '6566': 'P53985',
#  '1617': 'Q9NQZ3',
#  '201299': 'Q8NG50',
#  '266': 'Q99218',
#  '90665': 'Q9BQ87',
#  '57827': 'O95873',
#  '256957': 'A2RTY3',
#  '283150': 'Q6PIV2',
#  '57055': 'Q13117',
#  '4629': 'P35749',
#  '338657': 'Q86UT8',
#  '64591': 'A6NKD2',
#  '6928': 'P35680',
#  '728403': 'P0CW00',
#  '284098': 'Q7Z7B1',
#  '6230': 'P62851',
#  '6352': 'P13501',
#  '728137': 'P0CV98',
#  '7919': 'Q13838',
#  '1616': 'Q9UER7',
#  '3635': 'Q92835',
#  '80725': 'Q9C0H9',
#  '51399': 'Q9Y296',
#  '378950': 'A6NEQ0',
#  '1041': 'Q15517',
#  '2542': 'O43826',
#  '11072': 'O95147',
#  '7923': 'Q92506',
#  '440435': 'Q6PRD1',
#  '22829': 'Q8NFZ3',
#  '284106': 'P0C7P0',
#  '3975': 'P48742',
#  '58530': 'O95868',
#  '110599563': 'O95868',
#  '353513': 'O14598',
#  '140032': 'Q8TD47',
#  '83259': 'Q9BZA8',
#  '253175': 'Q9Y6F8',
#  '442867': 'O14599',
#  '5252': 'O43189',
#  '55054': 'Q676U5',
#  '534': 'O95670',
#  '9085': 'Q9Y6F8',
#  '7916': 'P48634',
#  '728395': 'P0CV99',
#  '124905612': 'P0CV99',
#  '124905613': 'P0CV99',
#  '124909159': 'P0CV99',
#  '124909293': 'P0CV99',
#  '124909305': 'P0CV99',
#  '124909329': 'P0CV99',
#  '10525': 'Q9Y4L1',
#  '378951': 'Q15415',
#  '728132': 'A0A494C1R9',
#  '124909317': 'A0A494C1R9',
#  '124909332': 'A0A494C1R9',
#  '29989': 'Q9NPH6',
#  '5460': 'Q01860',
#  '378948': 'A6NDE4',
#  '11276': 'Q9UMZ2',
#  '6838': 'O75683',
#  '5940': 'P0DJD3',
#  '6295': 'P10523',
#  '6837': 'Q15528',
#  '54883': 'Q9NXE8',
#  '284099': 'Q8N4C9',
#  '6358': 'Q16627',
#  '6130': 'P62424',
#  '720': 'P0C0L4',
#  '110384692': 'P0C0L4',
#  '79148': 'Q9H239',
#  '605': 'Q4VC05',
#  '22877': 'Q9HAP2',
#  '6834': 'Q15526',
#  '8527': 'Q16760',
#  '6836': 'O15260',
#  '8148': 'Q92804',
#  '1797': 'O77932',
#  '79370': 'Q9BZR8',
#  '169436': 'Q8NE28',
#  '100507747': 'A0A1B0GUA9',
#  '57109': 'Q9GZR2',
#  '79154': 'Q6UWP2',
#  '22821': 'Q14644',
#  '3125': 'P79483',
#  '57636': 'Q9P227',
#  '4040': 'O75581',
#  '54682': 'Q9H8J5',
#  '9278': 'O15209',
#  '118426': 'Q969J3',
#  '721': 'P0C0L5',
#  '80824': 'Q9BY84',
#  '5691': 'P49720',
#  '440560': 'O60813',
#  '343069': 'O60812',
#  '11093': 'Q76LX8',
#  '65122': 'O60811',
#  '400735': 'O60810',
#  '1589': 'P08686',
#  '343071': 'O60809',
#  '441871': 'Q5VXH5',
#  '440561': 'Q5VXH4',
#  '11094': 'Q9UGQ2',
#  '101929983': 'A3QJZ7',
#  '649330': 'B7ZW38',
#  '56256': 'Q9NUC0',
#  '440563': 'B2RXH8',
#  '101060301': 'P0DMR1',
#  '400736': 'Q5VWM6',
#  '391003': 'Q5VWM3',
#  '11182': 'Q9UGQ3',
#  '55733': 'Q5VTY9',
#  '645382': 'A0A0G2JMD5',
#  '780': 'Q08345',
#  '9277': 'O15213',
#  '3119': 'P01920',
#  '10236': 'O43390',
#  '6905': 'Q15813',
#  '80818': 'Q9C0F3',
#  '148789': 'Q8NCR0',
#  '653075': 'H3BQL2',
#  '2786': 'P50150',
#  '6920': 'O75764',
#  '57176': 'Q5ST30',
#  '55616': 'Q8TDY4',
#  '23522': 'Q8WYB5',
#  '143': 'Q9UKK3',
#  '4285': 'Q99797',
#  '342900': 'A8MZ59',
#  '1870': 'Q14209',
#  '338599': 'Q68J44',
#  '84056': 'Q9BW62',
#  '3399': 'Q02535',
#  '171222': 'A0A1B0GUS4',
#  '8900': 'P78396',
#  '9149': 'Q9Y463',
#  '10208': 'Q5W0Q7',
#  '646625': 'A6NGE7',
#  '3146': 'P09429',
#  '221504': 'Q96C00',
#  '2091': 'P22087',
#  '54937': 'Q9NX45',
#  '5651': 'P98073',
#  '8857': 'Q9Y6R7',
#  '55425': 'Q8IXQ4',
#  '5704': 'P43686',
#  '26747': 'Q9UHK0',
#  '25998': 'Q9P2D0',
#  '1525': 'P78310',
#  '339327': 'Q86UE3',
#  '3839': 'O00505',
#  '51084': 'Q9Y2S2',
#  '163131': 'Q9Y6R6',
#  '10069': 'P57060',
#  '7162': 'Q13641',
#  '1045': 'Q99626',
#  '84896': 'Q8NBU5',
#  '100144748': 'B2CW77',
#  '255967': 'Q58A45',
#  '284323': 'O75290',
#  '1447': 'P05814',
#  '6779': 'P02808',
#  '81617': 'Q9H9S4',
#  '3347': 'P15516',
#  '56911': 'P57077',
#  '3346': 'P15515',
#  '9811': 'O43310',
#  '10166': 'Q9Y619',
#  '29103': 'Q9Y5T4',
#  '2835': 'P47775',
#  '401137': 'Q6MZM9',
#  '2963': 'P13984',
#  '54891': 'Q53TQ3',
#  '10810': 'Q9UPY6',
#  '9875': 'O60287',
#  '100131902': 'Q3LHN0',
#  '58494': 'P57087',
#  '10600': 'Q9Y5T5',
#  '54768': 'Q4G0P3',
#  '26285': 'P56750',
#  '25834': 'Q9UBM8',
#  '116159': 'Q96J86',
#  '64968': 'P82932',
#  '643803': 'Q3LI83',
#  '9223': 'Q96QZ7',
#  '4719': 'P28331',
#  '10942': 'Q9Y6M0',
#  '794': 'P22676',
#  '8208': 'Q13112',
#  '10631': 'Q15063',
#  '49': 'P10323',
#  '124220': 'Q96DA0',
#  '1933': 'P24534',
#  '64063': 'Q9GZN4',
#  '387923': 'Q8N6R1',
#  '115286': 'Q70HW3',
#  '2825': 'P46091',
#  '57683': 'Q9HCK1',
#  '442185': 'Q9GZK6',
#  '57466': 'O95104',
#  '22862': 'Q9Y2H6',
#  '23228': 'Q9UPR0',
#  '8831': 'Q96PV0',
#  '10186': 'Q9Y693',
#  '11215': 'Q9UKA4',
#  '79024': 'Q9BVW6',
#  '440145': 'Q08AG7',
#  '10694': 'P50990',
#  '80209': 'Q86XN7',
#  '4685': 'O15394',
#  '5577': 'P31323',
#  '29957': 'Q6NUK1',
#  '220081': 'Q5W0A0',
#  '26959': 'O60381',
#  '10464': 'Q8WXW3',
#  '26046': 'O94822',
#  '100507436': 'Q29983',
#  '79866': 'Q6PGQ7',
#  '54798': 'Q6V1P9',
#  '57626': 'Q9NR64',
#  '9509': 'O95450',
#  '2845': 'Q99680',
#  '2971': 'Q92664',
#  '11184': 'Q92918',
#  '11062': 'O95620',
#  '55973': 'Q9UHQ4',
#  '1997': 'P32519',
#  '80230': 'Q96T51',
#  '3187': 'P31943',
#  '646019': 'A6NI87',
#  '27335': 'Q9UBQ5',
#  '400566': 'Q6ZQX7',
#  '351': 'P05067',
#  '150160': 'Q96SF2',
#  '8796': 'O95171',
#  '57154': 'Q9HCE7',
#  '8848': 'Q15714',
#  '402569': 'A9QM74',
#  '81': 'O43707',
#  '9073': 'P56748',
#  '101928147': 'B9A014',
#  '102723451': 'B9A014',
#  '3963': 'P47929',
#  '653499': 'P47929',
#  '821': 'P27824',
#  '341640': 'Q5SZK8',
#  '729233': 'P86481',
#  '30811': 'P57058',
#  '3960': 'P56470',
#  '9794': 'Q92585',
#  '5789': 'P23468',
#  '54149': 'Q9NYK6',
#  '9882': 'O60343',
#  '4056': 'Q16873',
#  '1891': 'Q13011',
#  '729246': 'P86480',
#  '10253': 'O43597',
#  '8218': 'P53675',
#  '729250': 'P86478',
#  '55275': 'Q5VIR6',
#  '23515': 'Q14149',
#  '51569': 'P61960',
#  '688': 'Q13887',
#  '220082': 'Q8NA61',
#  '11282': 'Q9UQ53',
#  '3191': 'P14866',
#  '81035': 'Q5KU26',
#  '23483': 'O95455',
#  '126432': 'Q6ZS11',
#  '57146': 'Q96B96',
#  '3613': 'O14732',
#  '7783': 'Q05996',
#  '257629': 'Q8N8V4',
#  '51586': 'Q96RN5',
#  '51149': 'Q6NTE8',
#  '55718': 'Q9NVU0',
#  '255762': 'Q8IXQ8',
#  '2321': 'P17948',
#  '51108': 'Q9H1A3',
#  '10261': 'O95976',
#  '337867': 'Q8NBM4',
#  '22933': 'Q8IXJ6',
#  '5983': 'P40938',
#  '4793': 'Q15653',
#  '643669': 'I3L3R5',
#  '23061': 'Q66K14',
#  '9229': 'O14490',
#  '1638': 'P40126',
#  '5457': 'Q01851',
#  '8711': 'Q13470',
#  '9375': 'Q99805',
#  '11031': 'Q13636',
#  '54938': 'Q9NP81',
#  '57048': 'Q9NRY6',
#  '6183': 'O15235',
#  '23762': 'Q969R2',
#  '115290': 'Q96EF6',
#  '4588': 'Q6W4X9',
#  '254863': 'Q8N2U0',
#  '221178': 'Q96N96',
#  '7525': 'P07947',
#  '146': 'P25100',
#  '343637': 'Q2I0M5',
#  '57555': 'Q8NFZ4',
#  '140881': 'Q9H1M3',
#  '374768': 'Q8N4L4',
#  '51378': 'Q9Y264',
#  '201243': 'Q0P670',
#  '8224': 'O14994',
#  '283093': 'Q96R67',
#  '107983988': 'A0A1B0GUW6',
#  '284114': 'Q8N9M5',
#  '4586': 'P98088',
#  '387921': 'Q5JS37',
#  '55423': 'Q9P1W8',
#  '10562': 'Q6UX06',
#  '122183': 'P86496',
#  '149840': 'Q8IYI0',
#  '2256': 'Q92914',
#  '5008': 'P13725',
#  '56255': 'Q9H1E5',
#  '10982': 'Q15555',
#  '128710': 'Q5VYV7',
#  '245938': 'Q8N687',
#  '4821': 'O95096',
#  '650': 'P12643',
#  '4733': 'Q9Y295',
#  '1140': 'P11230',
#  '57565': 'Q9P2G3',
#  '5173': 'P01213',
#  '57659': 'Q9P1Z0',
#  '83541': 'Q9BQ89',
#  '150280': 'Q8N7B1',
#  '643664': 'P0C7Q6',
#  '3642': 'Q01101',
#  '245939': 'Q7Z7B8',
#  '3810': 'Q14953',
#  '25793': 'Q9Y3I1',
#  '81623': 'Q9BYW3',
#  '3843': 'O00410',
#  '22903': 'Q9Y2F9',
#  '3996': 'Q15334',
#  '4729': 'P19404',
#  '644524': 'Q9H2Z4',
#  '4689': 'Q15080',
#  '29058': 'Q96A57',
#  '5126': 'P16519',
#  '394263': 'Q5SSG8',
#  '2314': 'Q13045',
#  '79175': 'Q6P1L6',
#  '10047': 'O60676',
#  '140862': 'B1AKI9',
#  ...}

# %% [markdown]
# # Map validation data sets to eggNOG IDs

# %%
from itertools import combinations
import pandas as pd
import re
import time
import numpy as np
from sklearn.metrics import log_loss

# %%
def map_ids(x, d):
    try:
        new_id = d[x]
        return(new_id)
    except:
        return(x)
    
def logloss(true_label, predicted, eps=1e-15):
    p = np.clip(predicted, eps, 1 - eps)
    if true_label == 1:
        return -np.log(p)
    else:
        return -np.log(1 - p)
    
def loglike(true_label, predicted, eps=1e-15):
    p = np.clip(predicted, eps, 1 - eps)
    if true_label == 1:
        return(np.log(p))
    else:
        return(np.log(1 - p))

# %%
# my data
leca_file = '../ppi_ml/results/ppi_predict/feature_sweep/100/scored_interactions_all_LinearSVC.csv'
leca_nogs_file = '../ppi_ml/annotations/lists/leca_nogs.txt'

# external data
xlms_file = '../ppi_ml/data/validation/bartolec_xlms_human.csv'
y2h_file = '../ppi_ml/data/validation/luck_HuRI_y2h_pairs.tsv'
cx_file = '../ppi_ml/data/validation/kim_hn3_coexp.tsv'

# %%
xlms = pd.read_csv(xlms_file)
xlms = xlms[xlms['URP Type'] == 'Inter']
xlms = xlms[['Protein1','Protein2','Total number of URPs','Total number of CSMs']]
xlms['ID1'] = [map_ids(i, og_dict) for i in xlms['Protein1']]
xlms['ID2'] = [map_ids(i, og_dict) for i in xlms['Protein2']]
xlms
# Out:
#         Protein1 Protein2  Total number of URPs  Total number of CSMs  \
# 1         Q9Y5J9   Q9Y5L4                     2                     4
# 2         Q9Y3U8   Q9Y676                     1                     1
# 3         Q9Y399   Q9Y3D9                     1                     2
# 4         Q9Y2Q9   Q9Y399                     1                     2
# 5         Q9Y2Q9   Q9Y3D9                     2                     3
# ...          ...      ...                   ...                   ...
# 2105      A1L167   P50914                     1                     1
# 2106      A0FGR8   Q9BSJ8                     1                     1
# 2107  A0A1B0GUW6   Q9UM21                     1                     1
# 2108  A0A0B4J271   P13667                     1                     1
# 2109  A0A087WUL8   P14625                     1                     1
#
#               ID1          ID2
# 1         KOG3489      KOG1733
# 2         KOG3452      KOG4021
# 3         KOG0832  ENOG502RZIC
# 4         KOG4078      KOG0832
# 5         KOG4078  ENOG502RZIC
# ...           ...          ...
# 2105      KOG0897      KOG3421
# 2106      KOG1012      KOG1012
# 2107  ENOG502TDYW  ENOG502QPQJ
# 2108  ENOG502SVXB      KOG0190
# 2109  ENOG502RU1I      KOG0020
#
# [2026 rows x 6 columns]

# %%
y2h = pd.read_csv(y2h_file, sep='\t', header=None, names=['ensembl_1','ensembl_2'])
y2h['ID1'] = [map_ids(map_ids(str(i), ensembl_dict), og_dict) for i in y2h['ensembl_1']]
y2h['ID2'] = [map_ids(map_ids(str(i), ensembl_dict), og_dict) for i in y2h['ensembl_2']]
y2h
# Out:
#              ensembl_1        ensembl_2              ID1              ID2
# 0      ENSG00000000005  ENSG00000061656      ENOG502QPTP          KOG2687
# 1      ENSG00000000005  ENSG00000099968      ENOG502QPTP      ENOG502R6AP
# 2      ENSG00000000005  ENSG00000104765      ENOG502QPTP      ENOG502R8Q5
# 3      ENSG00000000005  ENSG00000105383      ENOG502QPTP      ENOG502S41V
# 4      ENSG00000000005  ENSG00000114455      ENOG502QPTP      ENOG502S3IN
# ...                ...              ...              ...              ...
# 52543  ENSG00000273899  ENSG00000273899          KOG4709          KOG4709
# 52544  ENSG00000275302  ENSG00000278619      ENOG502S8M4          KOG0838
# 52545  ENSG00000275774  ENSG00000275774          KOG0118          KOG0118
# 52546  ENSG00000276070  ENSG00000278619      ENOG502S8M4          KOG0838
# 52547  ENSG00000276076  ENSG00000276076  ENSG00000276076  ENSG00000276076
#
# [52548 rows x 4 columns]

# %%
cx = pd.read_csv(cx_file, sep='\t', header=None, names=['entrez_1','entrez_2','score'])
cx['ID1'] = [map_ids(map_ids(str(i), entrez_dict), og_dict) for i in cx['entrez_1']]
cx['ID2'] = [map_ids(map_ids(str(i), entrez_dict), og_dict) for i in cx['entrez_2']]
cx
# Out:
#        entrez_1  entrez_2     score          ID1          ID2
# 0          6232      7178  4.575464      KOG1779      KOG1727
# 1          1915      7178  4.570955      KOG0052      KOG1727
# 2          6143      6167  4.564302      KOG1696      KOG3475
# 3          6147      6228  4.557484      KOG1751      KOG1749
# 4          6191      6228  4.554408      KOG0378      KOG1749
# ...         ...       ...       ...          ...          ...
# 81059     55032      8195  1.585753      KOG2234      KOG0360
# 81060     10159     51765  1.585749      KOG4737      KOG0201
# 81061     10799      1798  1.585744  ENOG502QSAV      KOG2788
# 81062      4998     55635  1.585742      KOG1514  ENOG502QR00
# 81063    253650      5563  1.585741      KOG0504      KOG0583
#
# [81064 rows x 5 columns]

# %%
leca_nogs = [line.strip() for line in open(leca_nogs_file, 'r')]
leca_nogs = set(leca_nogs)
len(leca_nogs)
# Out:
# 10092

# %%
xlms_fs = [get_leca_pairs(i, j, leca_nogs) for i, j in zip(xlms['ID1'], xlms['ID2'])]
set(xlms_fs)
# Out:
# {frozenset({'KOG1569', 'KOG4607'}),
#  frozenset({'KOG1723', 'KOG3434'}),
#  frozenset({'KOG0327', 'KOG0401'}),
#  frozenset({'KOG1245', 'KOG3048'}),
#  frozenset({'KOG2013', 'KOG2014'}),
#  frozenset({'KOG1769', 'KOG2013'}),
#  frozenset({'KOG3833', 'KOG4380'}),
#  frozenset({'KOG3366', 'KOG3976'}),
#  frozenset({'KOG0318', 'KOG0676'}),
#  frozenset({'KOG0118', 'KOG0127'}),
#  frozenset({'KOG0101', 'KOG0676'}),
#  frozenset({'KOG0319', 'KOG1539'}),
#  frozenset({'KOG1697', 'KOG3291'}),
#  frozenset({'KOG0052', 'KOG1628'}),
#  frozenset({'KOG0446', 'KOG2480'}),
#  frozenset({'KOG1628', 'KOG3273'}),
#  frozenset({'KOG0845', 'KOG1835'}),
#  frozenset({'KOG1494', 'KOG1997'}),
#  frozenset({'KOG0105', 'KOG0106'}),
#  frozenset({'KOG2291', 'KOG3593'}),
#  frozenset({'ENOG502RRRX', 'KOG0488'}),
#  frozenset({'KOG0019', 'KOG1144'}),
#  frozenset({'KOG1708', 'KOG3331'}),
#  frozenset({'KOG3168', 'KOG3172'}),
#  frozenset({'KOG1753', 'KOG3411'}),
#  frozenset({'KOG0829', 'KOG3184'}),
#  frozenset({'KOG2074', 'KOG2179'}),
#  frozenset({'KOG1465', 'KOG2670'}),
#  frozenset({'KOG0329', 'KOG2213'}),
#  frozenset({'KOG1835', 'KOG3091'}),
#  frozenset({'KOG1790', 'KOG3166'}),
#  frozenset({'KOG0857', 'KOG0886'}),
#  frozenset({'KOG0652', 'KOG3129'}),
#  frozenset({'KOG0402', 'KOG4661'}),
#  frozenset({'KOG3172', 'KOG3454'}),
#  frozenset({'KOG1628', 'KOG2309'}),
#  frozenset({'KOG0968', 'KOG4012'}),
#  frozenset({'KOG0878', 'KOG1475'}),
#  frozenset({'KOG0063', 'KOG4256'}),
#  frozenset({'KOG1768', 'KOG2479'}),
#  frozenset({'KOG1696', 'KOG4809'}),
#  frozenset({'KOG0391', 'KOG4776'}),
#  frozenset({'KOG1854', 'KOG4240'}),
#  frozenset({'KOG2945', 'KOG3436'}),
#  frozenset({'KOG0400', 'KOG2409'}),
#  frozenset({'KOG1753', 'KOG3502'}),
#  frozenset({'KOG1037', 'KOG1744'}),
#  frozenset({'KOG0052', 'KOG3295'}),
#  frozenset({'KOG3614', 'KOG4056'}),
#  frozenset({'KOG2235', 'KOG2607'}),
#  frozenset({'KOG1570', 'KOG3295'}),
#  frozenset({'KOG1459', 'KOG2550'}),
#  frozenset({'KOG1845', 'KOG4599'}),
#  frozenset({'KOG0678', 'KOG2826'}),
#  frozenset({'KOG0516', 'KOG1637'}),
#  frozenset({'KOG0651', 'KOG0729'}),
#  frozenset({'KOG0356', 'KOG1792'}),
#  frozenset({'KOG0846', 'KOG4034'}),
#  frozenset({'KOG0516', 'KOG4203'}),
#  frozenset({'KOG2413', 'KOG3518'}),
#  frozenset({'KOG0123', 'KOG1745'}),
#  frozenset({'KOG0891', 'KOG2327'}),
#  frozenset({'KOG2215', 'KOG2344'}),
#  frozenset({'KOG0378', 'KOG1117'}),
#  frozenset({'KOG0019', 'KOG0150'}),
#  frozenset({'KOG0101', 'KOG1375'}),
#  frozenset({'KOG0052', 'KOG1148'}),
#  frozenset({'KOG2700', 'KOG3859'}),
#  frozenset({'KOG3594', 'KOG4203'}),
#  frozenset({'KOG0951', 'KOG4796'}),
#  frozenset({'KOG0173', 'KOG0181'}),
#  frozenset({'KOG2445', 'KOG4460'}),
#  frozenset({'KOG1926', 'KOG3418'}),
#  frozenset({'KOG1696', 'KOG1728'}),
#  frozenset({'KOG1758', 'KOG3495'}),
#  frozenset({'KOG0469', 'KOG4280'}),
#  frozenset({'KOG0052', 'KOG1971'}),
#  frozenset({'KOG1721', 'KOG1887'}),
#  frozenset({'KOG0118', 'KOG1190'}),
#  frozenset({'KOG0328', 'KOG0533'}),
#  frozenset({'KOG0989', 'KOG2035'}),
#  frozenset({'KOG3028', 'KOG3073'}),
#  frozenset({'KOG1687', 'KOG3363'}),
#  frozenset({'KOG0951', 'KOG1795'}),
#  frozenset({'KOG2099', 'KOG4012'}),
#  frozenset({'KOG2669', 'KOG2806'}),
#  frozenset({'KOG1068', 'KOG3013'}),
#  frozenset({'KOG2513', 'KOG2768'}),
#  frozenset({'ENOG502QRKB', 'KOG1694'}),
#  frozenset({'KOG1942', 'KOG2680'}),
#  frozenset({'KOG0154', 'KOG0676'}),
#  frozenset({'KOG1122', 'KOG1744'}),
#  frozenset({'KOG0100', 'KOG4297'}),
#  frozenset({'KOG0531', 'KOG3656'}),
#  frozenset({'KOG1779', 'KOG3320'}),
#  frozenset({'KOG2196', 'KOG4833'}),
#  frozenset({'KOG3300', 'KOG4110'}),
#  frozenset({'KOG1475', 'KOG1714'}),
#  frozenset({'KOG0977', 'KOG4347'}),
#  frozenset({'KOG1744', 'KOG3657'}),
#  frozenset({'KOG0616', 'KOG3510'}),
#  frozenset({'KOG1139', 'KOG2945'}),
#  frozenset({'KOG4012', 'KOG4436'}),
#  frozenset({'KOG3973', 'KOG4380'}),
#  frozenset({'KOG2393', 'KOG2905'}),
#  frozenset({'KOG0346', 'KOG1070'}),
#  frozenset({'KOG2850', 'KOG3083'}),
#  frozenset({'KOG0473', 'KOG2039'}),
#  frozenset({'KOG0131', 'KOG2636'}),
#  frozenset({'KOG1634', 'KOG4012'}),
#  frozenset({'KOG1761', 'KOG3465'}),
#  frozenset({'KOG1475', 'KOG3504'}),
#  frozenset({'KOG3967', 'KOG4012'}),
#  frozenset({'KOG0101', 'KOG0778'}),
#  frozenset({'KOG0386', 'KOG1180'}),
#  frozenset({'KOG0378', 'KOG2318'}),
#  frozenset({'KOG0331', 'KOG3686'}),
#  frozenset({'KOG1376', 'KOG3501'}),
#  frozenset({'KOG0052', 'KOG1745'}),
#  frozenset({'KOG0110', 'KOG2188'}),
#  frozenset({'KOG0473', 'KOG4365'}),
#  frozenset({'KOG1662', 'KOG3686'}),
#  frozenset({'KOG1270', 'KOG3855'}),
#  frozenset({'KOG1425', 'KOG1795'}),
#  frozenset({'KOG2668', 'KOG2669'}),
#  frozenset({'KOG1287', 'KOG4213'}),
#  frozenset({'KOG1745', 'KOG2725'}),
#  frozenset({'KOG0468', 'KOG1795'}),
#  frozenset({'KOG1037', 'KOG3436'}),
#  frozenset({'KOG1350', 'KOG1353'}),
#  frozenset({'KOG3352', 'KOG4782'}),
#  frozenset({'KOG3382', 'KOG3456'}),
#  frozenset({'KOG0995', 'KOG4438'}),
#  frozenset({'KOG0101', 'KOG3717'}),
#  frozenset({'KOG0488', 'KOG4177'}),
#  frozenset({'KOG0101', 'KOG4464'}),
#  frozenset({'KOG0101', 'KOG3974'}),
#  frozenset({'KOG0676', 'KOG2046'}),
#  frozenset({'KOG1037', 'KOG1428'}),
#  frozenset({'KOG1951', 'KOG3237'}),
#  frozenset({'KOG1070', 'KOG3080'}),
#  frozenset({'KOG0115', 'KOG0118'}),
#  frozenset({'KOG0521', 'KOG4012'}),
#  frozenset({'KOG0101', 'KOG4436'}),
#  frozenset({'KOG1968', 'KOG2035'}),
#  frozenset({'ENOG502QQ7T', 'KOG3456'}),
#  frozenset({'KOG1562', 'KOG4715'}),
#  frozenset({'KOG0019', 'KOG0161'}),
#  frozenset({'KOG0361', 'KOG1809'}),
#  frozenset({'KOG1475', 'KOG3421'}),
#  frozenset({'KOG0052', 'KOG0452'}),
#  frozenset({'KOG0378', 'KOG3424'}),
#  frozenset({'KOG0002', 'KOG2171'}),
#  frozenset({'KOG1560', 'KOG2479'}),
#  frozenset({'KOG0676', 'KOG1700'}),
#  frozenset({'ENOG502QS9N', 'KOG1456'}),
#  frozenset({'ENOG502QPKK', 'KOG2103'}),
#  frozenset({'KOG2330', 'KOG2636'}),
#  frozenset({'KOG0276', 'KOG0292'}),
#  frozenset({'KOG1774', 'KOG1780'}),
#  frozenset({'KOG0443', 'KOG1412'}),
#  frozenset({'KOG0374', 'KOG3911'}),
#  frozenset({'KOG1272', 'KOG2172'}),
#  frozenset({'KOG0052', 'KOG0886'}),
#  frozenset({'KOG0109', 'KOG1646'}),
#  frozenset({'KOG1628', 'KOG2072'}),
#  frozenset({'KOG1646', 'KOG1722'}),
#  frozenset({'KOG2080', 'KOG3275'}),
#  frozenset({'KOG0657', 'KOG3090'}),
#  frozenset({'KOG1448', 'KOG1737'}),
#  frozenset({'KOG0676', 'KOG0679'}),
#  frozenset({'KOG2584', 'KOG4223'}),
#  frozenset({'KOG0875', 'KOG1685'}),
#  frozenset({'KOG1744', 'KOG2724'}),
#  frozenset({'KOG0285', 'KOG2441'}),
#  frozenset({'KOG0841', 'KOG0892'}),
#  frozenset({'KOG0040', 'KOG1721'}),
#  frozenset({'KOG1745', 'KOG1787'}),
#  frozenset({'KOG3313', 'KOG3478'}),
#  frozenset({'KOG0936', 'KOG1059'}),
#  frozenset({'KOG2748', 'KOG4021'}),
#  frozenset({'KOG1353', 'KOG1531'}),
#  frozenset({'KOG0100', 'KOG1751'}),
#  frozenset({'KOG0123', 'KOG4021'}),
#  frozenset({'KOG0400', 'KOG1696'}),
#  frozenset({'KOG2581', 'KOG3151'}),
#  frozenset({'KOG0985', 'KOG2431'}),
#  frozenset({'KOG0815', 'KOG3421'}),
#  frozenset({'KOG0676', 'KOG4154'}),
#  frozenset({'KOG0118', 'KOG1679'}),
#  frozenset({'KOG0101', 'KOG0660'}),
#  frozenset({'KOG0042', 'KOG1854'}),
#  frozenset({'KOG0646', 'KOG2425'}),
#  frozenset({'KOG0215', 'KOG0261'}),
#  frozenset({'KOG1744', 'KOG3971'}),
#  frozenset({'KOG3181', 'KOG3398'}),
#  frozenset({'KOG0344', 'KOG1070'}),
#  frozenset({'KOG1096', 'KOG2242'}),
#  frozenset({'KOG0397', 'KOG1264'}),
#  frozenset({'KOG0676', 'KOG0678'}),
#  frozenset({'KOG3429', 'KOG3589'}),
#  frozenset({'KOG0478', 'KOG0480'}),
#  frozenset({'KOG0687', 'KOG1463'}),
#  frozenset({'KOG0101', 'KOG4216'}),
#  frozenset({'KOG1373', 'KOG3353'}),
#  frozenset({'KOG0190', 'KOG1215'}),
#  frozenset({'KOG3048', 'KOG3478'}),
#  frozenset({'KOG0526', 'KOG1189'}),
#  frozenset({'KOG0008', 'KOG0522'}),
#  frozenset({'KOG0313', 'KOG2481'}),
#  frozenset({'KOG1745', 'KOG1911'}),
#  frozenset({'KOG0962', 'KOG2310'}),
#  frozenset({'KOG2192', 'KOG2791'}),
#  frozenset({'KOG2603', 'KOG3653'}),
#  frozenset({'KOG0699', 'KOG1744'}),
#  frozenset({'ENOG502QQAB', 'KOG0019'}),
#  frozenset({'KOG0289', 'KOG3531'}),
#  frozenset({'KOG0407', 'KOG2874'}),
#  frozenset({'KOG0052', 'KOG0815'}),
#  frozenset({'KOG0417', 'KOG0896'}),
#  frozenset({'KOG1135', 'KOG1137'}),
#  frozenset({'KOG0101', 'KOG2271'}),
#  frozenset({'KOG0035', 'KOG1210'}),
#  frozenset({'KOG0657', 'KOG2042'}),
#  frozenset({'KOG1721', 'KOG1745'}),
#  frozenset({'KOG1265', 'KOG2220'}),
#  frozenset({'KOG0378', 'KOG1722'}),
#  frozenset({'KOG1475', 'KOG3184'}),
#  frozenset({'KOG1646', 'KOG3320'}),
#  frozenset({'KOG1671', 'KOG3529'}),
#  frozenset({'KOG0397', 'KOG4012'}),
#  frozenset({'KOG0019', 'KOG0930'}),
#  frozenset({'KOG1728', 'KOG3283'}),
#  frozenset({'KOG0034', 'KOG2898'}),
#  frozenset({'KOG2773', 'KOG3117'}),
#  frozenset({'KOG2945', 'KOG3181'}),
#  frozenset({'KOG2889', 'KOG4727'}),
#  frozenset({'KOG0123', 'KOG2400'}),
#  frozenset({'KOG0385', 'KOG1744'}),
#  frozenset({'KOG0386', 'KOG1279'}),
#  frozenset({'KOG1646', 'KOG3681'}),
#  frozenset({'KOG0191', 'KOG2291'}),
#  frozenset({'KOG2326', 'KOG2327'}),
#  frozenset({'KOG0127', 'KOG1646'}),
#  frozenset({'KOG0303', 'KOG0676'}),
#  frozenset({'KOG1732', 'KOG3184'}),
#  frozenset({'KOG3833', 'KOG3973'}),
#  frozenset({'KOG2242', 'KOG2874'}),
#  frozenset({'KOG0328', 'KOG3756'}),
#  frozenset({'KOG0118', 'KOG0516'}),
#  frozenset({'KOG0799', 'KOG1694'}),
#  frozenset({'KOG0101', 'KOG2034'}),
#  frozenset({'KOG0336', 'KOG1728'}),
#  frozenset({'KOG1350', 'KOG3281'}),
#  frozenset({'KOG0846', 'KOG3429'}),
#  frozenset({'KOG1917', 'KOG3534'}),
#  frozenset({'KOG0173', 'KOG0185'}),
#  frozenset({'KOG0780', 'KOG1751'}),
#  frozenset({'KOG1233', 'KOG3730'}),
#  frozenset({'KOG0526', 'KOG1745'}),
#  frozenset({'KOG2945', 'KOG3166'}),
#  frozenset({'KOG0262', 'KOG2265'}),
#  frozenset({'KOG2637', 'KOG3181'}),
#  frozenset({'KOG0080', 'KOG1745'}),
#  frozenset({'KOG0396', 'KOG2817'}),
#  frozenset({'KOG0931', 'KOG1626'}),
#  frozenset({'KOG0384', 'KOG0397'}),
#  frozenset({'KOG3313', 'KOG4098'}),
#  frozenset({'KOG0101', 'KOG0864'}),
#  frozenset({'KOG0019', 'KOG0521'}),
#  frozenset({'KOG0676', 'KOG4229'}),
#  frozenset({'KOG0019', 'KOG3592'}),
#  frozenset({'KOG1539', 'KOG2055'}),
#  frozenset({'KOG0003', 'KOG0517'}),
#  frozenset({'KOG1515', 'KOG3217'}),
#  frozenset({'KOG1490', 'KOG1696'}),
#  frozenset({'KOG0027', 'KOG2945'}),
#  frozenset({'KOG0740', 'KOG2623'}),
#  frozenset({'KOG0954', 'KOG2747'}),
#  frozenset({'ENOG502QPM4', 'KOG0329'}),
#  frozenset({'KOG0407', 'KOG1767'}),
#  frozenset({'KOG0900', 'KOG2039'}),
#  frozenset({'KOG0727', 'KOG1556'}),
#  frozenset({'KOG3366', 'KOG4634'}),
#  frozenset({'KOG0101', 'KOG0504'}),
#  frozenset({'KOG0118', 'KOG4817'}),
#  frozenset({'KOG2039', 'KOG3181'}),
#  frozenset({'KOG2870', 'KOG3877'}),
#  frozenset({'KOG3452', 'KOG4021'}),
#  frozenset({'KOG1495', 'KOG1721'}),
#  frozenset({'KOG1596', 'KOG3237'}),
#  frozenset({'KOG0877', 'KOG3486'}),
#  frozenset({'KOG0505', 'KOG2242'}),
#  frozenset({'KOG0829', 'KOG1475'}),
#  frozenset({'KOG2036', 'KOG2773'}),
#  frozenset({'KOG0677', 'KOG3155'}),
#  frozenset({'KOG2944', 'KOG4155'}),
#  frozenset({'KOG1757', 'KOG4286'}),
#  frozenset({'KOG0236', 'KOG2326'}),
#  frozenset({'KOG2510', 'KOG2570'}),
#  frozenset({'KOG0118', 'KOG0331'}),
#  frozenset({'KOG0019', 'KOG0102'}),
#  frozenset({'KOG1156', 'KOG1265'}),
#  frozenset({'KOG1215', 'KOG3502'}),
#  frozenset({'KOG0413', 'KOG3436'}),
#  frozenset({'KOG0466', 'KOG2916'}),
#  frozenset({'KOG0052', 'KOG3166'}),
#  frozenset({'KOG0626', 'KOG2043'}),
#  frozenset({'KOG1757', 'KOG2633'}),
#  frozenset({'KOG0292', 'KOG2635'}),
#  frozenset({'KOG0102', 'KOG1567'}),
#  frozenset({'KOG0187', 'KOG0830'}),
#  frozenset({'KOG0815', 'KOG3449'}),
#  frozenset({'KOG0012', 'KOG1756'}),
#  frozenset({'KOG0460', 'KOG3902'}),
#  frozenset({'KOG0101', 'KOG1721'}),
#  frozenset({'KOG2039', 'KOG4600'}),
#  frozenset({'KOG0050', 'KOG2047'}),
#  frozenset({'KOG1343', 'KOG1358'}),
#  frozenset({'KOG0031', 'KOG0356'}),
#  frozenset({'KOG0946', 'KOG3595'}),
#  frozenset({'KOG0349', 'KOG3833'}),
#  frozenset({'KOG1756', 'KOG4012'}),
#  frozenset({'KOG0003', 'KOG1745'}),
#  frozenset({'KOG0118', 'KOG2242'}),
#  frozenset({'KOG0018', 'KOG0964'}),
#  frozenset({'KOG2206', 'KOG4835'}),
#  frozenset({'KOG2147', 'KOG3073'}),
#  frozenset({'KOG0357', 'KOG0358'}),
#  frozenset({'KOG0052', 'KOG0878'}),
#  frozenset({'KOG0190', 'KOG0575'}),
#  frozenset({'KOG2403', 'KOG4075'}),
#  frozenset({'KOG0019', 'KOG1245'}),
#  frozenset({'KOG2945', 'KOG3502'}),
#  frozenset({'KOG0890', 'KOG3090'}),
#  frozenset({'KOG1827', 'KOG4657'}),
#  frozenset({'KOG1694', 'KOG3421'}),
#  frozenset({'KOG0052', 'KOG1727'}),
#  frozenset({'KOG0414', 'KOG1694'}),
#  frozenset({'ENOG502QS75', 'KOG4607'}),
#  frozenset({'KOG0651', 'KOG0728'}),
#  frozenset({'KOG1490', 'KOG1723'}),
#  frozenset({'KOG0659', 'KOG1769'}),
#  frozenset({'KOG2240', 'KOG4012'}),
#  frozenset({'KOG0240', 'KOG1840'}),
#  frozenset({'KOG1915', 'KOG2609'}),
#  frozenset({'KOG2239', 'KOG2240'}),
#  frozenset({'KOG0045', 'KOG1570'}),
#  frozenset({'KOG0003', 'KOG1744'}),
#  frozenset({'KOG1745', 'KOG1756'}),
#  frozenset({'KOG1190', 'KOG1826'}),
#  frozenset({'KOG0478', 'KOG0482'}),
#  frozenset({'KOG2171', 'KOG3504'}),
#  frozenset({'KOG0897', 'KOG3421'}),
#  frozenset({'KOG1255', 'KOG1447'}),
#  frozenset({'KOG1694', 'KOG3418'}),
#  frozenset({'KOG0101', 'KOG0102'}),
#  frozenset({'KOG1596', 'KOG1951'}),
#  frozenset({'KOG0059', 'KOG0977'}),
#  frozenset({'KOG0676', 'KOG1422'}),
#  frozenset({'KOG0331', 'KOG3742'}),
#  frozenset({'KOG0962', 'KOG1863'}),
#  frozenset({'KOG0245', 'KOG1765'}),
#  frozenset({'KOG0337', 'KOG2885'}),
#  frozenset({'KOG1190', 'KOG2192'}),
#  frozenset({'KOG0436', 'KOG0469'}),
#  frozenset({'KOG1722', 'KOG3424'}),
#  frozenset({'KOG1374', 'KOG2001'}),
#  frozenset({'KOG0101', 'KOG0531'}),
#  frozenset({'KOG4162', 'KOG4688'}),
#  frozenset({'KOG0619', 'KOG3452'}),
#  frozenset({'KOG0213', 'KOG2330'}),
#  frozenset({'KOG0331', 'KOG3063'}),
#  frozenset({'KOG1857', 'KOG3358'}),
#  frozenset({'KOG1226', 'KOG3637'}),
#  frozenset({'KOG0951', 'KOG4727'}),
#  frozenset({'KOG0118', 'KOG3100'}),
#  frozenset({'KOG0865', 'KOG2284'}),
#  frozenset({'KOG3257', 'KOG3422'}),
#  frozenset({'KOG0040', 'KOG3371'}),
#  frozenset({'KOG0118', 'KOG3641'}),
#  frozenset({'KOG2291', 'KOG3412'}),
#  frozenset({'KOG1531', 'KOG3495'}),
#  frozenset({'KOG0676', 'KOG3174'}),
#  frozenset({'KOG0004', 'KOG3406'}),
#  frozenset({'KOG1628', 'KOG3181'}),
#  frozenset({'KOG0190', 'KOG2007'}),
#  frozenset({'KOG1690', 'KOG3738'}),
#  frozenset({'KOG1871', 'KOG4236'}),
#  frozenset({'KOG0161', 'KOG3270'}),
#  frozenset({'KOG0730', 'KOG2507'}),
#  frozenset({'KOG1951', 'KOG2036'}),
#  frozenset({'KOG0190', 'KOG1869'}),
#  frozenset({'KOG0130', 'KOG3392'}),
#  frozenset({'KOG0495', 'KOG1795'}),
#  frozenset({'KOG0543', 'KOG2239'}),
#  frozenset({'KOG0173', 'KOG0179'}),
#  frozenset({'KOG3154', 'KOG4012'}),
#  frozenset({'KOG0100', 'KOG0894'}),
#  frozenset({'KOG3365', 'KOG3877'}),
#  frozenset({'KOG1427', 'KOG1744'}),
#  frozenset({'KOG2291', 'KOG2292'}),
#  frozenset({'KOG2853', 'KOG3864'}),
#  frozenset({'KOG2039', 'KOG3301'}),
#  frozenset({'KOG2590', 'KOG3181'}),
#  frozenset({'ENOG502QRKB', 'KOG2274'}),
#  frozenset({'KOG0292', 'KOG1058'}),
#  frozenset({'KOG0052', 'KOG1475'}),
#  frozenset({'KOG2249', 'KOG2963'}),
#  frozenset({'KOG3060', 'KOG3289'}),
#  frozenset({'ENOG502QXWS', 'KOG0356'}),
#  frozenset({'KOG0727', 'KOG2581'}),
#  frozenset({'KOG3418', 'KOG4673'}),
#  frozenset({'KOG1346', 'KOG4012'}),
#  frozenset({'KOG1790', 'KOG2945'}),
#  frozenset({'KOG1644', 'KOG2636'}),
#  frozenset({'KOG2815', 'KOG4691'}),
#  frozenset({'KOG0213', 'KOG3931'}),
#  frozenset({'KOG0184', 'KOG1498'}),
#  frozenset({'KOG1713', 'KOG2870'}),
#  frozenset({'ENOG502QS2Z', 'KOG1721'}),
#  frozenset({'KOG0101', 'KOG1737'}),
#  frozenset({'KOG3464', 'KOG4191'}),
#  frozenset({'KOG1744', 'KOG1913'}),
#  frozenset({'KOG0825', 'KOG3663'}),
#  frozenset({'KOG0020', 'KOG3782'}),
#  frozenset({'KOG0036', 'KOG0101'}),
#  frozenset({'KOG1744', 'KOG3594'}),
#  frozenset({'KOG0063', 'KOG3375'}),
#  frozenset({'KOG0841', 'KOG4280'}),
#  frozenset({'KOG2945', 'KOG3344'}),
#  frozenset({'KOG0299', 'KOG3117'}),
#  frozenset({'KOG1790', 'KOG2309'}),
#  frozenset({'KOG0123', 'KOG0829'}),
#  frozenset({'ENOG502QQ7X', 'KOG0177'}),
#  frozenset({'KOG2309', 'KOG2945'}),
#  frozenset({'KOG1714', 'KOG1742'}),
#  frozenset({'KOG3392', 'KOG3756'}),
#  frozenset({'KOG0299', 'KOG0378'}),
#  frozenset({'KOG1937', 'KOG2701'}),
#  frozenset({'KOG0356', 'KOG1494'}),
#  frozenset({'KOG2189', 'KOG2670'}),
#  frozenset({'KOG1837', 'KOG2340'}),
#  frozenset({'KOG0357', 'KOG0363'}),
#  frozenset({'KOG2669', 'KOG4098'}),
#  frozenset({'KOG2055', 'KOG4547'}),
#  frozenset({'KOG2988', 'KOG3418'}),
#  frozenset({'KOG1521', 'KOG3497'}),
#  frozenset({'KOG0155', 'KOG1795'}),
#  frozenset({'KOG0030', 'KOG0161'}),
#  frozenset({'KOG0358', 'KOG3431'}),
#  frozenset({'KOG0544', 'KOG0898'}),
#  frozenset({'KOG1767', 'KOG2153'}),
#  frozenset({'KOG4204', 'KOG4466'}),
#  frozenset({'KOG4060', 'KOG4616'}),
#  frozenset({'KOG0342', 'KOG3080'}),
#  frozenset({'KOG0244', 'KOG2593'}),
#  frozenset({'KOG0118', 'KOG0994'}),
#  frozenset({'KOG0650', 'KOG3184'}),
#  frozenset({'KOG0727', 'KOG0728'}),
#  frozenset({'KOG0249', 'KOG3344'}),
#  frozenset({'KOG0830', 'KOG3181'}),
#  frozenset({'KOG0050', 'KOG3096'}),
#  frozenset({'KOG1350', 'KOG3366'}),
#  frozenset({'KOG0018', 'KOG1525'}),
#  frozenset({'KOG0606', 'KOG1866'}),
#  frozenset({'KOG2340', 'KOG3118'}),
#  frozenset({'KOG1744', 'KOG4012'}),
#  frozenset({'KOG0728', 'KOG1555'}),
#  frozenset({'KOG0518', 'KOG0676'}),
#  frozenset({'KOG0342', 'KOG0343'}),
#  frozenset({'KOG0040', 'KOG0517'}),
#  frozenset({'KOG0078', 'KOG1733'}),
#  frozenset({'KOG0101', 'KOG1376'}),
#  frozenset({'KOG1392', 'KOG3378'}),
#  frozenset({'KOG0118', 'KOG4318'}),
#  frozenset({'KOG3184', 'KOG3504'}),
#  frozenset({'KOG0215', 'KOG2409'}),
#  frozenset({'KOG0105', 'KOG0118'}),
#  frozenset({'KOG2351', 'KOG3298'}),
#  frozenset({'KOG0127', 'KOG0338'}),
#  frozenset({'KOG0052', 'KOG1869'}),
#  frozenset({'KOG1973', 'KOG4204'}),
#  frozenset({'KOG3529', 'KOG3911'}),
#  frozenset({'KOG0031', 'KOG0161'}),
#  frozenset({'KOG0901', 'KOG1722'}),
#  frozenset({'KOG1279', 'KOG4715'}),
#  frozenset({'KOG1937', 'KOG3682'}),
#  frozenset({'KOG3627', 'KOG4012'}),
#  frozenset({'KOG0408', 'KOG3162'}),
#  frozenset({'KOG0217', 'KOG0219'}),
#  frozenset({'KOG0726', 'KOG0729'}),
#  frozenset({'KOG0625', 'KOG2603'}),
#  frozenset({'KOG2506', 'KOG4110'}),
#  frozenset({'KOG0052', 'KOG1696'}),
#  frozenset({'KOG0100', 'KOG0104'}),
#  frozenset({'KOG2128', 'KOG4177'}),
#  frozenset({'KOG0469', 'KOG1948'}),
#  frozenset({'KOG1342', 'KOG3554'}),
#  frozenset({'KOG0676', 'KOG1945'}),
#  frozenset({'KOG2472', 'KOG2784'}),
#  frozenset({'KOG1767', 'KOG3291'}),
#  frozenset({'KOG0676', 'KOG1735'}),
#  frozenset({'KOG1691', 'KOG1692'}),
#  frozenset({'KOG0118', 'KOG0244'}),
#  frozenset({'KOG0096', 'KOG0112'}),
#  frozenset({'KOG2282', 'KOG3446'}),
#  frozenset({'KOG0266', 'KOG2581'}),
#  frozenset({'KOG2309', 'KOG3166'}),
#  frozenset({'KOG3595', 'KOG3905'}),
#  frozenset({'KOG1913', 'KOG4817'}),
#  frozenset({'KOG0854', 'KOG0873'}),
#  frozenset({'KOG1708', 'KOG1744'}),
#  frozenset({'KOG0103', 'KOG3538'}),
#  frozenset({'KOG0676', 'KOG3529'}),
#  frozenset({'KOG0676', 'KOG1387'}),
#  frozenset({'KOG1464', 'KOG1497'}),
#  frozenset({'KOG0191', 'KOG2447'}),
#  frozenset({'KOG0830', 'KOG1768'}),
#  frozenset({'KOG2242', 'KOG4673'}),
#  frozenset({'KOG0407', 'KOG2409'}),
#  frozenset({'KOG0400', 'KOG2988'}),
#  frozenset({'ENOG502QS9N', 'KOG1995'}),
#  frozenset({'KOG1756', 'KOG2987'}),
#  frozenset({'KOG0019', 'KOG0548'}),
#  frozenset({'KOG1744', 'KOG1756'}),
#  frozenset({'KOG1427', 'KOG4021'}),
#  frozenset({'KOG0516', 'KOG0977'}),
#  frozenset({'KOG3391', 'KOG3756'}),
#  frozenset({'KOG0533', 'KOG3301'}),
#  frozenset({'KOG0331', 'KOG4280'}),
#  frozenset({'KOG2072', 'KOG2314'}),
#  frozenset({'KOG0479', 'KOG0482'}),
#  frozenset({'KOG1697', 'KOG4422'}),
#  frozenset({'KOG2945', 'KOG3418'}),
#  frozenset({'KOG1570', 'KOG3464'}),
#  frozenset({'KOG1753', 'KOG3237'}),
#  frozenset({'KOG1767', 'KOG4206'}),
#  frozenset({'KOG3418', 'KOG4056'}),
#  frozenset({'KOG1475', 'KOG3457'}),
#  frozenset({'KOG3344', 'KOG3506'}),
#  frozenset({'KOG1555', 'KOG1556'}),
#  frozenset({'KOG1596', 'KOG2572'}),
#  frozenset({'KOG0118', 'KOG3045'}),
#  frozenset({'KOG0006', 'KOG0676'}),
#  frozenset({'KOG0516', 'KOG2379'}),
#  frozenset({'KOG2070', 'KOG4564'}),
#  frozenset({'KOG0101', 'KOG3128'}),
#  frozenset({'KOG3928', 'KOG3933'}),
#  frozenset({'KOG1570', 'KOG1767'}),
#  frozenset({'KOG0996', 'KOG3641'}),
#  frozenset({'KOG0118', 'KOG1077'}),
#  frozenset({'KOG0190', 'KOG2193'}),
#  frozenset({'KOG3333', 'KOG3346'}),
#  frozenset({'KOG0756', 'KOG2173'}),
#  frozenset({'KOG0115', 'KOG0190'}),
#  frozenset({'KOG3452', 'KOG3683'}),
#  frozenset({'KOG0052', 'KOG2118'}),
#  frozenset({'KOG0337', 'KOG0901'}),
#  frozenset({'KOG1189', 'KOG1745'}),
#  frozenset({'KOG0119', 'KOG0227'}),
#  frozenset({'KOG2481', 'KOG2823'}),
#  frozenset({'KOG0115', 'KOG3670'}),
#  frozenset({'KOG0674', 'KOG3184'}),
#  frozenset({'KOG0887', 'KOG3204'}),
#  frozenset({'KOG3279', 'KOG3331'}),
#  frozenset({'KOG0378', 'KOG1646'}),
#  frozenset({'KOG0402', 'KOG2309'}),
#  frozenset({'KOG0488', 'KOG0977'}),
#  frozenset({'KOG1685', 'KOG3166'}),
#  frozenset({'KOG0857', 'KOG4012'}),
#  frozenset({'KOG1475', 'KOG2037'}),
#  frozenset({'KOG1596', 'KOG4412'}),
#  frozenset({'KOG1854', 'KOG4604'}),
#  frozenset({'KOG0328', 'KOG3392'}),
#  frozenset({'KOG3301', 'KOG3424'}),
#  frozenset({'KOG0019', 'KOG0543'}),
#  frozenset({'KOG0118', 'KOG0657'}),
#  frozenset({'KOG2509', 'KOG2955'}),
#  frozenset({'KOG1498', 'KOG2908'}),
#  frozenset({'KOG0328', 'KOG2416'}),
#  frozenset({'KOG0652', 'KOG0727'}),
#  frozenset({'KOG0571', 'KOG1300'}),
#  frozenset({'KOG0018', 'KOG2327'}),
#  frozenset({'KOG0244', 'KOG1694'}),
#  frozenset({'KOG1767', 'KOG2916'}),
#  frozenset({'KOG1076', 'KOG2758'}),
#  frozenset({'KOG2301', 'KOG2453'}),
#  frozenset({'KOG0650', 'KOG2481'}),
#  frozenset({'KOG0895', 'KOG2790'}),
#  frozenset({'KOG0857', 'KOG3223'}),
#  frozenset({'KOG0118', 'KOG2036'}),
#  frozenset({'KOG3295', 'KOG3436'}),
#  frozenset({'KOG1464', 'KOG1554'}),
#  frozenset({'ENOG502QRXT', 'KOG1942'}),
#  frozenset({'KOG0677', 'KOG2826'}),
#  frozenset({'KOG0326', 'KOG4401'}),
#  frozenset({'KOG3627', 'KOG4794'}),
#  frozenset({'KOG3594', 'KOG3681'}),
#  frozenset({'KOG1668', 'KOG4266'}),
#  frozenset({'KOG3090', 'KOG3453'}),
#  frozenset({'ENOG502QS9N', 'KOG0331'}),
#  frozenset({'KOG0102', 'KOG0356'}),
#  frozenset({'KOG0990', 'KOG0991'}),
#  frozenset({'ENOG502QQ7T', 'KOG3382'}),
#  frozenset({'KOG1570', 'KOG2945'}),
#  frozenset({'KOG3311', 'KOG3411'}),
#  frozenset({'KOG3976', 'KOG4634'}),
#  frozenset({'KOG0676', 'KOG1044'}),
#  frozenset({'KOG0101', 'KOG0334'}),
#  frozenset({'KOG0543', 'KOG3791'}),
#  frozenset({'KOG0518', 'KOG0730'}),
#  frozenset({'KOG0163', 'KOG0676'}),
#  frozenset({'KOG0356', 'KOG3595'}),
#  frozenset({'KOG0416', 'KOG0521'}),
#  frozenset({'KOG2062', 'KOG3037'}),
#  frozenset({'KOG0106', 'KOG4207'}),
#  frozenset({'KOG3184', 'KOG4208'}),
#  frozenset({'KOG0407', 'KOG1628'}),
#  frozenset({'KOG3256', 'KOG3382'}),
#  frozenset({'KOG0407', 'KOG3291'}),
#  frozenset({'KOG2070', 'KOG2668'}),
#  frozenset({'KOG1588', 'KOG3751'}),
#  frozenset({'KOG1662', 'KOG3976'}),
#  frozenset({'KOG2196', 'KOG3630'}),
#  frozenset({'KOG0951', 'KOG1830'}),
#  frozenset({'KOG0381', 'KOG1756'}),
#  frozenset({'KOG0532', 'KOG1756'}),
#  frozenset({'KOG0101', 'KOG0688'}),
#  frozenset({'KOG0357', 'KOG0361'}),
#  frozenset({'KOG1732', 'KOG3504'}),
#  frozenset({'KOG0469', 'KOG0901'}),
#  frozenset({'KOG3181', 'KOG3344'}),
#  frozenset({'KOG1687', 'KOG2865'}),
#  frozenset({'KOG3172', 'KOG4206'}),
#  frozenset({'KOG0676', 'KOG3735'}),
#  frozenset({'KOG0676', 'KOG2968'}),
#  frozenset({'KOG0495', 'KOG2574'}),
#  frozenset({'KOG0329', 'KOG1874'}),
#  frozenset({'KOG0948', 'KOG2823'}),
#  frozenset({'KOG1523', 'KOG2826'}),
#  frozenset({'KOG0101', 'KOG1735'}),
#  frozenset({'KOG0019', 'KOG2121'}),
#  frozenset({'KOG0101', 'KOG0548'}),
#  frozenset({'KOG3486', 'KOG3520'}),
#  frozenset({'KOG3352', 'KOG4075'}),
#  frozenset({'KOG0096', 'KOG1426'}),
#  frozenset({'KOG2416', 'KOG3756'}),
#  frozenset({'KOG2582', 'KOG3250'}),
#  frozenset({'KOG2403', 'KOG3049'}),
#  frozenset({'KOG0040', 'KOG3587'}),
#  frozenset({'KOG0356', 'KOG1295'}),
#  frozenset({'KOG0469', 'KOG4189'}),
#  frozenset({'KOG2777', 'KOG4240'}),
#  frozenset({'KOG1876', 'KOG3380'}),
#  frozenset({'KOG3181', 'KOG3506'}),
#  frozenset({'KOG0676', 'KOG3681'}),
#  frozenset({'KOG0643', 'KOG2314'}),
#  frozenset({'KOG0040', 'KOG1685'}),
#  frozenset({'KOG3070', 'KOG4024'}),
#  frozenset({'KOG0927', 'KOG1570'}),
#  frozenset({'KOG0101', 'KOG1874'}),
#  frozenset({'KOG0729', 'KOG2005'}),
#  frozenset({'KOG0118', 'KOG0145'}),
#  frozenset({'KOG0955', 'KOG1973'}),
#  frozenset({'KOG2147', 'KOG2154'}),
#  frozenset({'KOG1697', 'KOG3928'}),
#  frozenset({'KOG1058', 'KOG3343'}),
#  frozenset({'KOG0107', 'KOG4207'}),
#  frozenset({'KOG0268', 'KOG2172'}),
#  frozenset({'KOG1587', 'KOG3595'}),
#  frozenset({'KOG0007', 'KOG2636'}),
#  frozenset({'KOG0362', 'KOG0364'}),
#  frozenset({'KOG0981', 'KOG1924'}),
#  frozenset({'KOG0746', 'KOG0901'}),
#  frozenset({'KOG2036', 'KOG2874'}),
#  frozenset({'KOG0505', 'KOG0946'}),
#  frozenset({'KOG1637', 'KOG4106'}),
#  frozenset({'KOG0836', 'KOG3174'}),
#  frozenset({'KOG2242', 'KOG4246'}),
#  frozenset({'KOG1744', 'KOG2712'}),
#  frozenset({'KOG1110', 'KOG2291'}),
#  frozenset({'KOG1350', 'KOG1662'}),
#  frozenset({'KOG0101', 'KOG3595'}),
#  frozenset({'KOG0160', 'KOG3418'}),
#  frozenset({'KOG0446', 'KOG0977'}),
#  frozenset({'KOG0313', 'KOG3596'}),
#  frozenset({'KOG1898', 'KOG2636'}),
#  frozenset({'KOG1164', 'KOG2265'}),
#  frozenset({'KOG0803', 'KOG4012'}),
#  frozenset({'KOG1492', 'KOG2040'}),
#  frozenset({'KOG0727', 'KOG1555'}),
#  frozenset({'KOG1628', 'KOG3301'}),
#  frozenset({'KOG0105', 'KOG4207'}),
#  frozenset({'KOG0991', 'KOG1968'}),
#  frozenset({'KOG2147', 'KOG2171'}),
#  frozenset({'KOG0020', 'KOG2091'}),
#  frozenset({'KOG0893', 'KOG3434'}),
#  frozenset({'KOG0364', 'KOG1672'}),
#  frozenset({'KOG1241', 'KOG3971'}),
#  frozenset({'KOG0676', 'KOG2675'}),
#  frozenset({'KOG1722', 'KOG3248'}),
#  frozenset({'KOG0751', 'KOG3863'}),
#  frozenset({'KOG1351', 'KOG1352'}),
#  frozenset({'KOG1671', 'KOG2583'}),
#  frozenset({'KOG2825', 'KOG3024'}),
#  frozenset({'KOG1351', 'KOG2759'}),
#  frozenset({'KOG0400', 'KOG0407'}),
#  frozenset({'KOG0619', 'KOG3166'}),
#  frozenset({'KOG0086', 'KOG0516'}),
#  frozenset({'KOG0118', 'KOG3070'}),
#  frozenset({'KOG1486', 'KOG4018'}),
#  frozenset({'KOG0676', 'KOG2994'}),
#  frozenset({'KOG0118', 'KOG1456'}),
#  frozenset({'KOG0488', 'KOG4587'}),
#  frozenset({'KOG2538', 'KOG2928'}),
#  frozenset({'KOG0102', 'KOG2056'}),
#  frozenset({'KOG0584', 'KOG2396'}),
#  frozenset({'KOG0381', 'KOG1745'}),
#  frozenset({'KOG0153', 'KOG3228'}),
#  frozenset({'KOG0362', 'KOG3527'}),
#  frozenset({'KOG2945', 'KOG3406'}),
#  frozenset({'KOG2147', 'KOG3871'}),
#  frozenset({'KOG1248', 'KOG3871'}),
#  frozenset({'KOG2242', 'KOG4315'}),
#  frozenset({'KOG0107', 'KOG0118'}),
#  frozenset({'KOG3168', 'KOG3428'}),
#  frozenset({'KOG4060', 'KOG4778'}),
#  frozenset({'KOG0877', 'KOG3181'}),
#  frozenset({'KOG1245', 'KOG1745'}),
#  frozenset({'KOG0105', 'KOG0113'}),
#  frozenset({'KOG1697', 'KOG3933'}),
#  frozenset({'KOG0473', 'KOG3457'}),
#  frozenset({'KOG2347', 'KOG3691'}),
#  frozenset({'KOG2450', 'KOG2653'}),
#  frozenset({'KOG0101', 'KOG0517'}),
#  frozenset({'KOG1745', 'KOG2915'}),
#  frozenset({'KOG1694', 'KOG3504'}),
#  frozenset({'KOG2266', 'KOG3068'}),
#  frozenset({'KOG4674', 'KOG4719'}),
#  frozenset({'KOG0101', 'KOG2581'}),
#  frozenset({'KOG0007', 'KOG1644'}),
#  frozenset({'KOG1816', 'KOG2834'}),
#  frozenset({'KOG1098', 'KOG3452'}),
#  frozenset({'KOG0118', 'KOG0676'}),
#  frozenset({'ENOG502QV3I', 'KOG4212'}),
#  frozenset({'KOG0355', 'KOG1745'}),
#  frozenset({'KOG0052', 'KOG0267'}),
#  frozenset({'KOG1744', 'KOG2154'}),
#  frozenset({'KOG0101', 'KOG0657'}),
#  frozenset({'ENOG502RG69', 'KOG1036'}),
#  frozenset({'KOG1723', 'KOG3185'}),
#  frozenset({'KOG0101', 'KOG1274'}),
#  frozenset({'KOG0114', 'KOG0213'}),
#  frozenset({'KOG0829', 'KOG3421'}),
#  frozenset({'KOG1426', 'KOG1756'}),
#  frozenset({'KOG0178', 'KOG0181'}),
#  frozenset({'KOG0924', 'KOG1453'}),
#  frozenset({'KOG0284', 'KOG2043'}),
#  frozenset({'KOG0362', 'KOG3516'}),
#  frozenset({'KOG1943', 'KOG3610'}),
#  frozenset({'KOG0875', 'KOG3031'}),
#  frozenset({'KOG0746', 'KOG4811'}),
#  frozenset({'KOG0960', 'KOG3052'}),
#  frozenset({'KOG0407', 'KOG3273'}),
#  frozenset({'KOG1795', 'KOG2441'}),
#  frozenset({'KOG1353', 'KOG3366'}),
#  frozenset({'KOG0264', 'KOG3554'}),
#  frozenset({'KOG0115', 'KOG2301'}),
#  frozenset({'KOG1774', 'KOG1823'}),
#  frozenset({'KOG0877', 'KOG1033'}),
#  frozenset({'KOG1779', 'KOG3486'}),
#  frozenset({'KOG1494', 'KOG4568'}),
#  frozenset({'KOG0517', 'KOG2885'}),
#  frozenset({'KOG1745', 'KOG4021'}),
#  frozenset({'KOG2815', 'KOG3271'}),
#  frozenset({'KOG1490', 'KOG3185'}),
#  frozenset({'KOG3163', 'KOG3492'}),
#  frozenset({'KOG0746', 'KOG1723'}),
#  frozenset({'KOG1660', 'KOG2273'}),
#  frozenset({'KOG0400', 'KOG3373'}),
#  None,
#  frozenset({'KOG0676', 'KOG2000'}),
#  frozenset({'KOG0272', 'KOG0495'}),
#  frozenset({'KOG1751', 'KOG1926'}),
#  frozenset({'KOG0101', 'KOG0877'}),
#  frozenset({'KOG3295', 'KOG3452'}),
#  frozenset({'KOG0266', 'KOG4121'}),
#  frozenset({'KOG2758', 'KOG3677'}),
#  frozenset({'KOG1926', 'KOG2885'}),
#  frozenset({'KOG0878', 'KOG3064'}),
#  frozenset({'KOG2573', 'KOG3387'}),
#  frozenset({'KOG0118', 'KOG4441'}),
#  frozenset({'KOG0830', 'KOG3486'}),
#  frozenset({'KOG1830', 'KOG2046'}),
#  frozenset({'KOG3184', 'KOG3412'}),
#  frozenset({'KOG0378', 'KOG1041'}),
#  frozenset({'KOG0227', 'KOG1150'}),
#  frozenset({'KOG2479', 'KOG3502'}),
#  frozenset({'KOG0355', 'KOG1744'}),
#  frozenset({'KOG2215', 'KOG3745'}),
#  frozenset({'KOG2291', 'KOG2416'}),
#  frozenset({'ENOG502QS9N', 'KOG2192'}),
#  frozenset({'KOG0101', 'KOG4637'}),
#  frozenset({'KOG1335', 'KOG2787'}),
#  frozenset({'KOG2177', 'KOG3090'}),
#  frozenset({'KOG0488', 'KOG1745'}),
#  frozenset({'KOG0279', 'KOG3181'}),
#  frozenset({'KOG2299', 'KOG4661'}),
#  frozenset({'KOG0052', 'KOG2371'}),
#  frozenset({'KOG1280', 'KOG1376'}),
#  frozenset({'KOG0397', 'KOG0875'}),
#  frozenset({'KOG0356', 'KOG4152'}),
#  frozenset({'KOG0453', 'KOG1494'}),
#  frozenset({'KOG0052', 'KOG1668'}),
#  frozenset({'KOG0003', 'KOG4012'}),
#  frozenset({'KOG3637', 'KOG3872'}),
#  frozenset({'KOG0381', 'KOG4021'}),
#  frozenset({'KOG0019', 'KOG0724'}),
#  frozenset({'KOG1745', 'KOG4562'}),
#  frozenset({'KOG0235', 'KOG2238'}),
#  frozenset({'KOG1556', 'KOG2581'}),
#  frozenset({'KOG0096', 'KOG0101'}),
#  frozenset({'KOG0477', 'KOG0481'}),
#  frozenset({'KOG0107', 'KOG4236'}),
#  frozenset({'KOG3166', 'KOG3418'}),
#  frozenset({'KOG0052', 'KOG1375'}),
#  frozenset({'KOG1105', 'KOG1694'}),
#  frozenset({'KOG1110', 'KOG1262'}),
#  frozenset({'KOG1765', 'KOG3031'}),
#  frozenset({'KOG2200', 'KOG2279'}),
#  frozenset({'KOG1808', 'KOG2261'}),
#  frozenset({'KOG0182', 'KOG0184'}),
#  frozenset({'KOG0475', 'KOG1744'}),
#  frozenset({'KOG0105', 'KOG0107'}),
#  frozenset({'KOG1037', 'KOG1756'}),
#  frozenset({'KOG0676', 'KOG0742'}),
#  frozenset({'KOG1190', 'KOG4322'}),
#  frozenset({'KOG0606', 'KOG2208'}),
#  frozenset({'KOG0052', 'KOG0857'}),
#  frozenset({'KOG3819', 'KOG4012'}),
#  frozenset({'KOG0118', 'KOG1428'}),
#  frozenset({'KOG1373', 'KOG3457'}),
#  frozenset({'KOG0118', 'KOG1995'}),
#  frozenset({'KOG0019', 'KOG0101'}),
#  frozenset({'KOG1490', 'KOG3163'}),
#  frozenset({'KOG0516', 'KOG2474'}),
#  frozenset({'KOG0118', 'KOG0977'}),
#  frozenset({'KOG1751', 'KOG3436'}),
#  frozenset({'KOG1715', 'KOG3257'}),
#  frozenset({'KOG1426', 'KOG1744'}),
#  frozenset({'KOG1738', 'KOG3166'}),
#  frozenset({'KOG0096', 'KOG1215'}),
#  frozenset({'KOG0385', 'KOG1245'}),
#  frozenset({'KOG0101', 'KOG2153'}),
#  frozenset({'KOG0291', 'KOG4655'}),
#  frozenset({'KOG1102', 'KOG2441'}),
#  frozenset({'KOG2971', 'KOG3295'}),
#  frozenset({'KOG1433', 'KOG1854'}),
#  frozenset({'KOG1507', 'KOG1744'}),
#  frozenset({'KOG1588', 'KOG3826'}),
#  frozenset({'KOG1696', 'KOG2240'}),
#  frozenset({'KOG1671', 'KOG3494'}),
#  frozenset({'KOG1694', 'KOG3070'}),
#  frozenset({'KOG0477', 'KOG1086'}),
#  frozenset({'KOG1685', 'KOG4208'}),
#  frozenset({'KOG0101', 'KOG2160'}),
#  frozenset({'KOG2481', 'KOG3184'}),
#  frozenset({'KOG0650', 'KOG2153'}),
#  frozenset({'KOG1526', 'KOG4725'}),
#  frozenset({'KOG2036', 'KOG2318'}),
#  frozenset({'KOG0651', 'KOG0727'}),
#  frozenset({'KOG1713', 'KOG3389'}),
#  frozenset({'KOG0938', 'KOG1983'}),
#  frozenset({'KOG0118', 'KOG4212'}),
#  frozenset({'KOG0742', 'KOG4223'}),
#  frozenset({'KOG1744', 'KOG4021'}),
#  frozenset({'KOG0676', 'KOG4678'}),
#  frozenset({'KOG0477', 'KOG0480'}),
#  frozenset({'KOG0730', 'KOG4600'}),
#  frozenset({'KOG0265', 'KOG2441'}),
#  frozenset({'KOG0020', 'KOG0100'}),
#  frozenset({'KOG1549', 'KOG1748'}),
#  frozenset({'KOG2295', 'KOG3595'}),
#  frozenset({'KOG1240', 'KOG4248'}),
#  frozenset({'KOG0045', 'KOG3595'}),
#  frozenset({'KOG0250', 'KOG0979'}),
#  frozenset({'KOG0101', 'KOG0112'}),
#  frozenset({'KOG0517', 'KOG1853'}),
#  frozenset({'KOG1475', 'KOG1694'}),
#  frozenset({'KOG0052', 'KOG4424'}),
#  frozenset({'KOG0891', 'KOG2326'}),
#  frozenset({'KOG1742', 'KOG3295'}),
#  frozenset({'KOG0676', 'KOG1662'}),
#  frozenset({'KOG0676', 'KOG1747'}),
#  frozenset({'KOG0900', 'KOG3181'}),
#  frozenset({'KOG0106', 'KOG0107'}),
#  frozenset({'KOG2330', 'KOG3172'}),
#  frozenset({'KOG0845', 'KOG3911'}),
#  frozenset({'KOG4562', 'KOG4718'}),
#  frozenset({'KOG1475', 'KOG3412'}),
#  frozenset({'KOG0407', 'KOG1768'}),
#  frozenset({'KOG0407', 'KOG3283'}),
#  frozenset({'KOG0746', 'KOG1646'}),
#  frozenset({'KOG3458', 'KOG4110'}),
#  frozenset({'KOG1084', 'KOG3418'}),
#  frozenset({'KOG0106', 'KOG3101'}),
#  frozenset({'KOG0068', 'KOG2056'}),
#  frozenset({'KOG0445', 'KOG4012'}),
#  frozenset({'KOG0651', 'KOG0652'}),
#  frozenset({'KOG0356', 'KOG4228'}),
#  frozenset({'KOG0845', 'KOG4521'}),
#  frozenset({'KOG1991', 'KOG4012'}),
#  frozenset({'KOG1189', 'KOG1744'}),
#  frozenset({'KOG0875', 'KOG1122'}),
#  frozenset({'ENOG502QQ0A', 'KOG2447'}),
#  frozenset({'KOG0118', 'KOG1588'}),
#  frozenset({'KOG0004', 'KOG3506'}),
#  frozenset({'KOG0027', 'KOG0163'}),
#  frozenset({'KOG0358', 'KOG0361'}),
#  frozenset({'KOG0161', 'KOG2301'}),
#  frozenset({'KOG0202', 'KOG1565'}),
#  frozenset({'KOG0391', 'KOG2680'}),
#  frozenset({'KOG0360', 'KOG0362'}),
#  frozenset({'KOG0118', 'KOG4387'}),
#  frozenset({'KOG0775', 'KOG3166'}),
#  frozenset({'KOG0469', 'KOG4222'}),
#  frozenset({'ENOG502QSR4', 'KOG1735'}),
#  frozenset({'KOG0037', 'KOG0244'}),
#  frozenset({'KOG1041', 'KOG2242'}),
#  frozenset({'KOG0815', 'KOG1762'}),
#  frozenset({'KOG0161', 'KOG1744'}),
#  frozenset({'KOG0337', 'KOG2153'}),
#  frozenset({'KOG0078', 'KOG0791'}),
#  frozenset({'KOG0019', 'KOG0970'}),
#  frozenset({'KOG1070', 'KOG4008'}),
#  frozenset({'KOG1745', 'KOG1757'}),
#  frozenset({'KOG0381', 'KOG1744'}),
#  frozenset({'ENOG502QS9N', 'KOG0118'}),
#  frozenset({'KOG0019', 'KOG1822'}),
#  frozenset({'KOG1696', 'KOG3320'}),
#  frozenset({'KOG1823', 'KOG3424'}),
#  frozenset({'KOG0391', 'KOG4012'}),
#  frozenset({'KOG0951', 'KOG2217'}),
#  frozenset({'KOG2655', 'KOG3859'}),
#  frozenset({'KOG3389', 'KOG3426'}),
#  frozenset({'KOG0732', 'KOG3166'}),
#  frozenset({'KOG0951', 'KOG2653'}),
#  frozenset({'KOG0466', 'KOG2768'}),
#  frozenset({'KOG0279', 'KOG0830'}),
#  frozenset({'KOG0473', 'KOG3301'}),
#  frozenset({'KOG0117', 'KOG0118'}),
#  frozenset({'KOG0357', 'KOG0362'}),
#  frozenset({'KOG0003', 'KOG1756'}),
#  frozenset({'KOG1427', 'KOG1745'}),
#  frozenset({'KOG1757', 'KOG4012'}),
#  frozenset({'KOG2440', 'KOG2668'}),
#  frozenset({'KOG1463', 'KOG1498'}),
#  frozenset({'KOG0118', 'KOG3535'}),
#  frozenset({'KOG0235', 'KOG4377'}),
#  frozenset({'KOG1756', 'KOG4021'}),
#  frozenset({'KOG3418', 'KOG4441'}),
#  frozenset({'KOG0244', 'KOG1124'}),
#  frozenset({'KOG0190', 'KOG0674'}),
#  frozenset({'KOG1744', 'KOG1745'}),
#  frozenset({'KOG0694', 'KOG4012'}),
#  frozenset({'KOG0901', 'KOG2423'}),
#  frozenset({'KOG1749', 'KOG3320'}),
#  frozenset({'KOG1744', 'KOG2266'}),
#  frozenset({'KOG2147', 'KOG3980'}),
#  frozenset({'KOG1494', 'KOG1641'}),
#  frozenset({'KOG1539', 'KOG2572'}),
#  frozenset({'KOG0727', 'KOG0729'}),
#  frozenset({'KOG1795', 'KOG2026'}),
#  frozenset({'KOG3166', 'KOG3184'}),
#  frozenset({'KOG1698', 'KOG3280'}),
#  frozenset({'KOG0999', 'KOG4012'}),
#  frozenset({'KOG4009', 'KOG4633'}),
#  frozenset({'KOG1769', 'KOG2591'}),
#  frozenset({'KOG0216', 'KOG3421'}),
#  frozenset({'KOG0019', 'KOG4439'}),
#  frozenset({'ENOG502RB0C', 'KOG0213'}),
#  frozenset({'KOG2072', 'KOG2479'}),
#  frozenset({'KOG0706', 'KOG0746'}),
#  frozenset({'KOG0161', 'KOG0676'}),
#  frozenset({'KOG0385', 'KOG1954'}),
#  frozenset({'KOG2054', 'KOG4008'}),
#  frozenset({'KOG1199', 'KOG2967'}),
#  frozenset({'KOG0830', 'KOG1901'}),
#  frozenset({'KOG0338', 'KOG2481'}),
#  frozenset({'KOG0644', 'KOG1897'}),
#  frozenset({'KOG0941', 'KOG3463'}),
#  frozenset({'KOG0734', 'KOG2620'}),
#  frozenset({'KOG0968', 'KOG3501'}),
#  frozenset({'KOG0004', 'KOG0898'}),
#  frozenset({'KOG1768', 'KOG3502'}),
#  frozenset({'KOG0878', 'KOG3412'}),
#  frozenset({'KOG0742', 'KOG3078'}),
#  frozenset({'KOG0784', 'KOG0785'}),
#  frozenset({'KOG0594', 'KOG4012'}),
#  ...}

# %%
#xlms_fs = [x for x in get_leca_pairs(i, j, leca_nogs) for i, j in zip(xlms['ID1'], xlms['ID2'])]
xlms_fs = [frozenset({i, j}) for i, j in zip(xlms['ID1'], xlms['ID2']) if i in leca_nogs and j in leca_nogs]
y2h_fs = [frozenset({i, j}) for i, j in zip(y2h['ID1'], y2h['ID2']) if i in leca_nogs and j in leca_nogs]
cx_fs = [frozenset({i, j}) for i, j in zip(cx['ID1'], cx['ID2']) if i in leca_nogs and j in leca_nogs]
print(f'# total XLMS pairs: {len(xlms_fs)}')
print(f'# total Y2H pairs: {len(y2h_fs)}')
print(f'# total CX pairs: {len(cx_fs)}')
# Out:
# # total XLMS pairs: 1587
# # total Y2H pairs: 20568
# # total CX pairs: 41650

# %%
leca = pd.read_csv(leca_file)
leca[['ID1', 'ID2']] = leca['ID'].str.split(' ', n=1, expand=True)
leca['fs'] = [frozenset({i, j}) for i, j in zip(leca['ID1'], leca['ID2'])]
leca_fs = [frozenset({i, j}) for i, j in zip(leca['ID1'], leca['ID2'])]

# %%
leca_gs = leca[(leca.set == 'train') | (leca.set == 'test')]
leca_fsgs = [frozenset({i, j}) for i, j in zip(leca_gs['ID1'], leca_gs['ID2'])]

# %%
xlms_true = set(leca_fs) & set(xlms_fs)
y2h_true = set(leca_fs) & set(y2h_fs)
cx_true = set(leca_fs) & set(cx_fs)
print(f'# XLMS overlap: {len(xlms_true)}')
print(f'# Y2H overlap: {len(y2h_true)}')
print(f'# CX overlap: {len(cx_true)}')
# Out:
# # XLMS overlap: 912
# # Y2H overlap: 4610
# # CX overlap: 17501

# %%
xlms_true_gs = set(leca_fsgs) & set(xlms_fs)
y2h_true_gs = set(leca_fsgs) & set(y2h_fs)
cx_true_gs = set(leca_fsgs) & set(cx_fs)
print(f'# XLMS overlap: {len(xlms_true)}')
print(f'# Y2H overlap: {len(y2h_true)}')
print(f'# CX overlap: {len(cx_true)}')
# Out:
# # XLMS overlap: 912
# # Y2H overlap: 4610
# # CX overlap: 17501

# %%
t0 = time.time()
leca['xlms'] = [1 if i in xlms_true else 0 for i in leca['fs']]
rt_xlms = round(time.time() - t0, 2)
print(f'XLMS match time: {rt_xlms} seconds')
t1 = time.time()
leca['y2h'] = [1 if i in y2h_true else 0 for i in leca['fs']]
rt_y2h = round(time.time() - t1, 2)
print(f'Y2H match time: {rt_y2h} seconds')
t2 = time.time()
leca['cx'] = [1 if i in cx_true else 0 for i in leca['fs']]
rt_cx = round(time.time() - t2, 2)
print(f'CX match time: {rt_cx} seconds')
# Out:
# XLMS match time: 1.72 seconds
# Y2H match time: 1.82 seconds
# CX match time: 2.01 seconds

# %%
leca['bin'] = np.divmod(np.arange(len(leca)),1000)[0]+1

# %% [markdown]
# ## Calculate logloss per bin for the intersection of LECA PPIs and external sets

# %%
def calc_cumu_overlap(df, col):
    cumu_frac = 0
    cumu_lst = []
    df = df.sort_values('mean_ppi_score').reset_index(drop=True)
    for i in range(len(df)):
        cumu_frac += df[col][i]
        cumu_lst.append(cumu_frac)
    cumu_lst.reverse()
    return(cumu_lst)

def calc_binned_logloss(df, target, real_total=None):
    df = df[df[target] == 1]
    overlap = len(df)
    gb = df.groupby(['bin'])
    n = gb.size().to_frame(name='int_size')
    ll = gb.apply(lambda x: log_loss(x[target], x['ppi_score'], labels=[1,0])).to_frame(name='logloss')
    avg = gb.agg({'ppi_score':'mean'}).rename(columns={'ppi_score':'mean_ppi_score'})
    res = n.join(ll).join(avg)
    res['int_frac'] = res['int_size']/overlap
    res['int_cumu_overlap'] = calc_cumu_overlap(res, 'int_frac')
    if real_total:
        res['total_frac'] = res['int_size']/real_total
        res['total_cumu_overlap'] = calc_cumu_overlap(res, 'total_frac')
    res['set'] = target
    return(res)

# %%
xlms_ll = calc_binned_logloss(leca, 'xlms', real_total=len(xlms_fs))
y2h_ll = calc_binned_logloss(leca, 'y2h', real_total=len(y2h_fs))
cx_ll = calc_binned_logloss(leca, 'cx', real_total=len(cx_fs))

# %%
ll_out = pd.concat([xlms_ll, y2h_ll, cx_ll])
ll_out.to_csv('../ppi_ml/results/ext_val_logloss.csv')

# %%
ll_out
# Out:
#       int_size       logloss  mean_ppi_score  int_frac  int_cumu_overlap  \
# bin
# 1           81  3.215782e-07        1.000000  0.088816          1.000000
# 2           51  8.321853e-06        0.999992  0.055921          0.911184
# 3           43  5.750111e-05        0.999943  0.047149          0.855263
# 4           36  1.993283e-04        0.999801  0.039474          0.808114
# 5           25  5.976943e-04        0.999402  0.027412          0.768640
# ...        ...           ...             ...       ...               ...
# 4488         2  2.850650e+00        0.057807  0.000114          0.000800
# 4489         4  2.860023e+00        0.057268  0.000229          0.000686
# 4490         3  2.872887e+00        0.056536  0.000171          0.000457
# 4491         2  2.890372e+00        0.055556  0.000114          0.000286
# 4492         3  2.950987e+00        0.052331  0.000171          0.000171
#
#       total_frac  total_cumu_overlap   set
# bin
# 1       0.051040            0.574669  xlms
# 2       0.032136            0.523629  xlms
# 3       0.027095            0.491493  xlms
# 4       0.022684            0.464398  xlms
# 5       0.015753            0.441714  xlms
# ...          ...                 ...   ...
# 4488    0.000048            0.000336    cx
# 4489    0.000096            0.000288    cx
# 4490    0.000072            0.000192    cx
# 4491    0.000048            0.000120    cx
# 4492    0.000072            0.000072    cx
#
# [6715 rows x 8 columns]

# %% [markdown]
# # Calculate odds for LECA PPIs and external PPIs

# %%
def calc_binned_odds(df, target, overlap):
    
    # calc ext odds
    df_ext = df[df[target] == 1]
    gb = df_ext.groupby(['bin'])
    n_ext = gb.size().to_frame(name='int_size')
    n_ext['ext_odds'] = n_ext['int_size']/(overlap - n_ext['int_size'])

    # calc leca odds
    df_leca = df[(df.set == 'test') | (df.set == 'train')]
    gs_total = len(df_leca)
    gb = df_leca.groupby(['bin'])
    n_leca = gb.size().to_frame(name='gs_size')
    n_leca['leca_odds'] = n_leca['gs_size']/(gs_total - n_leca['gs_size'])
    
    # calc avg ppi score
    avg = gb.agg({'ppi_score':'mean'}).rename(columns={'ppi_score':'mean_ppi_score'})
    res = n_ext.join(n_leca).join(avg)
    
    # calc odds ratio
    res['odds_ratio'] = res['ext_odds']/res['leca_odds']
    res['set'] = target
    res['total_overlap'] = overlap
    print(res)
    return(res)

# %%
xlms_lo = calc_binned_odds(leca, 'xlms', overlap=len(xlms_true))
y2h_lo = calc_binned_odds(leca, 'y2h', overlap=len(y2h_true))
cx_lo = calc_binned_odds(leca, 'cx', overlap=len(cx_true))
# Out:
#       int_size  ext_odds  gs_size  leca_odds  mean_ppi_score  odds_ratio  \
# bin
# 1           81  0.097473       73   0.002761        1.000000   35.307898
# 2           51  0.059233      108   0.004090        0.999992   14.483675
# 3           43  0.049482      122   0.004622        0.999941   10.705182
# 4           36  0.041096      141   0.005346        0.999781    7.687263
# 5           25  0.028185      154   0.005842        0.999438    4.824741
# ...        ...       ...      ...        ...             ...         ...
# 4210         1  0.001098        2   0.000075        0.070133   14.552141
# 4220         1  0.001098        4   0.000151        0.069941    7.275521
# 4276         1  0.001098        2   0.000075        0.068760   14.552141
# 4318         1  0.001098        5   0.000189        0.067763    5.820198
# 4401         1  0.001098        2   0.000075        0.065252   14.552141
#
#        set  total_overlap
# bin
# 1     xlms            912
# 2     xlms            912
# 3     xlms            912
# 4     xlms            912
# 5     xlms            912
# ...    ...            ...
# 4210  xlms            912
# 4220  xlms            912
# 4276  xlms            912
# 4318  xlms            912
# 4401  xlms            912
#
# [376 rows x 8 columns]
#       int_size  ext_odds  gs_size  leca_odds  mean_ppi_score  odds_ratio  set  \
# bin
# 1            8  0.001738     73.0   0.002761        1.000000    0.629696  y2h
# 2            6  0.001303    108.0   0.004090        0.999992    0.318660  y2h
# 3            7  0.001521    122.0   0.004622        0.999941    0.329005  y2h
# 4           12  0.002610    141.0   0.005346        0.999781    0.488186  y2h
# 5           11  0.002392    154.0   0.005842        0.999438    0.409437  y2h
# ...        ...       ...      ...        ...             ...         ...  ...
# 4472         1  0.000217      2.0   0.000075        0.060980    2.876329  y2h
# 4479         1  0.000217      1.0   0.000038        0.060120    5.752875  y2h
# 4480         1  0.000217      2.0   0.000075        0.059906    2.876329  y2h
# 4484         1  0.000217      2.0   0.000075        0.059103    2.876329  y2h
# 4492         1  0.000217      2.0   0.000075        0.052439    2.876329  y2h
#
#       total_overlap
# bin
# 1              4610
# 2              4610
# 3              4610
# 4              4610
# 5              4610
# ...             ...
# 4472           4610
# 4479           4610
# 4480           4610
# 4484           4610
# 4492           4610
#
# [2505 rows x 8 columns]
#       int_size  ext_odds  gs_size  leca_odds  mean_ppi_score  odds_ratio set  \
# bin
# 1          464  0.027235     73.0   0.002761        1.000000    9.865355  cx
# 2          287  0.016672    108.0   0.004090        0.999992    4.076729  cx
# 3          252  0.014610    122.0   0.004622        0.999941    3.160691  cx
# 4          232  0.013434    141.0   0.005346        0.999781    2.513010  cx
# 5          213  0.012321    154.0   0.005842        0.999438    2.109077  cx
# ...        ...       ...      ...        ...             ...         ...  ..
# 4488         2  0.000114      2.0   0.000075        0.057675    1.515172  cx
# 4489         4  0.000229      1.0   0.000038        0.057319    6.061611  cx
# 4490         3  0.000171      NaN        NaN             NaN         NaN  cx
# 4491         2  0.000114      NaN        NaN             NaN         NaN  cx
# 4492         3  0.000171      2.0   0.000075        0.052439    2.272888  cx
#
#       total_overlap
# bin
# 1             17501
# 2             17501
# 3             17501
# 4             17501
# 5             17501
# ...             ...
# 4488          17501
# 4489          17501
# 4490          17501
# 4491          17501
# 4492          17501
#
# [3834 rows x 8 columns]

# %%
lo_out = pd.concat([xlms_lo, y2h_lo, cx_lo])
lo_out.to_csv('../ppi_ml/results/ext_val_odds_ratio.csv')

# %% [markdown]
# # Calculate log odds ratio

# %%
from datetime import datetime as dt
from tqdm import tqdm
tqdm.pandas()

# %%
# total leca
leca = pd.read_csv(leca_file)
leca[['ID1', 'ID2']] = leca['ID'].str.split(' ', n=1, expand=True)
leca['fs'] = [frozenset({i, j}) for i, j in zip(leca['ID1'], leca['ID2'])]
leca_fs = [frozenset({i, j}) for i, j in zip(leca['ID1'], leca['ID2'])]

# %%
# total external
xlms_fs = [frozenset({i, j}) for i, j in zip(xlms['ID1'], xlms['ID2']) if i in leca_nogs and j in leca_nogs]
y2h_fs = [frozenset({i, j}) for i, j in zip(y2h['ID1'], y2h['ID2']) if i in leca_nogs and j in leca_nogs]
cx_fs = [frozenset({i, j}) for i, j in zip(cx['ID1'], cx['ID2']) if i in leca_nogs and j in leca_nogs]
print(f'# total XLMS pairs: {len(xlms_fs)}')
print(f'# total Y2H pairs: {len(y2h_fs)}')
print(f'# total CX pairs: {len(cx_fs)}')
# Out:
# # total XLMS pairs: 1587
# # total Y2H pairs: 20568
# # total CX pairs: 41650

# %%
# intersection of leca and external
xlms_int = set(leca_fs) & set(xlms_fs)
y2h_int = set(leca_fs) & set(y2h_fs)
cx_int = set(leca_fs) & set(cx_fs)
print(f'# XLMS overlap: {len(xlms_int)}')
print(f'# Y2H overlap: {len(y2h_int)}')
print(f'# CX overlap: {len(cx_int)}')
# Out:
# # XLMS overlap: 912
# # Y2H overlap: 4610
# # CX overlap: 17501

# %%
def calc_binned_log_odds(df, target, ext_set):
    
    all_leca_ppis = set([frozenset({i, j}) for i, j in zip(df['ID1'], df['ID2'])])
    all_prots = set([p for pair in all_leca_ppis for p in list(pair)])
    all_ppis = set([frozenset({i, j}) for i,j in list(combinations(list(all_prots), 2))])
    all_assayable_ppis = all_ppis.difference(all_leca_ppis)

    leca_only = len(all_leca_ppis.difference(ext_set))
    ext_only = len(all_assayable_ppis.intersection(ext_set))
    neither = len(all_assayable_ppis.difference(ext_set))
    both = len(df[df[target] == 1])
    odds_ratio = (both/ext_only)/(leca_only/neither)
    
    return(odds_ratio)

# %%
leca_binned = leca.groupby('bin')
avg = leca_binned.agg({'ppi_score':'mean'}).rename(columns={'ppi_score':'mean_ppi_score'})

# %%
xlms_or = leca_binned.progress_apply(lambda x: calc_binned_log_odds(x, 'xlms', xlms_fs))
# Out:
#   4%|███                                                                                   | 163/4492 [03:42<1:38:28,  1.36s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [268], line 1
# ----> 1 xlms_or = leca_binned.progress_apply(lambda x: calc_binned_log_odds(x, 'xlms', xlms_fs))
#
# File ~/miniconda3/envs/dev/lib/python3.10/site-packages/tqdm/std.py:814, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     811 # Apply the provided function (in **kwargs)
#     812 # on the df using our wrapper (which provides bar updating)
#     813 try:
# --> 814     return getattr(df, df_function)(wrapper, **kwargs)
#     815 finally:
#     816     t.close()
#
# File ~/miniconda3/envs/dev/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1567, in GroupBy.apply(self, func, *args, **kwargs)
#    1559     new_msg = (
#    1560         f"The operation {orig_func} failed on a column. If any error is "
#    1561         f"raised, this will raise an exception in a future version "
#    1562         f"of pandas. Drop these columns to avoid this warning."
#    1563     )
#    1564     with rewrite_warning(
#    1565         old_msg, FutureWarning, new_msg
#    1566     ) if is_np_func else nullcontext():
# -> 1567         result = self._python_apply_general(f, self._selected_obj)
#    1568 except TypeError:
#    1569     # gh-20949
#    1570     # try again, with .apply acting as a filtering
#    (...)
#    1574     # fails on *some* columns, e.g. a numeric operation
#    1575     # on a string grouper column
#    1577     with self._group_selection_context():
#    1578         # GH#50538
#
# File ~/miniconda3/envs/dev/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1629, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1592 @final
#    1593 def _python_apply_general(
#    1594     self,
#    (...)
#    1599     is_agg: bool = False,
#    1600 ) -> NDFrameT:
#    1601     """
#    1602     Apply function f in python space
#    1603
#    (...)
#    1627         data after applying f
#    1628     """
# -> 1629     values, mutated = self.grouper.apply(f, data, self.axis)
#    1630     if not_indexed_same is None:
#    1631         not_indexed_same = mutated or self.mutated
#
# File ~/miniconda3/envs/dev/lib/python3.10/site-packages/pandas/core/groupby/ops.py:839, in BaseGrouper.apply(self, f, data, axis)
#     837 # group might be modified
#     838 group_axes = group.axes
# --> 839 res = f(group)
#     840 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     841     mutated = True
#
# File ~/miniconda3/envs/dev/lib/python3.10/site-packages/tqdm/std.py:809, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     803 def wrapper(*args, **kwargs):
#     804     # update tbar correctly
#     805     # it seems `pandas apply` calls `func` twice
#     806     # on the first column/row to decide whether it can
#     807     # take a fast or slow code path; so stop when t.total==t.n
#     808     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 809     return func(*args, **kwargs)
#
# Cell In [268], line 1, in <lambda>(x)
# ----> 1 xlms_or = leca_binned.progress_apply(lambda x: calc_binned_log_odds(x, 'xlms', xlms_fs))
#
# Cell In [267], line 8, in calc_binned_log_odds(df, target, ext_set)
#       6 all_prots = set([p for pair in all_leca_ppis for p in list(pair)])
#       7 #print(f"[{dt.now()}] Generating all possible pairs ...")
# ----> 8 all_ppis = set([frozenset({i, j}) for i,j in list(combinations(list(all_prots), 2))])
#       9 #print(f"[{dt.now()}] Finding all assayable pairs, minus LECA PPIs ...")
#      10 all_assayable_ppis = all_ppis.difference(all_leca_ppis)
#
# Cell In [267], line 8, in <listcomp>(.0)
#       6 all_prots = set([p for pair in all_leca_ppis for p in list(pair)])
#       7 #print(f"[{dt.now()}] Generating all possible pairs ...")
# ----> 8 all_ppis = set([frozenset({i, j}) for i,j in list(combinations(list(all_prots), 2))])
#       9 #print(f"[{dt.now()}] Finding all assayable pairs, minus LECA PPIs ...")
#      10 all_assayable_ppis = all_ppis.difference(all_leca_ppis)
#
# KeyboardInterrupt:

# %%
y2h_or = leca_binned.progress_apply(lambda x: calc_binned_log_odds(x, 'y2h', y2h_fs))
# Out:
#  17%|███████████████                                                                       | 786/4492 [27:03<2:07:36,  2.07s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [269], line 1
# ----> 1 y2h_or = leca_binned.progress_apply(lambda x: calc_binned_log_odds(x, 'y2h', y2h_fs)).to_frame(name='y2h_or')
#
# File ~/miniconda3/envs/dev/lib/python3.10/site-packages/tqdm/std.py:814, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     811 # Apply the provided function (in **kwargs)
#     812 # on the df using our wrapper (which provides bar updating)
#     813 try:
# --> 814     return getattr(df, df_function)(wrapper, **kwargs)
#     815 finally:
#     816     t.close()
#
# File ~/miniconda3/envs/dev/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1567, in GroupBy.apply(self, func, *args, **kwargs)
#    1559     new_msg = (
#    1560         f"The operation {orig_func} failed on a column. If any error is "
#    1561         f"raised, this will raise an exception in a future version "
#    1562         f"of pandas. Drop these columns to avoid this warning."
#    1563     )
#    1564     with rewrite_warning(
#    1565         old_msg, FutureWarning, new_msg
#    1566     ) if is_np_func else nullcontext():
# -> 1567         result = self._python_apply_general(f, self._selected_obj)
#    1568 except TypeError:
#    1569     # gh-20949
#    1570     # try again, with .apply acting as a filtering
#    (...)
#    1574     # fails on *some* columns, e.g. a numeric operation
#    1575     # on a string grouper column
#    1577     with self._group_selection_context():
#    1578         # GH#50538
#
# File ~/miniconda3/envs/dev/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1629, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1592 @final
#    1593 def _python_apply_general(
#    1594     self,
#    (...)
#    1599     is_agg: bool = False,
#    1600 ) -> NDFrameT:
#    1601     """
#    1602     Apply function f in python space
#    1603
#    (...)
#    1627         data after applying f
#    1628     """
# -> 1629     values, mutated = self.grouper.apply(f, data, self.axis)
#    1630     if not_indexed_same is None:
#    1631         not_indexed_same = mutated or self.mutated
#
# File ~/miniconda3/envs/dev/lib/python3.10/site-packages/pandas/core/groupby/ops.py:839, in BaseGrouper.apply(self, f, data, axis)
#     837 # group might be modified
#     838 group_axes = group.axes
# --> 839 res = f(group)
#     840 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     841     mutated = True
#
# File ~/miniconda3/envs/dev/lib/python3.10/site-packages/tqdm/std.py:809, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     803 def wrapper(*args, **kwargs):
#     804     # update tbar correctly
#     805     # it seems `pandas apply` calls `func` twice
#     806     # on the first column/row to decide whether it can
#     807     # take a fast or slow code path; so stop when t.total==t.n
#     808     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 809     return func(*args, **kwargs)
#
# Cell In [269], line 1, in <lambda>(x)
# ----> 1 y2h_or = leca_binned.progress_apply(lambda x: calc_binned_log_odds(x, 'y2h', y2h_fs)).to_frame(name='y2h_or')
#
# KeyboardInterrupt:

# %%
cx_or = leca_binned.apply(lambda x: calc_binned_log_odds(x, 'cx', cx_fs))
# Out:
#         xlms_or
# bin
# 1     30.246464
# 2     12.815109
# 3     13.082196
# 4     13.873444
# 5     12.274084
# ...         ...
# 4488   0.000000
# 4489   0.000000
# 4490   0.000000
# 4491   0.000000
# 4492   0.000000
#
# [4492 rows x 1 columns]

# %%
res = avg.join(xlms_or).join(y2h_or).join(cx_or)

# %%
res.to_csv('../ppi_ml/results/ext_val_odds_ratio.csv')

# %%
len(y2h_fs)
# Out:
# 20568

# %% [markdown]
# ### set up for a janky parallelization on the command line

# %%
import pickle

# %%
with open('../ppi_ml/results/ext_val/xlms_set.pkl', 'wb') as f:
    pickle.dump(xlms_fs, f)
with open('../ppi_ml/results/ext_val/y2h_set.pkl', 'wb') as f:
    pickle.dump(y2h_fs, f)
with open('../ppi_ml/results/ext_val/cx_set.pkl', 'wb') as f:
    pickle.dump(cx_fs, f)

# %%
leca.to_pickle('../ppi_ml/results/ext_val/leca_ext_val.pkl')

# %%
# !ls /stor/work/Marcotte/project/rmcox/leca/ppi_ml/results/ext_val/
# Out:
# cx_set.pkl  leca_ext_val.pkl  xlms_set.pkl  y2h_set.pkl

# %%
infile = sys.argv[1]
extfile = sys.argv[2]
target = sys.argv[3]
outfile = f'/stor/work/Marcotte/project/rmcox/leca/ppi_ml/results/ext_val/{target}_or.pkl'

# %%
for i in exps:
    print(f'python3 janky_parallel_or.py leca_ext_val.pkl {i}_set.pkl {i}')
# Out:
# python3 janky_parallel_or.py leca_ext_val.pkl xlms_set.pkl xlms
# python3 janky_parallel_or.py leca_ext_val.pkl y2h_set.pkl y2h
# python3 janky_parallel_or.py leca_ext_val.pkl cx_set.pkl cx

# %% [markdown]
# ### results

# %%
res_list = []
for exp in exps:
    with open(f'../ppi_ml/results/ext_val/{exp}_or.pkl', 'rb') as f:
        results = pickle.load(f)
        print(results)
        res_list.append(results)
res_list
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# [Empty DataFrame
#  Columns: []
#  Index: [],
#  Empty DataFrame
#  Columns: []
#  Index: [],
#  Empty DataFrame
#  Columns: []
#  Index: []]

# %%
with open('../ppi_ml/results/ext_val/cx_set.pkl', 'rb') as f:
    test = pickle.load(f)
test
# Out:
# [frozenset({'KOG1727', 'KOG1779'}),
#  frozenset({'KOG0052', 'KOG1727'}),
#  frozenset({'KOG1696', 'KOG3475'}),
#  frozenset({'KOG1749', 'KOG1751'}),
#  frozenset({'KOG0378', 'KOG1749'}),
#  frozenset({'KOG1727', 'KOG3311'}),
#  frozenset({'KOG3475', 'KOG3499'}),
#  frozenset({'KOG1728', 'KOG3475'}),
#  frozenset({'KOG1646', 'KOG1749'}),
#  frozenset({'KOG1728', 'KOG2988'}),
#  frozenset({'KOG1570', 'KOG3320'}),
#  frozenset({'KOG0397', 'KOG1646'}),
#  frozenset({'KOG1779', 'KOG2988'}),
#  frozenset({'KOG0052', 'KOG1749'}),
#  frozenset({'KOG0402', 'KOG1749'}),
#  frozenset({'KOG1727', 'KOG1762'}),
#  frozenset({'KOG1696', 'KOG1728'}),
#  frozenset({'KOG1570', 'KOG1646'}),
#  frozenset({'KOG1646', 'KOG1728'}),
#  frozenset({'KOG0397', 'KOG3475'}),
#  frozenset({'KOG1646', 'KOG1751'}),
#  frozenset({'KOG0378', 'KOG1646'}),
#  frozenset({'KOG1751', 'KOG2988'}),
#  frozenset({'KOG3486', 'KOG3499'}),
#  frozenset({'KOG1646', 'KOG1696'}),
#  frozenset({'KOG0402', 'KOG3311'}),
#  frozenset({'KOG1696', 'KOG1751'}),
#  frozenset({'KOG0402', 'KOG2988'}),
#  frozenset({'KOG1728', 'KOG1751'}),
#  frozenset({'KOG0378', 'KOG1779'}),
#  frozenset({'KOG1751', 'KOG3475'}),
#  frozenset({'KOG1646', 'KOG1779'}),
#  frozenset({'KOG1762', 'KOG1779'}),
#  frozenset({'KOG0052', 'KOG0378'}),
#  frozenset({'KOG1646', 'KOG3406'}),
#  frozenset({'KOG0877', 'KOG1762'}),
#  frozenset({'KOG1753', 'KOG3475'}),
#  frozenset({'KOG1751', 'KOG1779'}),
#  frozenset({'KOG0877', 'KOG1727'}),
#  frozenset({'KOG2988', 'KOG3475'}),
#  frozenset({'KOG1646', 'KOG3475'}),
#  frozenset({'KOG1749', 'KOG2988'}),
#  frozenset({'KOG1728', 'KOG1779'}),
#  frozenset({'KOG1722', 'KOG3475'}),
#  frozenset({'KOG1722', 'KOG3320'}),
#  frozenset({'KOG1722', 'KOG3486'}),
#  frozenset({'KOG0877', 'KOG1749'}),
#  frozenset({'KOG0378', 'KOG1751'}),
#  frozenset({'KOG0402', 'KOG1779'}),
#  frozenset({'KOG1646', 'KOG3320'}),
#  frozenset({'KOG0052', 'KOG3311'}),
#  frozenset({'KOG1728', 'KOG3418'}),
#  frozenset({'KOG1727', 'KOG1749'}),
#  frozenset({'KOG1728', 'KOG1749'}),
#  frozenset({'KOG1696', 'KOG1779'}),
#  frozenset({'KOG1751', 'KOG1762'}),
#  frozenset({'KOG1570', 'KOG1728'}),
#  frozenset({'KOG1727', 'KOG1751'}),
#  frozenset({'KOG0397', 'KOG1696'}),
#  frozenset({'KOG1570', 'KOG3475'}),
#  frozenset({'KOG1696', 'KOG1749'}),
#  frozenset({'KOG1570', 'KOG1696'}),
#  frozenset({'KOG1696', 'KOG2988'}),
#  frozenset({'KOG3320', 'KOG3504'}),
#  frozenset({'KOG1749', 'KOG1779'}),
#  frozenset({'KOG0877', 'KOG1751'}),
#  frozenset({'KOG0378', 'KOG1727'}),
#  frozenset({'KOG0052', 'KOG1779'}),
#  frozenset({'KOG1646', 'KOG2988'}),
#  frozenset({'KOG1646', 'KOG3418'}),
#  frozenset({'KOG1696', 'KOG3406'}),
#  frozenset({'KOG3320', 'KOG3475'}),
#  frozenset({'KOG0002', 'KOG1646'}),
#  frozenset({'KOG0002', 'KOG1779'}),
#  frozenset({'KOG0052', 'KOG0402'}),
#  frozenset({'KOG1728', 'KOG1753'}),
#  frozenset({'KOG2988', 'KOG3311'}),
#  frozenset({'KOG0002', 'KOG0402'}),
#  frozenset({'KOG1779', 'KOG3475'}),
#  frozenset({'KOG0397', 'KOG1728'}),
#  frozenset({'KOG1779', 'KOG3311'}),
#  frozenset({'KOG1646', 'KOG1727'}),
#  frozenset({'KOG1722', 'KOG3499'}),
#  frozenset({'KOG0829', 'KOG3291'}),
#  frozenset({'KOG0004', 'KOG3184'}),
#  frozenset({'KOG0898', 'KOG1728'}),
#  frozenset({'KOG0052', 'KOG1646'}),
#  frozenset({'KOG1728', 'KOG3311'}),
#  frozenset({'KOG0397', 'KOG3184'}),
#  frozenset({'KOG3436', 'KOG3499'}),
#  frozenset({'KOG1570', 'KOG3411'}),
#  frozenset({'KOG0002', 'KOG3311'}),
#  frozenset({'KOG1646', 'KOG1762'}),
#  frozenset({'KOG3418', 'KOG3499'}),
#  frozenset({'KOG1727', 'KOG2988'}),
#  frozenset({'KOG0402', 'KOG1751'}),
#  frozenset({'KOG0397', 'KOG1751'}),
#  frozenset({'KOG1696', 'KOG1753'}),
#  frozenset({'KOG1751', 'KOG3311'}),
#  frozenset({'KOG3475', 'KOG3486'}),
#  frozenset({'KOG0002', 'KOG3406'}),
#  frozenset({'KOG0402', 'KOG0877'}),
#  frozenset({'KOG0002', 'KOG1728'}),
#  frozenset({'KOG0397', 'KOG3418'}),
#  frozenset({'KOG0397', 'KOG3499'}),
#  frozenset({'KOG0886', 'KOG3499'}),
#  frozenset({'KOG0397', 'KOG3486'}),
#  frozenset({'KOG1728', 'KOG3406'}),
#  frozenset({'KOG1646', 'KOG3311'}),
#  frozenset({'KOG0898', 'KOG3499'}),
#  frozenset({'KOG3406', 'KOG3475'}),
#  frozenset({'KOG0378', 'KOG1728'}),
#  frozenset({'KOG1749', 'KOG3311'}),
#  frozenset({'KOG3418', 'KOG3486'}),
#  frozenset({'KOG0378', 'KOG0402'}),
#  frozenset({'KOG1728', 'KOG3320'}),
#  frozenset({'KOG0397', 'KOG1753'}),
#  frozenset({'KOG1646', 'KOG3184'}),
#  frozenset({'KOG0052', 'KOG0877'}),
#  frozenset({'KOG0397', 'KOG3320'}),
#  frozenset({'KOG0002', 'KOG3475'}),
#  frozenset({'KOG0886', 'KOG3475'}),
#  frozenset({'KOG1728', 'KOG3486'}),
#  frozenset({'KOG1749', 'KOG3344'}),
#  frozenset({'KOG0052', 'KOG1751'}),
#  frozenset({'KOG1727', 'KOG1728'}),
#  frozenset({'KOG1570', 'KOG3181'}),
#  frozenset({'KOG3544'}),
#  frozenset({'KOG1722', 'KOG3504'}),
#  frozenset({'KOG0878', 'KOG3344'}),
#  frozenset({'KOG0877', 'KOG3344'}),
#  frozenset({'KOG1646', 'KOG1753'}),
#  frozenset({'KOG2988', 'KOG3184'}),
#  frozenset({'KOG3475', 'KOG3504'}),
#  frozenset({'KOG0002', 'KOG2988'}),
#  frozenset({'KOG0002', 'KOG1727'}),
#  frozenset({'KOG1749', 'KOG3475'}),
#  frozenset({'KOG1696', 'KOG3320'}),
#  frozenset({'KOG1696', 'KOG3418'}),
#  frozenset({'KOG1751', 'KOG3406'}),
#  frozenset({'KOG0397', 'KOG0898'}),
#  frozenset({'KOG0402', 'KOG1646'}),
#  frozenset({'KOG0397', 'KOG2988'}),
#  frozenset({'KOG1570', 'KOG3184'}),
#  frozenset({'KOG3544'}),
#  frozenset({'KOG0746', 'KOG1570'}),
#  frozenset({'KOG3255', 'KOG3344'}),
#  frozenset({'KOG0402', 'KOG1728'}),
#  frozenset({'KOG0878', 'KOG1751'}),
#  frozenset({'KOG1779', 'KOG3344'}),
#  frozenset({'KOG1727', 'KOG3424'}),
#  frozenset({'KOG1570', 'KOG3436'}),
#  frozenset({'KOG1696', 'KOG3184'}),
#  frozenset({'KOG3436', 'KOG3504'}),
#  frozenset({'KOG2988', 'KOG3411'}),
#  frozenset({'KOG3418', 'KOG3475'}),
#  frozenset({'KOG1749', 'KOG3184'}),
#  frozenset({'KOG0402', 'KOG1727'}),
#  frozenset({'KOG0002', 'KOG1749'}),
#  frozenset({'KOG0815', 'KOG1570'}),
#  frozenset({'KOG1751', 'KOG1753'}),
#  frozenset({'ENOG502QQMH', 'KOG1124'}),
#  frozenset({'KOG0877', 'KOG3311'}),
#  frozenset({'KOG0397', 'KOG3406'}),
#  frozenset({'KOG3544'}),
#  frozenset({'KOG3544'}),
#  frozenset({'KOG0898', 'KOG3502'}),
#  frozenset({'KOG0378', 'KOG2988'}),
#  frozenset({'KOG0407', 'KOG3344'}),
#  frozenset({'KOG0898', 'KOG3486'}),
#  frozenset({'KOG1762', 'KOG3344'}),
#  frozenset({'KOG3320', 'KOG3418'}),
#  frozenset({'KOG0002', 'KOG1696'}),
#  frozenset({'KOG3184', 'KOG3320'}),
#  frozenset({'KOG1727', 'KOG1754'}),
#  frozenset({'KOG0402', 'KOG3475'}),
#  frozenset({'KOG0829', 'KOG1753'}),
#  frozenset({'KOG3436', 'KOG3475'}),
#  frozenset({'KOG3544'}),
#  frozenset({'ENOG502QQMH', 'KOG0941'}),
#  frozenset({'KOG0002', 'KOG3418'}),
#  frozenset({'KOG1779', 'KOG3255'}),
#  frozenset({'KOG0878', 'KOG3255'}),
#  frozenset({'KOG0378', 'KOG1866'}),
#  frozenset({'KOG0378', 'KOG1696'}),
#  frozenset({'KOG0397', 'KOG1722'}),
#  frozenset({'KOG0397', 'KOG1749'}),
#  frozenset({'KOG1696', 'KOG1727'}),
#  frozenset({'KOG0052', 'KOG2988'}),
#  frozenset({'KOG3499', 'KOG3504'}),
#  frozenset({'KOG3291', 'KOG3504'}),
#  frozenset({'KOG3544'}),
#  frozenset({'KOG1570', 'KOG1753'}),
#  frozenset({'KOG1728', 'KOG3411'}),
#  frozenset({'KOG1779', 'KOG3406'}),
#  frozenset({'KOG0887', 'KOG3184'}),
#  frozenset({'KOG0875', 'KOG1475'}),
#  frozenset({'KOG1696', 'KOG3311'}),
#  frozenset({'KOG1696', 'KOG3504'}),
#  frozenset({'KOG3486', 'KOG3504'}),
#  frozenset({'KOG0052', 'KOG1762'}),
#  frozenset({'KOG3475', 'KOG3506'}),
#  frozenset({'KOG3184', 'KOG3418'}),
#  frozenset({'KOG0886', 'KOG1570'}),
#  frozenset({'KOG1628', 'KOG3184'}),
#  frozenset({'KOG3184', 'KOG3434'}),
#  frozenset({'KOG3291', 'KOG3320'}),
#  frozenset({'KOG1762', 'KOG3255'}),
#  frozenset({'KOG3544'}),
#  frozenset({'KOG0402', 'KOG3184'}),
#  frozenset({'KOG1751', 'KOG3344'}),
#  frozenset({'KOG2988', 'KOG3406'}),
#  frozenset({'KOG0877', 'KOG1779'}),
#  frozenset({'KOG1696', 'KOG1722'}),
#  frozenset({'KOG0829', 'KOG3411'}),
#  frozenset({'KOG1728', 'KOG3504'}),
#  frozenset({'KOG1570', 'KOG3504'}),
#  frozenset({'KOG1753', 'KOG3418'}),
#  frozenset({'KOG0402', 'KOG3418'}),
#  frozenset({'KOG1749', 'KOG1762'}),
#  frozenset({'KOG0877', 'KOG1754'}),
#  frozenset({'KOG1696', 'KOG1762'}),
#  frozenset({'ENOG502QQMH', 'KOG0446'}),
#  frozenset({'KOG1577'}),
#  frozenset({'KOG0746', 'KOG1475'}),
#  frozenset({'KOG0052', 'KOG1754'}),
#  frozenset({'KOG1646', 'KOG3204'}),
#  frozenset({'KOG1475', 'KOG1570'}),
#  frozenset({'KOG0941', 'KOG1124'}),
#  frozenset({'KOG3544'}),
#  frozenset({'KOG1728', 'KOG3204'}),
#  frozenset({'KOG0052', 'KOG3344'}),
#  frozenset({'KOG1751', 'KOG3255'}),
#  frozenset({'KOG1754', 'KOG3344'}),
#  frozenset({'KOG0887', 'KOG1722'}),
#  frozenset({'KOG0355', 'KOG0594'}),
#  frozenset({'ENOG502QQMH', 'KOG0001'}),
#  frozenset({'KOG0829', 'KOG3504'}),
#  frozenset({'KOG0001', 'KOG1124'}),
#  frozenset({'KOG1570', 'KOG3291'}),
#  frozenset({'KOG3544'}),
#  frozenset({'KOG1749', 'KOG3204'}),
#  frozenset({'KOG0887', 'KOG1628'}),
#  frozenset({'KOG0001', 'KOG0941'}),
#  frozenset({'KOG0878', 'KOG1749'}),
#  frozenset({'KOG1762', 'KOG3311'}),
#  frozenset({'KOG0187', 'KOG1646'}),
#  frozenset({'KOG0402', 'KOG1762'}),
#  frozenset({'KOG1696', 'KOG3204'}),
#  frozenset({'KOG1722', 'KOG3434'}),
#  frozenset({'KOG1646', 'KOG3434'}),
#  frozenset({'KOG0407', 'KOG0877'}),
#  frozenset({'KOG0898', 'KOG3475'}),
#  frozenset({'KOG0446', 'KOG1124'}),
#  frozenset({'KOG1727', 'KOG3344'}),
#  frozenset({'KOG3418', 'KOG3436'}),
#  frozenset({'KOG0187', 'KOG0402'}),
#  frozenset({'KOG1628', 'KOG1646'}),
#  frozenset({'KOG3311', 'KOG3344'}),
#  frozenset({'KOG0887', 'KOG3320'}),
#  frozenset({'KOG3544'}),
#  frozenset({'KOG2988', 'KOG3255'}),
#  frozenset({'KOG0875', 'KOG3283'}),
#  frozenset({'KOG0887', 'KOG3434'}),
#  frozenset({'KOG0829', 'KOG0898'}),
#  frozenset({'KOG1570', 'KOG1722'}),
#  frozenset({'KOG3320', 'KOG3436'}),
#  frozenset({'KOG3544'}),
#  frozenset({'KOG0378', 'KOG3311'}),
#  frozenset({'KOG0052', 'KOG3424'}),
#  frozenset({'KOG0878', 'KOG1646'}),
#  frozenset({'KOG0397', 'KOG3434'}),
#  frozenset({'KOG0397', 'KOG0886'}),
#  frozenset({'KOG1742', 'KOG1749'}),
#  frozenset({'KOG3544'}),
#  frozenset({'KOG0878', 'KOG1728'}),
#  frozenset({'KOG0243', 'KOG1166'}),
#  frozenset({'KOG0407', 'KOG1749'}),
#  frozenset({'KOG1646', 'KOG3283'}),
#  frozenset({'KOG0354', 'KOG0941'}),
#  frozenset({'KOG1475', 'KOG3283'}),
#  frozenset({'KOG1570', 'KOG1749'}),
#  frozenset({'KOG1728', 'KOG3344'}),
#  frozenset({'KOG0901', 'KOG3184'}),
#  frozenset({'KOG1646', 'KOG1767'}),
#  frozenset({'KOG0354'}),
#  frozenset({'KOG1124'}),
#  frozenset({'KOG1722', 'KOG1728'}),
#  frozenset({'KOG0192', 'KOG0355'}),
#  frozenset({'KOG1728', 'KOG3255'}),
#  frozenset({'KOG1475', 'KOG1646'}),
#  frozenset({'KOG1727', 'KOG3255'}),
#  frozenset({'KOG3291', 'KOG3486'}),
#  frozenset({'KOG3311', 'KOG3475'}),
#  frozenset({'KOG1475', 'KOG3320'}),
#  frozenset({'KOG0407', 'KOG1762'}),
#  frozenset({'KOG0378', 'KOG3344'}),
#  frozenset({'KOG0878', 'KOG1779'}),
#  frozenset({'KOG3320', 'KOG3486'}),
#  frozenset({'KOG0002', 'KOG0378'}),
#  frozenset({'KOG1728', 'KOG1762'}),
#  frozenset({'KOG0407', 'KOG1751'}),
#  frozenset({'KOG1762', 'KOG3424'}),
#  frozenset({'KOG0887', 'KOG2988'}),
#  frozenset({'KOG3544'}),
#  frozenset({'KOG0898', 'KOG3504'}),
#  frozenset({'KOG1749', 'KOG3255'}),
#  frozenset({'KOG1570', 'KOG1779'}),
#  frozenset({'KOG1570', 'KOG3283'}),
#  frozenset({'KOG0402', 'KOG3424'}),
#  frozenset({'KOG0244', 'KOG0355'}),
#  frozenset({'KOG0886', 'KOG3504'}),
#  frozenset({'KOG0898', 'KOG1646'}),
#  frozenset({'KOG1628', 'KOG3320'}),
#  frozenset({'KOG1866', 'KOG3403'}),
#  frozenset({'KOG0407', 'KOG0878'}),
#  frozenset({'KOG0875', 'KOG3434'}),
#  frozenset({'KOG1762', 'KOG3406'}),
#  frozenset({'KOG1714', 'KOG3291'}),
#  frozenset({'KOG0875', 'KOG3320'}),
#  frozenset({'KOG0397', 'KOG0400'}),
#  frozenset({'KOG0397', 'KOG3401'}),
#  frozenset({'KOG0746', 'KOG3311'}),
#  frozenset({'KOG0875', 'KOG1570'}),
#  frozenset({'KOG1749', 'KOG3504'}),
#  frozenset({'KOG3418', 'KOG3504'}),
#  frozenset({'KOG1742', 'KOG3204'}),
#  frozenset({'KOG1754', 'KOG1779'}),
#  frozenset({'KOG1728', 'KOG3506'}),
#  frozenset({'KOG0898', 'KOG3418'}),
#  frozenset({'KOG0875', 'KOG3184'}),
#  frozenset({'KOG0594', 'KOG1826'}),
#  frozenset({'KOG1767', 'KOG3320'}),
#  frozenset({'KOG0192', 'KOG0594'}),
#  frozenset({'KOG1762', 'KOG2988'}),
#  frozenset({'KOG0829', 'KOG1728'}),
#  frozenset({'KOG1727', 'KOG3406'}),
#  frozenset({'KOG0243', 'KOG0355'}),
#  frozenset({'KOG0052', 'KOG1728'}),
#  frozenset({'KOG1754', 'KOG3311'}),
#  frozenset({'KOG1722', 'KOG3184'}),
#  frozenset({'KOG0407', 'KOG3311'}),
#  frozenset({'KOG3311', 'KOG3406'}),
#  frozenset({'KOG2988', 'KOG3344'}),
#  frozenset({'KOG0878', 'KOG2988'}),
#  frozenset({'KOG1696', 'KOG3436'}),
#  frozenset({'KOG0402', 'KOG3486'}),
#  frozenset({'KOG1696', 'KOG1767'}),
#  frozenset({'KOG0878', 'KOG3475'}),
#  frozenset({'KOG0400', 'KOG1646'}),
#  frozenset({'KOG0397', 'KOG0402'}),
#  frozenset({'KOG0400', 'KOG1722'}),
#  frozenset({'KOG0243', 'KOG0995'}),
#  frozenset({'KOG0653', 'KOG0654'}),
#  frozenset({'KOG1646', 'KOG3411'}),
#  frozenset({'KOG0187', 'KOG1749'}),
#  frozenset({'KOG1628', 'KOG1749'}),
#  frozenset({'KOG1646', 'KOG3344'}),
#  frozenset({'KOG0901', 'KOG1646'}),
#  frozenset({'KOG0354', 'KOG0446'}),
#  frozenset({'KOG0001', 'KOG0941'}),
#  frozenset({'KOG0887', 'KOG3418'}),
#  frozenset({'ENOG502QQMH', 'KOG1124'}),
#  frozenset({'KOG0402', 'KOG0887'}),
#  frozenset({'KOG1749', 'KOG3418'}),
#  frozenset({'KOG1124'}),
#  frozenset({'KOG0378', 'KOG3406'}),
#  frozenset({'KOG0001'}),
#  frozenset({'KOG2037'}),
#  frozenset({'KOG0397', 'KOG0901'}),
#  frozenset({'KOG0901', 'KOG3434'}),
#  frozenset({'KOG1646', 'KOG3401'}),
#  frozenset({'KOG3436', 'KOG3486'}),
#  frozenset({'KOG1728', 'KOG3502'}),
#  frozenset({'KOG0187', 'KOG3204'}),
#  frozenset({'KOG1646', 'KOG3436'}),
#  frozenset({'KOG1475', 'KOG3184'}),
#  frozenset({'KOG0402', 'KOG1696'}),
#  frozenset({'KOG0400', 'KOG2988'}),
#  frozenset({'KOG0875', 'KOG1646'}),
#  frozenset({'KOG1646', 'KOG1732'}),
#  frozenset({'KOG0187', 'KOG3283'}),
#  frozenset({'KOG0187', 'KOG2988'}),
#  frozenset({'KOG0001', 'KOG0446'}),
#  frozenset({'KOG0001', 'KOG1124'}),
#  frozenset({'KOG0407', 'KOG3255'}),
#  frozenset({'KOG0402', 'KOG1722'}),
#  frozenset({'KOG2988', 'KOG3434'}),
#  frozenset({'KOG1628', 'KOG2988'}),
#  frozenset({'KOG1722', 'KOG1767'}),
#  frozenset({'KOG0446', 'KOG0941'}),
#  frozenset({'KOG3283', 'KOG3320'}),
#  frozenset({'KOG0355', 'KOG0654'}),
#  frozenset({'KOG3320', 'KOG3499'}),
#  frozenset({'KOG0407', 'KOG1779'}),
#  frozenset({'KOG0397', 'KOG1742'}),
#  frozenset({'KOG0355', 'KOG1166'}),
#  frozenset({'KOG1475', 'KOG1628'}),
#  frozenset({'KOG0244', 'KOG0653'}),
#  frozenset({'KOG1646', 'KOG1722'}),
#  frozenset({'KOG0402', 'KOG3504'}),
#  frozenset({'KOG0402', 'KOG3204'}),
#  frozenset({'KOG0400', 'KOG3434'}),
#  frozenset({'KOG0378', 'KOG3403'}),
#  frozenset({'KOG0397', 'KOG1779'}),
#  frozenset({'KOG1728', 'KOG3499'}),
#  frozenset({'ENOG502QQMH', 'KOG0001'}),
#  frozenset({'KOG0002', 'KOG3255'}),
#  frozenset({'KOG3184', 'KOG3283'}),
#  frozenset({'KOG0187', 'KOG3184'}),
#  frozenset({'KOG1749', 'KOG3411'}),
#  frozenset({'KOG1749', 'KOG3434'}),
#  frozenset({'KOG0407', 'KOG2988'}),
#  frozenset({'KOG0001', 'KOG0446'}),
#  frozenset({'KOG0187', 'KOG3504'}),
#  frozenset({'KOG0378', 'KOG0877'}),
#  frozenset({'KOG0746', 'KOG3283'}),
#  frozenset({'KOG3486', 'KOG3506'}),
#  frozenset({'KOG3255', 'KOG3424'}),
#  frozenset({'KOG0400', 'KOG0887'}),
#  frozenset({'KOG0187', 'KOG1475'}),
#  frozenset({'KOG3283', 'KOG3436'}),
#  frozenset({'KOG0941', 'KOG1124'}),
#  frozenset({'KOG0187', 'KOG1696'}),
#  frozenset({'KOG1722', 'KOG3418'}),
#  frozenset({'KOG0187', 'KOG3436'}),
#  frozenset({'KOG1628', 'KOG3283'}),
#  frozenset({'KOG0355', 'KOG0653'}),
#  frozenset({'KOG0187', 'KOG0397'}),
#  frozenset({'KOG0653', 'KOG1166'}),
#  frozenset({'KOG1646', 'KOG3255'}),
#  frozenset({'KOG3204', 'KOG3504'}),
#  frozenset({'KOG0878', 'KOG1762'}),
#  frozenset({'KOG1628', 'KOG3434'}),
#  frozenset({'KOG1475', 'KOG3204'}),
#  frozenset({'KOG1753', 'KOG1779'}),
#  frozenset({'KOG1475', 'KOG3434'}),
#  frozenset({'KOG0746', 'KOG0875'}),
#  frozenset({'KOG1749', 'KOG1754'}),
#  frozenset({'KOG3311', 'KOG3418'}),
#  frozenset({'KOG3184', 'KOG3504'}),
#  frozenset({'KOG3255', 'KOG3311'}),
#  frozenset({'KOG0397', 'KOG1732'}),
#  frozenset({'KOG0653'}),
#  frozenset({'KOG0886', 'KOG1646'}),
#  frozenset({'KOG1475', 'KOG3504'}),
#  frozenset({'KOG0378', 'KOG3475'}),
#  frozenset({'KOG0887', 'KOG0901'}),
#  frozenset({'KOG0402', 'KOG3434'}),
#  frozenset({'KOG0244', 'KOG1826'}),
#  frozenset({'KOG3406', 'KOG3418'}),
#  frozenset({'KOG0402', 'KOG1570'}),
#  frozenset({'KOG1570', 'KOG1751'}),
#  frozenset({'KOG0243', 'KOG4280'}),
#  frozenset({'KOG0875', 'KOG0901'}),
#  frozenset({'KOG1753', 'KOG3320'}),
#  frozenset({'KOG0886', 'KOG1728'}),
#  frozenset({'KOG0400', 'KOG3418'}),
#  frozenset({'KOG3283', 'KOG3434'}),
#  frozenset({'KOG0901', 'KOG3283'}),
#  frozenset({'KOG3204', 'KOG3475'}),
#  frozenset({'KOG3418', 'KOG3434'}),
#  frozenset({'KOG1714', 'KOG3204'}),
#  frozenset({'KOG0877', 'KOG3255'}),
#  frozenset({'KOG0002', 'KOG0878'}),
#  frozenset({'KOG0898', 'KOG3311'}),
#  frozenset({'KOG0052', 'KOG3255'}),
#  frozenset({'KOG1646', 'KOG3486'}),
#  frozenset({'KOG0397', 'KOG0887'}),
#  frozenset({'KOG0875', 'KOG1722'}),
#  frozenset({'KOG1732', 'KOG3184'}),
#  frozenset({'KOG1749', 'KOG3320'}),
#  frozenset({'KOG0878', 'KOG1696'}),
#  frozenset({'KOG3166', 'KOG3204'}),
#  frozenset({'KOG1714', 'KOG3320'}),
#  frozenset({'KOG0355', 'KOG4280'}),
#  frozenset({'KOG0397', 'KOG3504'}),
#  frozenset({'KOG0354', 'KOG1124'}),
#  frozenset({'KOG0400', 'KOG0402'}),
#  frozenset({'KOG0654', 'KOG1826'}),
#  frozenset({'KOG1749', 'KOG3401'}),
#  frozenset({'KOG1646', 'KOG3499'}),
#  frozenset({'KOG0875', 'KOG3401'}),
#  frozenset({'KOG0400', 'KOG3184'}),
#  frozenset({'KOG0446', 'KOG1124'}),
#  frozenset({'KOG0898', 'KOG3291'}),
#  frozenset({'ENOG502QQMH', 'KOG0354'}),
#  frozenset({'KOG1246', 'KOG1866'}),
#  frozenset({'KOG0052', 'KOG1696'}),
#  frozenset({'KOG1696', 'KOG3411'}),
#  frozenset({'KOG3204', 'KOG3311'}),
#  frozenset({'KOG1754', 'KOG3255'}),
#  frozenset({'KOG3311', 'KOG3424'}),
#  frozenset({'KOG0878', 'KOG1754'}),
#  frozenset({'KOG0402', 'KOG3406'}),
#  frozenset({'KOG0402', 'KOG3436'}),
#  frozenset({'KOG3184', 'KOG3401'}),
#  frozenset({'KOG1754', 'KOG1762'}),
#  frozenset({'KOG1628', 'KOG1728'}),
#  frozenset({'KOG0829', 'KOG3486'}),
#  frozenset({'KOG1762', 'KOG3475'}),
#  frozenset({'KOG0400', 'KOG1732'}),
#  frozenset({'KOG1475', 'KOG1696'}),
#  frozenset({'KOG1767', 'KOG3283'}),
#  frozenset({'KOG1728', 'KOG3412'}),
#  frozenset({'KOG0001', 'KOG1124'}),
#  frozenset({'KOG0305', 'KOG0653'}),
#  frozenset({'ENOG502QQMH', 'KOG1863'}),
#  frozenset({'KOG0402', 'KOG1767'}),
#  frozenset({'KOG0244', 'KOG1166'}),
#  frozenset({'KOG3204', 'KOG3502'}),
#  frozenset({'KOG0877', 'KOG0878'}),
#  frozenset({'KOG1646', 'KOG3504'}),
#  frozenset({'KOG3418', 'KOG3502'}),
#  frozenset({'KOG3255', 'KOG3475'}),
#  frozenset({'KOG0878', 'KOG1753'}),
#  frozenset({'KOG0875', 'KOG0887'}),
#  frozenset({'KOG3401', 'KOG3504'}),
#  frozenset({'KOG1732', 'KOG3204'}),
#  frozenset({'KOG0898', 'KOG3412'}),
#  frozenset({'KOG0901', 'KOG1628'}),
#  frozenset({'KOG3255', 'KOG3412'}),
#  frozenset({'KOG0187', 'KOG3418'}),
#  frozenset({'KOG3184', 'KOG3204'}),
#  frozenset({'KOG0354', 'KOG1124'}),
#  frozenset({'KOG0397', 'KOG3283'}),
#  frozenset({'KOG0887', 'KOG1728'}),
#  frozenset({'KOG0187', 'KOG3320'}),
#  frozenset({'KOG0875', 'KOG1628'}),
#  frozenset({'KOG3475', 'KOG3502'}),
#  frozenset({'KOG1767', 'KOG3475'}),
#  frozenset({'KOG0402', 'KOG3255'}),
#  frozenset({'KOG0939', 'KOG1727'}),
#  frozenset({'KOG1754', 'KOG3424'}),
#  frozenset({'KOG1628', 'KOG3401'}),
#  frozenset({'KOG1767', 'KOG3401'}),
#  frozenset({'KOG0877', 'KOG3424'}),
#  frozenset({'KOG0378', 'KOG1762'}),
#  frozenset({'KOG0654', 'KOG1166'}),
#  frozenset({'KOG1790', 'KOG3255'}),
#  frozenset({'KOG0355', 'KOG0995'}),
#  frozenset({'KOG1696', 'KOG3434'}),
#  frozenset({'KOG0187', 'KOG3401'}),
#  frozenset({'KOG1696', 'KOG3291'}),
#  frozenset({'KOG3283', 'KOG3475'}),
#  frozenset({'KOG0407', 'KOG1728'}),
#  frozenset({'KOG0407', 'KOG1727'}),
#  frozenset({'KOG1696', 'KOG3506'}),
#  frozenset({'KOG0594', 'KOG0654'}),
#  frozenset({'KOG0654', 'KOG0995'}),
#  frozenset({'KOG3434', 'KOG3504'}),
#  frozenset({'KOG0887', 'KOG3475'}),
#  frozenset({'KOG0402', 'KOG3283'}),
#  frozenset({'KOG1646', 'KOG1742'}),
#  frozenset({'KOG3283', 'KOG3486'}),
#  frozenset({'KOG0619', 'KOG3544'}),
#  frozenset({'KOG0397', 'KOG3204'}),
#  frozenset({'KOG1744', 'KOG1756'}),
#  frozenset({'KOG1767', 'KOG3184'}),
#  frozenset({'KOG1732', 'KOG3434'}),
#  frozenset({'KOG1779', 'KOG3411'}),
#  frozenset({'KOG0901', 'KOG3401'}),
#  frozenset({'KOG1646', 'KOG3424'}),
#  frozenset({'KOG0877', 'KOG3502'}),
#  frozenset({'KOG3204', 'KOG3283'}),
#  frozenset({'KOG1475', 'KOG3291'}),
#  frozenset({'KOG0052', 'KOG0407'}),
#  frozenset({'KOG0247', 'KOG0355'}),
#  frozenset({'KOG1751', 'KOG3204'}),
#  frozenset({'KOG0898', 'KOG3436'}),
#  frozenset({'KOG3311', 'KOG3486'}),
#  frozenset({'KOG1749', 'KOG3283'}),
#  frozenset({'KOG0187', 'KOG3475'}),
#  frozenset({'KOG3320', 'KOG3411'}),
#  frozenset({'KOG3311', 'KOG3320'}),
#  frozenset({'KOG2037', 'KOG2145'}),
#  frozenset({'KOG1570', 'KOG1767'}),
#  frozenset({'KOG0001', 'KOG1124'}),
#  frozenset({'KOG0355', 'KOG1826'}),
#  frozenset({'KOG1475', 'KOG1714'}),
#  frozenset({'KOG0878', 'KOG3311'}),
#  frozenset({'KOG2988', 'KOG3320'}),
#  frozenset({'KOG1753', 'KOG3291'}),
#  frozenset({'KOG0887', 'KOG1570'}),
#  frozenset({'KOG0378', 'KOG3184'}),
#  frozenset({'KOG0829', 'KOG1714'}),
#  frozenset({'KOG0901', 'KOG1732'}),
#  frozenset({'KOG0187', 'KOG1732'}),
#  frozenset({'KOG0594', 'KOG1166'}),
#  frozenset({'KOG0594', 'KOG0995'}),
#  frozenset({'KOG0397', 'KOG1628'}),
#  frozenset({'KOG0187', 'KOG1779'}),
#  frozenset({'KOG0247', 'KOG0653'}),
#  frozenset({'KOG0446', 'KOG0941'}),
#  frozenset({'KOG0829', 'KOG1646'}),
#  frozenset({'KOG0002', 'KOG3344'}),
#  frozenset({'KOG0887', 'KOG3504'}),
#  frozenset({'KOG1696', 'KOG3283'}),
#  frozenset({'KOG0594', 'KOG2025'}),
#  frozenset({'KOG0247', 'KOG0654'}),
#  frozenset({'KOG0402', 'KOG1628'}),
#  frozenset({'KOG1722', 'KOG2988'}),
#  frozenset({'KOG0829', 'KOG1570'}),
#  frozenset({'KOG0244', 'KOG0247'}),
#  frozenset({'KOG1475', 'KOG1767'}),
#  frozenset({'KOG0378', 'KOG0878'}),
#  frozenset({'KOG0898', 'KOG1753'}),
#  frozenset({'KOG1779', 'KOG3424'}),
#  frozenset({'KOG1727', 'KOG3475'}),
#  frozenset({'KOG1646', 'KOG3181'}),
#  frozenset({'KOG1696', 'KOG3255'}),
#  frozenset({'KOG0402', 'KOG0901'}),
#  frozenset({'KOG0995', 'KOG1166'}),
#  frozenset({'KOG0594', 'KOG0673'}),
#  frozenset({'KOG1779', 'KOG3502'}),
#  frozenset({'KOG1790', 'KOG3344'}),
#  frozenset({'KOG0402', 'KOG1732'}),
#  frozenset({'KOG0243', 'KOG0654'}),
#  frozenset({'KOG0407', 'KOG1754'}),
#  frozenset({'KOG0407', 'KOG1696'}),
#  frozenset({'KOG3401', 'KOG3475'}),
#  frozenset({'KOG0400', 'KOG1749'}),
#  frozenset({'KOG3344', 'KOG3412'}),
#  frozenset({'KOG0402', 'KOG3344'}),
#  frozenset({'KOG3184', 'KOG3486'}),
#  frozenset({'KOG0244', 'KOG2025'}),
#  frozenset({'KOG1732', 'KOG1749'}),
#  frozenset({'KOG0878', 'KOG3506'}),
#  frozenset({'KOG0995', 'KOG2025'}),
#  frozenset({'KOG0887', 'KOG3283'}),
#  frozenset({'KOG0887', 'KOG1767'}),
#  frozenset({'KOG0355', 'KOG0673'}),
#  frozenset({'KOG0247', 'KOG1720'}),
#  frozenset({'KOG0192', 'KOG0995'}),
#  frozenset({'KOG0898', 'KOG3506'}),
#  frozenset({'KOG1767', 'KOG3434'}),
#  frozenset({'KOG1721', 'KOG1866'}),
#  frozenset({'KOG1753', 'KOG3506'}),
#  frozenset({'KOG1124'}),
#  frozenset({'KOG1722', 'KOG3506'}),
#  frozenset({'KOG0187', 'KOG1728'}),
#  frozenset({'KOG0995', 'KOG4280'}),
#  frozenset({'KOG3344', 'KOG3424'}),
#  frozenset({'KOG0002', 'KOG3184'}),
#  frozenset({'KOG3184', 'KOG3475'}),
#  frozenset({'KOG1628', 'KOG1732'}),
#  frozenset({'KOG1728', 'KOG1767'}),
#  frozenset({'KOG1628', 'KOG1767'}),
#  frozenset({'KOG0875', 'KOG1749'}),
#  frozenset({'KOG1124', 'KOG2037'}),
#  frozenset({'KOG0941', 'KOG1863'}),
#  frozenset({'KOG0878', 'KOG0898'}),
#  frozenset({'KOG1714', 'KOG3283'}),
#  frozenset({'KOG0402', 'KOG0898'}),
#  frozenset({'KOG1749', 'KOG3424'}),
#  frozenset({'KOG0378', 'KOG1246'}),
#  frozenset({'KOG3283', 'KOG3418'}),
#  frozenset({'KOG3283', 'KOG3401'}),
#  frozenset({'KOG0001', 'KOG1863'}),
#  frozenset({'KOG1753', 'KOG3486'}),
#  frozenset({'KOG0898', 'KOG1749'}),
#  frozenset({'KOG0187', 'KOG0887'}),
#  frozenset({'KOG0187', 'KOG1767'}),
#  frozenset({'KOG0887', 'KOG1749'}),
#  frozenset({'KOG0877', 'KOG2988'}),
#  frozenset({'KOG3320', 'KOG3506'}),
#  frozenset({'KOG2988', 'KOG3401'}),
#  frozenset({'KOG0653', 'KOG4280'}),
#  frozenset({'KOG0244', 'KOG4280'}),
#  frozenset({'KOG3283', 'KOG3291'}),
#  frozenset({'KOG1728', 'KOG3184'}),
#  frozenset({'KOG1728', 'KOG3291'}),
#  frozenset({'KOG0746', 'KOG3166'}),
#  frozenset({'KOG1696', 'KOG3344'}),
#  frozenset({'KOG0187', 'KOG1751'}),
#  frozenset({'KOG1570', 'KOG3204'}),
#  frozenset({'KOG0247', 'KOG0995'}),
#  frozenset({'KOG1742', 'KOG3401'}),
#  frozenset({'KOG0354', 'KOG1124'}),
#  frozenset({'KOG0878', 'KOG0893'}),
#  frozenset({'KOG3283', 'KOG3504'}),
#  frozenset({'ENOG502QQMH', 'KOG1124'}),
#  frozenset({'KOG0243', 'KOG0594'}),
#  frozenset({'KOG2988', 'KOG3499'}),
#  frozenset({'KOG0654', 'KOG4280'}),
#  frozenset({'KOG0002', 'KOG1762'}),
#  frozenset({'KOG0142', 'KOG1393'}),
#  frozenset({'KOG0354', 'KOG1863'}),
#  frozenset({'KOG3320', 'KOG3401'}),
#  frozenset({'KOG1754', 'KOG2988'}),
#  frozenset({'KOG1646', 'KOG3506'}),
#  frozenset({'KOG1722', 'KOG1753'}),
#  frozenset({'KOG3291', 'KOG3418'}),
#  frozenset({'KOG1584'}),
#  frozenset({'KOG3204', 'KOG3320'}),
#  frozenset({'KOG1732', 'KOG3401'}),
#  frozenset({'KOG0378', 'KOG1570'}),
#  frozenset({'KOG0400', 'KOG3475'}),
#  frozenset({'KOG0378', 'KOG3255'}),
#  frozenset({'KOG2988', 'KOG3424'}),
#  frozenset({'KOG0247', 'KOG0653'}),
#  frozenset({'KOG0893', 'KOG3475'}),
#  frozenset({'KOG1696', 'KOG3499'}),
#  frozenset({'KOG1696', 'KOG1742'}),
#  frozenset({'KOG0378', 'KOG3411'}),
#  frozenset({'KOG0887', 'KOG3401'}),
#  frozenset({'KOG0901', 'KOG3166'}),
#  frozenset({'KOG1696', 'KOG3502'}),
#  frozenset({'KOG1570', 'KOG3255'}),
#  frozenset({'KOG0878', 'KOG3412'}),
#  frozenset({'KOG2988', 'KOG3283'}),
#  frozenset({'KOG1696', 'KOG1732'}),
#  frozenset({'KOG0243', 'KOG2025'}),
#  frozenset({'KOG0402', 'KOG1475'}),
#  frozenset({'KOG1475', 'KOG1749'}),
#  frozenset({'KOG1722', 'KOG3283'}),
#  frozenset({'KOG3204', 'KOG3436'}),
#  frozenset({'KOG0001', 'KOG0354'}),
#  frozenset({'KOG1732', 'KOG3406'}),
#  frozenset({'KOG0878', 'KOG1570'}),
#  frozenset({'KOG0878', 'KOG1727'}),
#  frozenset({'KOG0004', 'KOG3311'}),
#  frozenset({'KOG0239', 'KOG0244'}),
#  frozenset({'KOG0878', 'KOG3406'}),
#  frozenset({'KOG1628', 'KOG1742'}),
#  frozenset({'KOG3255', 'KOG3406'}),
#  frozenset({'KOG3320', 'KOG3434'}),
#  frozenset({'KOG1646', 'KOG3166'}),
#  frozenset({'KOG0402', 'KOG1754'}),
#  frozenset({'KOG1751', 'KOG1790'}),
#  frozenset({'KOG0239', 'KOG2025'}),
#  frozenset({'KOG0243', 'KOG0653'}),
#  frozenset({'KOG1720', 'KOG1826'}),
#  frozenset({'KOG0877', 'KOG1696'}),
#  frozenset({'KOG0887', 'KOG3486'}),
#  frozenset({'KOG0407', 'KOG1646'}),
#  frozenset({'KOG3406', 'KOG3502'}),
#  frozenset({'KOG3181', 'KOG3486'}),
#  frozenset({'KOG1749', 'KOG3406'}),
#  frozenset({'KOG0244', 'KOG0653'}),
#  frozenset({'KOG0898', 'KOG1696'}),
#  frozenset({'KOG0187', 'KOG3291'}),
#  frozenset({'KOG0247', 'KOG4280'}),
#  frozenset({'KOG0400', 'KOG3401'}),
#  frozenset({'KOG0654', 'KOG2025'}),
#  frozenset({'KOG0901', 'KOG3320'}),
#  frozenset({'KOG0397', 'KOG0875'}),
#  frozenset({'KOG1745', 'KOG1826'}),
#  frozenset({'KOG0887', 'KOG1475'}),
#  frozenset({'KOG1751', 'KOG1754'}),
#  frozenset({'KOG0397', 'KOG1570'}),
#  frozenset({'KOG0654', 'KOG0950'}),
#  frozenset({'KOG0187', 'KOG1570'}),
#  frozenset({'KOG3544'}),
#  frozenset({'KOG1753', 'KOG3255'}),
#  frozenset({'KOG1714', 'KOG3411'}),
#  frozenset({'KOG3401', 'KOG3418'}),
#  frozenset({'KOG1628', 'KOG3504'}),
#  frozenset({'KOG1728', 'KOG3283'}),
#  frozenset({'KOG0247', 'KOG0305'}),
#  frozenset({'KOG1751', 'KOG3424'}),
#  frozenset({'KOG1570', 'KOG3506'}),
#  frozenset({'KOG1570', 'KOG1714'}),
#  frozenset({'KOG0893', 'KOG1646'}),
#  frozenset({'KOG1779', 'KOG3412'}),
#  frozenset({'KOG0402', 'KOG3411'}),
#  frozenset({'KOG0003', 'KOG0898'}),
#  frozenset({'KOG0941'}),
#  frozenset({'KOG0878', 'KOG1790'}),
#  frozenset({'KOG1722', 'KOG3401'}),
#  frozenset({'KOG0187', 'KOG3406'}),
#  frozenset({'KOG1722', 'KOG3436'}),
#  frozenset({'KOG1475', 'KOG3166'}),
#  frozenset({'KOG0002', 'KOG3486'}),
#  frozenset({'KOG0402', 'KOG3502'}),
#  frozenset({'KOG1166', 'KOG2025'}),
#  frozenset({'KOG0898', 'KOG3344'}),
#  frozenset({'KOG3311', 'KOG3434'}),
#  frozenset({'KOG1753', 'KOG3412'}),
#  frozenset({'KOG1714', 'KOG3504'}),
#  frozenset({'KOG1124', 'KOG2037'}),
#  frozenset({'KOG0004', 'KOG0857'}),
#  frozenset({'KOG0653', 'KOG0995'}),
#  frozenset({'KOG0400', 'KOG1696'}),
#  frozenset({'KOG2025', 'KOG4280'}),
#  frozenset({'KOG0378', 'KOG0397'}),
#  frozenset({'KOG3204', 'KOG3434'}),
#  frozenset({'KOG0877', 'KOG1646'}),
#  frozenset({'KOG0244', 'KOG0594'}),
#  frozenset({'KOG1749', 'KOG1753'}),
#  frozenset({'KOG0901', 'KOG3499'}),
#  frozenset({'KOG0004', 'KOG0378'}),
#  frozenset({'KOG0886', 'KOG3506'}),
#  frozenset({'KOG0400', 'KOG3504'}),
#  frozenset({'KOG3499', 'KOG3506'}),
#  frozenset({'KOG1749', 'KOG1790'}),
#  frozenset({'KOG3401', 'KOG3436'}),
#  frozenset({'KOG1628', 'KOG1722'}),
#  frozenset({'KOG0203', 'KOG3927'}),
#  frozenset({'KOG0002', 'KOG0939'}),
#  frozenset({'KOG1570', 'KOG3486'}),
#  frozenset({'KOG0187', 'KOG1628'}),
#  frozenset({'KOG1722', 'KOG3291'}),
#  frozenset({'KOG0939', 'KOG1779'}),
#  frozenset({'KOG1779', 'KOG1790'}),
#  frozenset({'KOG0397', 'KOG3506'}),
#  frozenset({'KOG0187', 'KOG3311'}),
#  frozenset({'KOG0878', 'KOG0886'}),
#  frozenset({'KOG2988', 'KOG3502'}),
#  frozenset({'KOG0243', 'KOG0244'}),
#  frozenset({'KOG2988', 'KOG3204'}),
#  frozenset({'KOG0939', 'KOG3311'}),
#  frozenset({'KOG0052', 'KOG3406'}),
#  frozenset({'KOG0878', 'KOG3424'}),
#  frozenset({'KOG0893', 'KOG1728'}),
#  frozenset({'KOG0886', 'KOG1722'}),
#  frozenset({'KOG1646', 'KOG1790'}),
#  frozenset({'KOG3181', 'KOG3499'}),
#  frozenset({'KOG0893', 'KOG1570'}),
#  frozenset({'KOG1065', 'KOG3714'}),
#  frozenset({'KOG3166', 'KOG3434'}),
#  frozenset({'KOG3311', 'KOG3502'}),
#  frozenset({'KOG1728', 'KOG3436'}),
#  frozenset({'KOG1779', 'KOG3184'}),
#  frozenset({'KOG3184', 'KOG3499'}),
#  frozenset({'KOG0355', 'KOG1720'}),
#  frozenset({'KOG0052', 'KOG3475'}),
#  frozenset({'KOG0397', 'KOG0878'}),
#  frozenset({'KOG0355', 'KOG3971'}),
#  frozenset({'KOG0875', 'KOG1767'}),
#  frozenset({'KOG0400', 'KOG0901'}),
#  frozenset({'KOG0746', 'KOG0898'}),
#  frozenset({'KOG3504', 'KOG3506'}),
#  frozenset({'KOG1696', 'KOG3486'}),
#  frozenset({'KOG0001', 'KOG4075'}),
#  frozenset({'KOG0002', 'KOG0887'}),
#  frozenset({'KOG3311', 'KOG3436'}),
#  frozenset({'KOG1722', 'KOG3411'}),
#  frozenset({'KOG0052', 'KOG0878'}),
#  frozenset({'KOG0002', 'KOG3411'}),
#  frozenset({'KOG2988', 'KOG3504'}),
#  frozenset({'KOG0877', 'KOG0898'}),
#  frozenset({'KOG2988', 'KOG3506'}),
#  frozenset({'KOG0378', 'KOG0407'}),
#  frozenset({'KOG3184', 'KOG3411'}),
#  frozenset({'KOG1732', 'KOG1767'}),
#  frozenset({'KOG3181', 'KOG3320'}),
#  frozenset({'KOG0402', 'KOG0939'}),
#  frozenset({'KOG1727', 'KOG3502'}),
#  frozenset({'KOG0002', 'KOG3320'}),
#  frozenset({'KOG0354', 'KOG1124'}),
#  frozenset({'KOG0378', 'KOG3204'}),
#  frozenset({'KOG1749', 'KOG1767'}),
#  frozenset({'KOG3291', 'KOG3436'}),
#  frozenset({'KOG0893', 'KOG3255'}),
#  frozenset({'KOG3255', 'KOG3506'}),
#  frozenset({'KOG0397', 'KOG1767'}),
#  frozenset({'KOG1742', 'KOG3504'}),
#  frozenset({'KOG0815', 'KOG3411'}),
#  frozenset({'KOG3411', 'KOG3504'}),
#  frozenset({'KOG1722', 'KOG1732'}),
#  frozenset({'KOG0939', 'KOG3424'}),
#  frozenset({'KOG1570', 'KOG3434'}),
#  frozenset({'KOG0886', 'KOG0893'}),
#  frozenset({'KOG0877', 'KOG1790'}),
#  frozenset({'KOG0002', 'KOG1751'}),
#  frozenset({'KOG1732', 'KOG2988'}),
#  frozenset({'KOG0887', 'KOG1646'}),
#  frozenset({'KOG0901', 'KOG1749'}),
#  frozenset({'KOG0877', 'KOG1570'}),
#  frozenset({'KOG1714', 'KOG1753'}),
#  frozenset({'KOG1475', 'KOG3401'}),
#  frozenset({'KOG0402', 'KOG3499'}),
#  frozenset({'KOG3283', 'KOG3311'}),
#  frozenset({'KOG1762', 'KOG3412'}),
#  frozenset({'KOG3255', 'KOG3418'}),
#  frozenset({'KOG3184', 'KOG3311'}),
#  frozenset({'KOG0378', 'KOG1753'}),
#  frozenset({'KOG0002', 'KOG0407'}),
#  frozenset({'KOG0192', 'KOG1720'}),
#  frozenset({'KOG0887', 'KOG3204'}),
#  frozenset({'KOG0002', 'KOG3301'}),
#  frozenset({'KOG0397', 'KOG3436'}),
#  frozenset({'KOG1762', 'KOG3502'}),
#  frozenset({'KOG0746', 'KOG0815'}),
#  frozenset({'KOG1570', 'KOG1762'}),
#  frozenset({'KOG0877', 'KOG1728'}),
#  frozenset({'KOG0004', 'KOG3320'}),
#  frozenset({'KOG1751', 'KOG3418'}),
#  frozenset({'KOG0052', 'KOG3184'}),
#  frozenset({'KOG3406', 'KOG3486'}),
#  frozenset({'KOG0355', 'KOG0580'}),
#  frozenset({'KOG1767', 'KOG3204'}),
#  frozenset({'KOG0901', 'KOG1722'}),
#  frozenset({'KOG0829', 'KOG3475'}),
#  frozenset({'KOG0875', 'KOG3166'}),
#  frozenset({'KOG0886', 'KOG2988'}),
#  frozenset({'KOG0355', 'KOG2025'}),
#  frozenset({'KOG1696', 'KOG1790'}),
#  frozenset({'KOG1742', 'KOG3418'}),
#  frozenset({'KOG0875', 'KOG1732'}),
#  frozenset({'KOG0402', 'KOG0875'}),
#  frozenset({'KOG1790', 'KOG3311'}),
#  frozenset({'KOG1722', 'KOG3181'}),
#  frozenset({'KOG0402', 'KOG1714'}),
#  frozenset({'KOG0031', 'KOG1700'}),
#  frozenset({'KOG1749', 'KOG3166'}),
#  frozenset({'KOG0378', 'KOG3424'}),
#  frozenset({'ENOG502QQMH', 'KOG0941'}),
#  frozenset({'KOG3204', 'KOG3291'}),
#  frozenset({'KOG1753', 'KOG3344'}),
#  frozenset({'KOG0829', 'KOG3502'}),
#  frozenset({'KOG1732', 'KOG3283'}),
#  frozenset({'KOG0378', 'KOG1754'}),
#  frozenset({'KOG0004', 'KOG0397'}),
#  frozenset({'KOG0887', 'KOG1696'}),
#  frozenset({'KOG1570', 'KOG1628'}),
#  frozenset({'KOG0676', 'KOG2046'}),
#  frozenset({'KOG3344', 'KOG3475'}),
#  frozenset({'KOG1753', 'KOG3406'}),
#  frozenset({'KOG0898', 'KOG3255'}),
#  frozenset({'KOG0877', 'KOG0939'}),
#  frozenset({'KOG2988', 'KOG3418'}),
#  frozenset({'KOG0887', 'KOG3411'}),
#  frozenset({'KOG0901', 'KOG3504'}),
#  frozenset({'KOG0901', 'KOG1570'}),
#  frozenset({'KOG1790', 'KOG3424'}),
#  frozenset({'KOG0898', 'KOG3320'}),
#  frozenset({'KOG0397', 'KOG3255'}),
#  frozenset({'KOG1570', 'KOG3424'}),
#  frozenset({'KOG0886', 'KOG3486'}),
#  frozenset({'KOG0355', 'KOG3265'}),
#  frozenset({'KOG1790', 'KOG2988'}),
#  frozenset({'KOG1172', 'KOG3378'}),
#  frozenset({'KOG0829', 'KOG1762'}),
#  frozenset({'KOG1376'}),
#  frozenset({'KOG1742', 'KOG3311'}),
#  frozenset({'KOG1722', 'KOG3421'}),
#  frozenset({'KOG1727', 'KOG1790'}),
#  frozenset({'KOG1475', 'KOG1722'}),
#  frozenset({'KOG3344', 'KOG3406'}),
#  frozenset({'KOG0002', 'KOG0397'}),
#  frozenset({'KOG0002', 'KOG0877'}),
#  frozenset({'KOG1694', 'KOG3184'}),
#  frozenset({'KOG0402', 'KOG0878'}),
#  frozenset({'KOG1570', 'KOG3499'}),
#  frozenset({'KOG0887', 'KOG1714'}),
#  frozenset({'KOG0004', 'KOG0402'}),
#  frozenset({'KOG3166', 'KOG3184'}),
#  frozenset({'KOG0893', 'KOG1751'}),
#  frozenset({'KOG1722', 'KOG1751'}),
#  frozenset({'KOG0901', 'KOG1475'}),
#  frozenset({'KOG1753', 'KOG3504'}),
#  frozenset({'KOG1714', 'KOG1749'}),
#  frozenset({'KOG2988', 'KOG3486'}),
#  frozenset({'KOG3291', 'KOG3502'}),
#  frozenset({'KOG1475', 'KOG1732'}),
#  frozenset({'KOG3544'}),
#  frozenset({'KOG0746', 'KOG1646'}),
#  frozenset({'KOG0941', 'KOG1124'}),
#  frozenset({'KOG0407', 'KOG3424'}),
#  frozenset({'KOG1570', 'KOG3401'}),
#  frozenset({'KOG0002', 'KOG3424'}),
#  frozenset({'KOG0407', 'KOG3475'}),
#  frozenset({'KOG0402', 'KOG0407'}),
#  frozenset({'KOG0402', 'KOG1753'}),
#  frozenset({'KOG0187', 'KOG3499'}),
#  frozenset({'KOG0002', 'KOG3504'}),
#  frozenset({'KOG0052', 'KOG1790'}),
#  frozenset({'KOG1767', 'KOG2988'}),
#  frozenset({'KOG0035', 'KOG3581'}),
#  frozenset({'KOG0397', 'KOG0893'}),
#  frozenset({'KOG0893', 'KOG1753'}),
#  frozenset({'KOG0052', 'KOG0939'}),
#  frozenset({'KOG0052', 'KOG1570'}),
#  frozenset({'KOG0901', 'KOG1767'}),
#  frozenset({'KOG0378', 'KOG1790'}),
#  frozenset({'KOG0939', 'KOG1749'}),
#  frozenset({'KOG1767', 'KOG1779'}),
#  frozenset({'KOG3204', 'KOG3401'}),
#  frozenset({'KOG0004', 'KOG1678'}),
#  frozenset({'KOG0378', 'KOG0939'}),
#  frozenset({'KOG1727', 'KOG3204'}),
#  frozenset({'KOG1628', 'KOG1696'}),
#  frozenset({'KOG1749', 'KOG3502'}),
#  frozenset({'KOG1714', 'KOG1728'}),
#  frozenset({'KOG3301', 'KOG3502'}),
#  frozenset({'KOG1714', 'KOG3475'}),
#  frozenset({'KOG0400', 'KOG3204'}),
#  frozenset({'KOG0305', 'KOG0653'}),
#  frozenset({'KOG0400', 'KOG1728'}),
#  frozenset({'KOG1728', 'KOG1754'}),
#  frozenset({'KOG1779', 'KOG3204'}),
#  frozenset({'KOG1646', 'KOG3412'}),
#  frozenset({'KOG1762', 'KOG1790'}),
#  frozenset({'KOG0407', 'KOG1790'}),
#  frozenset({'KOG1570', 'KOG3311'}),
#  frozenset({'KOG3166', 'KOG3283'}),
#  frozenset({'KOG1751', 'KOG3320'}),
#  frozenset({'KOG1751', 'KOG3412'}),
#  ...]
